# %%
import urllib3

# %%
http = urllib3.PoolManager()

# %%
request = http.request('GET', 'http://en.akinator.com/personnages/')

# %%
request.status
# Out:
# 200

# %%
request.data
# Out:
# b'\n<!DOCTYPE html>\n<html >\n    <head>\n        <meta charset="utf-8">\n        <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n        <title>Akinator, the Web Genius</title>\n        <meta name="description" content="">\n                <meta name="author" content="Elokence">\n        <meta name="viewport" content="width=device-width,initial-scale=1">\n\n                <link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png?v86">\n        <link rel="apple-touch-icon" sizes="114x114" href="/apple-touch-icon-114x114.png?v86">\n        <link rel="apple-touch-icon" sizes="72x72" href="/apple-touch-icon-72x72.png?v86">\n        <link rel="apple-touch-icon" sizes="144x144" href="/apple-touch-icon-144x144.png?v86">\n        <link rel="apple-touch-icon" sizes="60x60" href="/apple-touch-icon-60x60.png?v86">\n        <link rel="apple-touch-icon" sizes="120x120" href="/apple-touch-icon-120x120.png?v86">\n        <link rel="apple-touch-icon" sizes="76x76
# ...

# %%
type(request.data)
# Out:
# bytes

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(request.data, 'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>Akinator, the Web Genius</title>
# <meta content="" name="description"/>
# <meta content="Elokence" name="author"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <link href="/apple-touch-icon-57x57.png?v86" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/apple-touch-icon-114x114.png?v86" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/apple-touch-icon-72x72.png?v86" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/apple-touch-icon-144x144.png?v86" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/apple-touch-icon-60x60.png?v86" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/apple-touch-icon-120x120.png?v86" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/apple-touch-icon-76x76.png?v86" rel="apple-touch-icon" sizes="76x76"/>
# ...

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>Akinator, the Web Genius</title>
# <meta content="" name="description"/>
# <meta content="Elokence" name="author"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# <link href="/apple-touch-icon-57x57.png?v86" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/apple-touch-icon-114x114.png?v86" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/apple-touch-icon-72x72.png?v86" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/apple-touch-icon-144x144.png?v86" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/apple-touch-icon-60x60.png?v86" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/apple-touch-icon-120x120.png?v86" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/apple-touch-icon-76x76.png?v86" rel="apple-touch-icon" sizes="76x76"/>
# ...

# %%
intro = soup.find('div', id='bulle-inner').text

# %%
intro
# Out:
# '\n                                        Think about a real or fictional character\n    , I will try to guess who it is.\n\n                    '

# %%
intro_2 = soup.find('div', id = 'infos-area-title').text

# %%
intro_2
# Out:
# 'Player information '

# %%
form = soup.find('div', id='infos-area-content').text

# %%
form
# Out:
# '\n\nAge :\n\n\n\n'

# %%
form_2 = soup.find( 'div', id='infos-area-footer', attrs={"input type":'submit'})

# %%
form_2

# %%
form_2 = soup.find( 'div', id='infos-area-footer', )

# %%
form_2
# Out:
# <div id="infos-area-footer"><input type="submit" value="Play"/></div>

# %%
form_2
# Out:
# <div id="infos-area-footer"><input type="submit" value="Play"/></div>

# %%
form_2.value
