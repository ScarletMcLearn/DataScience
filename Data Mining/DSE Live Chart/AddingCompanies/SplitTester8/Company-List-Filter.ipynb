# %%
company_lst_1 = [
                'MARICO',
                'OLYMPIC',
                'BSCCL',
                'SQUARETEXT',
    
                'APEXFOODS',
                'EHL',
                'GSPFINANCE',
                'IPDC',
    
                'MATINSPINN',
                'SALVOCHEM',
                'TRUSTBANK',


    #################################
                'ACMELAB',
                'ACIFORMULA',
                'JAMUNAOIL',
                'HWAWELLTEX',
    
                'DOREENPWR',
                'BSC',
                'INTRACO',
                'FORTUNE',

                'GPHISPAT',
                'RENATA', 
                'ANWARGALV',
                'BDCOM',

                'BERGERPBL',
                'PHARMAID',
                'PARAMOUNT',
                'RAHIMAFOOD',
    # #################################
                'IDLC',
                # 'KAY&QUE',
                'LINDEBD',
                'MJLBD',

                'NPOLYMER',
    # #################################
                'UPGDCL',
                'KPCL',
                'GPHISPAT',
                'BSCCL',

                # 'AMCL(PRAN)',
                'ACI',
                'SQURPHARMA',
                'SPCL',

                'POWERGRID',
                'BATBC',
                'ARAMIT',

              ]

# %%
company_lst_2 = ['MEGHNALIFE',
 'PAPERPROC',
 'ZAHINTEX',
 'STYLECRAFT',
 'NTLTUBES',
 'SAMORITA',
 'CENTRALPHL',
 'ICBIBANK',
 'CITYBANK',
 'ASIAINS',
 'PUBALIBANK',
 'ZEALBANGLA',
 'EXIMBANK',
 'HRTEX',
 'PRIMETEX',
 'STANCERAM',
 'NCCBANK',
 'GEMINISEA',
 'ALLTEX',
 'ENVOYTEX',
 'ICBEPMF1S1',
 'FINEFOODS',
 'PEOPLESINS',
 'RELIANCE1',
 'BDAUTOCA',
 'BBS',
 'MERCINS',
 'NRBCBANK',
 'EASTLAND',
 'AZIZPIPES',
 'RDFOOD',
 'WALTONHIL',
 'ACMEPL',
 'TILIL',
 'HFL',
 'DBH1STMF',
 'WATACHEM',
 'AMBEEPHA',
 'BENGALWTL',
 'AAMRANET',
 'SAVAREFR',
 'STANDARINS',
 'PLFSL',
 'PRIMEBANK',
 'SSSTEEL',
 'ETL',
 'MONNOAGML',
 'RELIANCINS',
 'ILFSL',
 'NFML',
 'FUWANGFOOD',
 'PREMIERBAN',
 'CONTININS',
 'DACCADYE',
 'BARKAPOWER',
 'BXSYNTH',
 'DUTCHBANGL',
 'WMSHIPYARD',
 'ATCSLGF',
 'MHSML',
 'MAKSONSPIN',
 'CLICL',
 'PHPMF1',
 'RECKITTBEN',
 'GHAIL',
 'SHASHADNIM',
 'TALLUSPIN',
 'COPPERTECH',
 'ICBAGRANI1',
 'SHURWID',
 'MPETROLEUM',
 'BDLAMPS',
 'MEGHNACEM',
 'FUWANGCER',
 'CVOPRL',
 'PHENIXINS',
 'PIONEERINS',
 'PURABIGEN',
 'SKICL',
 'UCB',
 'AIL',
 'EASTERNINS',
 'QUEENSOUTH',
 'LHBL',
 'PHOENIXFIN',
 'NAVANAPHAR',
 'HAKKANIPUL',
 'ITC',
 'ICBAMCL2ND',
 'MIRACLEIND',
 'GLDNJMF',
 'NEWLINE',
 'ACTIVEFINE',
 'KPPL',
 'MONNOCERA',
 'DELTALIFE',
 'BNICL',
 'FAREASTLIF',
 'APOLOISPAT',
 'BDWELDING',
 'ARAMITCEM',
 'GRAMEENS2',
 'GREENDELT',
 'SAIHAMTEX',
 'RUPALIBANK',
 'SEMLIBBLSF',
 'BIFC',
 'ICBSONALI1',
 'DAFODILCOM',
 'SAPORTL',
 'IFIC',
 'HEIDELBCEM',
 'EMERALDOIL',
 'EIL',
 'RINGSHINE',
 'GQBALLPEN',
 'BDTHAI',
 'FEKDIL',
 'UNITEDINS',
 'TITASGAS',
 'SONALIANSH',
 'ACFL',
 'MLDYEING',
 'SHYAMPSUG',
 'ROBI',
 'SAIHAMCOT',
 'JHRML',
 'KAYQUE',
 'ICB3RDNRB',
 'TRUSTB1MF',
 'RSRMSTEEL',
 'GREENDELMF',
 'MEGHNAINS',
 'PRIMEINSUR',
 'DHAKAINS',
 'SUNLIFEINS',
 'CAPMIBBLMF',
 'CNATEX',
 'BATASHOE',
 'LRBDL',
 'UNILEVERCL',
 'TAKAFULINS',
 'PDL',
 'MONOSPOOL',
 'SONARBAINS',
 'JAMUNABANK',
 'NCCBLMF1',
 'DSHGARME',
 'IBP',
                ]
 'SONALIPAPR',
 'MALEKSPIN',
 'GIB',
 'BEXIMCO',
 'EASTRNLUB',
 'NITOLINS',
 'SOUTHEASTB',
 'FASFIN',
 'PADMALIFE',
 'GHCL',
 'CAPMBDBLMF',
 'AFCAGRO',
 'SUMITPOWER',
 'APEXTANRY',
 'ICICL',
 'ISLAMICFIN',
 'SANDHANINS',
 'BSRMLTD',
 'OIMEX',
 'DSSL',
 'IFIC1STMF',
 'UNIONCAP',
 'EGEN',
 'EBL',
 'IFADAUTOS',
 'LRGLOBMF1',
 'INDEXAGRO',
 'IBNSINA',
 'BEACHHATCH',
 'DESHBANDHU',
 'MEGCONMILK',
 'ALIF',
 'MERCANBANK',
 'GP',
 'IMAMBUTTON',
 'BPML',
 'CRYSTALINS',
 'DGIC',
 'FBFIF',
 'VAMLBDMF1',
 'DOMINAGE',
 'ICB',
 'DESCO',
 'IFILISLMF1',
 'SINGERBD',
 'FAMILYTEX',
 'RUPALILIFE',
 'ONEBANKLTD',
 'FIRSTSBANK',
 'BPPL',
 'MBL1STMF',
 'SAFKOSPINN',
 'QUASEMIND',
 'BDTHAIFOOD',
 'NLI1STMF',
 'AIBL1STIMF',
 'DBH',
 'SILCOPHL',
 'CENTRALINS',
 'RAKCERAMIC',
 'POPULARLIF',
 'NHFIL',
 'KEYACOSMET',
 'AAMRATECH',
 'ESQUIRENIT',
 'SBACBANK',
 'INTECH',
 'PRAGATIINS',
 'MTB',
 'BSRMSTEEL',
 'ADNTEL',
 'ECABLES',
 'RAHIMTEXT',
 'SAIFPOWER',
 'LEGACYFOOT',
 'AMANFEED',
 'GOLDENSON',
 'FEDERALINS',
 'SEMLLECMF',
 'METROSPIN',
 'NURANI',
 'UTTARAFIN',
 'ORIONINFU',
 'AOL',
 'GBBPOWER',
 'NATLIFEINS',
 'PROGRESLIF',
 'YPL',
 'ORIONPHARM',
 'TAMIJTEX',
 'PF1STMF',
 'SEMLFBSLGF',
 'ADVENT',
 'FIRSTFIN',
 'AFTABAUTO',
 'MIDASFIN',
 'SKTRIMS',
 'NORTHERN',
 'ALHAJTEX',
 'ANLIMAYARN',
 'JMISMDL',
 'EXIM1STMF',
 'SIMTEX',
 'MIDLANDBNK',
 'RUPALIINS',
 'PTL',
 'GLOBALINS',
 'USMANIAGL',
 'PADMAOIL',
 'LANKABAFIN',
 'NAHEEACP',
 'RNSPIN',
 'KDSALTD',
 'AMCLPRAN',
 'KOHINOOR',
 'ALARABANK',
 'DHAKABANK',
 'MEGHNAPET',
 'BDFINANCE',
 'RANFOUNDRY',
 'TOSRIFA',
 'BDSERVICE',
 'UTTARABANK',
 '1JANATAMF',
 'PENINSULA',
 'PREMIERLEA',
 'SPCERAMICS',
 'DULAMIACOT',
 'APEXSPINN',
 'DELTASPINN',
 'KTL',
 'REGENTTEX',
 'EBLNRBMF',
 'BXPHARMA',
 'ISLAMIBANK',
 'EPGL',
 'STANDBANKL',
 'ASIAPACINS',
 'MONNOFABR',
 'VAMLRBBF',
 'NORTHRNINS',
 'SINOBANGLA',
 'UNIONBANK',
 'TUNGHAI',
 'FAREASTFIN',
 'EBL1STMF',
 'REPUBLIC',
 'ABBANK',
 'ISLAMIINS',
 'BANKASIA',
 'PRAGATILIF',
 'PRIME1ICBA',
 'PRIMEFIN',
 'SHAHJABANK',
 'BAYLEASING',
 'PROVATIINS',
 'BRACBANK',
 'AGNISYSL',
 'OAL',
 'SALAMCRST',
 'UNITEDFIN',
 'UNIQUEHRL',
 'SIBL',
 'ABB1STMF',
 'SILVAPHL',
 'MIRAKHTER',
 'ZAHEENSPIN',
 'RENWICKJA',
 'UNIONINS',
 'JUTESPINN',
 'ISNLTD',
 'POPULAR1MF',
 'PRIMELIFE',
 'SONALILIFE',
 'AGRANINS',
 'KBPPWBIL',
 'NBL',
 'VFSTDL',
 'SEAPEARL',
 'BBSCABLES',
 'MITHUNKNIT',
 'GENNEXT',
 'JANATAINS',
 'BGIC',
 'CONFIDCEM',
 'PREMIERCEM',
 'SAMATALETH',
 'SONARGAON',
 'NTC',
 'RUNNERAUTO',
 'LIBRAINFU',
 'BANGAS',
 'KARNAPHULI',
 'APEXFOOT',
 'SHEPHERD',
 'NAVANACNG',
 'ATLASBANG',
 'ARGONDENIM',
 'FARCHEM',
 'BEACONPHAR',
 '1STPRIMFMF',
 'CROWNCEMNT',
 'LOVELLO',
 'GENEXIL',
 'CITYGENINS']

tmp = []

for i in company_lst_2:
    if i not in company_lst_1:
        tmp.append(i)

# %%
tmp
# Out:
# ['MEGHNALIFE',
#  'PAPERPROC',
#  'ZAHINTEX',
#  'STYLECRAFT',
#  'NTLTUBES',
#  'SAMORITA',
#  'CENTRALPHL',
#  'ICBIBANK',
#  'CITYBANK',
#  'ASIAINS',
#  'PUBALIBANK',
#  'ZEALBANGLA',
#  'EXIMBANK',
#  'HRTEX',
#  'PRIMETEX',
#  'STANCERAM',
#  'NCCBANK',
#  'GEMINISEA',
#  'ALLTEX',
#  'ENVOYTEX',
#  'ICBEPMF1S1',
#  'FINEFOODS',
#  'PEOPLESINS',
#  'RELIANCE1',
#  'BDAUTOCA',
#  'BBS',
#  'MERCINS',
#  'NRBCBANK',
#  'EASTLAND',
#  'AZIZPIPES',
#  'RDFOOD',
#  'WALTONHIL',
#  'ACMEPL',
#  'TILIL',
#  'HFL',
#  'DBH1STMF',
#  'WATACHEM',
#  'AMBEEPHA',
#  'BENGALWTL',
#  'AAMRANET',
#  'SAVAREFR',
#  'STANDARINS',
#  'PLFSL',
#  'PRIMEBANK',
#  'SSSTEEL',
#  'ETL',
#  'MONNOAGML',
#  'RELIANCINS',
#  'ILFSL',
#  'NFML',
#  'FUWANGFOOD',
#  'PREMIERBAN',
#  'CONTININS',
#  'DACCADYE',
#  'BARKAPOWER',
#  'BXSYNTH',
#  'DUTCHBANGL',
#  'WMSHIPYARD',
#  'ATCSLGF',
#  'MHSML',
#  'MAKSONSPIN',
#  'CLICL',
#  'PHPMF1',
#  'RECKITTBEN',
#  'GHAIL',
#  'SHASHADNIM',
#  'TALLUSPIN',
# ...

# %%
company_lst_1 = [
                'MARICO',
                'OLYMPIC',
                'BSCCL',
                'SQUARETEXT',
    
                'APEXFOODS',
                'EHL',
                'GSPFINANCE',
                'IPDC',
    
                'MATINSPINN',
                'SALVOCHEM',
                'TRUSTBANK',


    #################################
                'ACMELAB',
                'ACIFORMULA',
                'JAMUNAOIL',
                'HWAWELLTEX',
    
                'DOREENPWR',
                'BSC',
                'INTRACO',
                'FORTUNE',

                'GPHISPAT',
                'RENATA', 
                'ANWARGALV',
                'BDCOM',

                'BERGERPBL',
                'PHARMAID',
                'PARAMOUNT',
                'RAHIMAFOOD',
    # #################################
                'IDLC',
                # 'KAY&QUE',
                'LINDEBD',
                'MJLBD',

                'NPOLYMER',
    # #################################
                'UPGDCL',
                'KPCL',
                'GPHISPAT',
                'BSCCL',

                # 'AMCL(PRAN)',
                'ACI',
                'SQURPHARMA',
                'SPCL',

                'POWERGRID',
                'BATBC',
                'ARAMIT',

              ]


company_lst_2 = ['MEGHNALIFE',
 'PAPERPROC',
 'ZAHINTEX',
 'STYLECRAFT',
 'NTLTUBES',
 'SAMORITA',
 'CENTRALPHL',
 'ICBIBANK',
 'CITYBANK',
 'ASIAINS',
 'PUBALIBANK',
 'ZEALBANGLA',
 'EXIMBANK',
 'HRTEX',
 'PRIMETEX',
 'STANCERAM',
 'NCCBANK',
 'GEMINISEA',
 'ALLTEX',
 'ENVOYTEX',
 'ICBEPMF1S1',
 'FINEFOODS',
 'PEOPLESINS',
 'RELIANCE1',
 'BDAUTOCA',
 'BBS',
 'MERCINS',
 'NRBCBANK',
 'EASTLAND',
 'AZIZPIPES',
 'RDFOOD',
 'WALTONHIL',
 'ACMEPL',
 'TILIL',
 'HFL',
 'DBH1STMF',
 'WATACHEM',
 'AMBEEPHA',
 'BENGALWTL',
 'AAMRANET',
 'SAVAREFR',
 'STANDARINS',
 'PLFSL',
 'PRIMEBANK',
 'SSSTEEL',
 'MONNOAGML',
 'ETL',
 'RELIANCINS',
 'ILFSL',
 'NFML',
 'FUWANGFOOD',
 'PREMIERBAN',
 'CONTININS',
 'DACCADYE',
 'BARKAPOWER',
 'BXSYNTH',
 'DUTCHBANGL',
 'WMSHIPYARD',
 'ATCSLGF',
 'MHSML',
 'MAKSONSPIN',
 'CLICL',
 'PHPMF1',
 'RECKITTBEN',
 'GHAIL',
 'SHASHADNIM',
 'TALLUSPIN',
 'COPPERTECH',
 'ICBAGRANI1',
 'SHURWID',
 'MPETROLEUM',
 'BDLAMPS',
 'MEGHNACEM',
 'LOVELLO',
 'FUWANGCER',
 'CVOPRL',
 'PHENIXINS',
 'PIONEERINS',
 'PURABIGEN',
 'SKICL',
 'UCB',
 'AIL',
 'EASTERNINS',
 'QUEENSOUTH'
              ]





len(company_lst_1) + len(company_lst_2)
# Out:
# 125

# %%
company_lst_3 = [
    'RELIANCE1',
 'BDAUTOCA',
 'BBS',
 'MERCINS',
 'NRBCBANK',
 'EASTLAND',
 'AZIZPIPES',
 'RDFOOD',
 'WALTONHIL',
 'ACMEPL',
 'TILIL',
 'HFL',
 'DBH1STMF',
 'WATACHEM',
 'AMBEEPHA',
 'BENGALWTL',
 'AAMRANET',
 'SAVAREFR',
 'STANDARINS',
 'PLFSL',
 'PRIMEBANK',
 'SSSTEEL',
 'ETL',
 'MONNOAGML',
 'RELIANCINS',
 'ILFSL',
 'NFML',
 'FUWANGFOOD',
 'PREMIERBAN',
 'CONTININS',
 'DACCADYE',
 'BARKAPOWER',
 'BXSYNTH',
 'DUTCHBANGL',
 'WMSHIPYARD',
 'ATCSLGF',
 'MHSML',
 'MAKSONSPIN',
 'CLICL',
 'PHPMF1',
 'RECKITTBEN',
 'GHAIL',
 'SHASHADNIM',
 'TALLUSPIN',
 'COPPERTECH',
 'ICBAGRANI1',
 'SHURWID',
 'MPETROLEUM',
 'BDLAMPS',
 'MEGHNACEM',
 'FUWANGCER',
 'CVOPRL',
 'PHENIXINS',
 'PIONEERINS',
 'PURABIGEN',
 'SKICL',
 'UCB',
 'AIL',
 'EASTERNINS',
 'QUEENSOUTH',
 'LHBL',
 'PHOENIXFIN',
 'NAVANAPHAR',
 'HAKKANIPUL',
 'ITC',
 'ICBAMCL2ND',
 'MIRACLEIND',
 'GLDNJMF',
 'NEWLINE',
 'ACTIVEFINE',
 'KPPL',
 'MONNOCERA',
 'DELTALIFE',
 'BNICL',
 'FAREASTLIF',
 'APOLOISPAT',
 'BDWELDING',
 'ARAMITCEM',
 'GRAMEENS2',
 'GREENDELT',
 'SAIHAMTEX',
 'RUPALIBANK',
 'SEMLIBBLSF',
 'BIFC',
 'ICBSONALI1',
 'DAFODILCOM',
 'SAPORTL',
 'IFIC',
 'HEIDELBCEM',
 'EMERALDOIL',
 'EIL',
 'RINGSHINE',
 'GQBALLPEN',
 'BDTHAI',
 'FEKDIL',
 'UNITEDINS',
 'TITASGAS',
 'SONALIANSH',
 'ACFL',
 'MLDYEING',
 'SHYAMPSUG',
 'ROBI',
 'SAIHAMCOT',
 'JHRML',
 'KAYQUE',
 'ICB3RDNRB',
 'TRUSTB1MF',
 'RSRMSTEEL',
 'GREENDELMF',
 'MEGHNAINS',
 'PRIMEINSUR',
 'DHAKAINS',
 'SUNLIFEINS',
 'CAPMIBBLMF',
 'CNATEX',
 'BATASHOE',
 'LRBDL',
 'UNILEVERCL',
 'TAKAFULINS',
 'PDL',
 'MONOSPOOL',
 'SONARBAINS',
 'JAMUNABANK',
 'NCCBLMF1',
 'DSHGARME',
 'IBP',
]

company_lst_4 = [
 'SONALIPAPR',
 'MALEKSPIN',
 'GIB',
 'BEXIMCO',
 'EASTRNLUB',
 'NITOLINS',
 'SOUTHEASTB',
 'FASFIN',
 'PADMALIFE',
 'GHCL',
 'CAPMBDBLMF',
 'AFCAGRO',
 'SUMITPOWER',
 'APEXTANRY',
 'ICICL',
 'ISLAMICFIN',
 'SANDHANINS',
 'BSRMLTD',
 'OIMEX',
 'DSSL',
 'IFIC1STMF',
 'UNIONCAP',
 'EGEN',

# company_lst_5 = [
 'EBL',
 'IFADAUTOS',
 'LRGLOBMF1',
 'INDEXAGRO',
 'IBNSINA',
 'BEACHHATCH',
 'DESHBANDHU',
 'MEGCONMILK',
 'ALIF',
 'MERCANBANK',
 'GP',
 'IMAMBUTTON',
 'BPML',
 'CRYSTALINS',
 'DGIC',
 'FBFIF',
 'VAMLBDMF1',
 'DOMINAGE',
 'ICB',
 'DESCO',
 'IFILISLMF1',
 'SINGERBD',
 'FAMILYTEX',
 'RUPALILIFE',
 'ONEBANKLTD',
 'FIRSTSBANK',
 'BPPL',
 'MBL1STMF',
 'SAFKOSPINN',
 'QUASEMIND',
 'BDTHAIFOOD',
 'NLI1STMF',
 'AIBL1STIMF',
 'DBH',
 'SILCOPHL',
 'CENTRALINS',
 'RAKCERAMIC',
 'POPULARLIF',
 'NHFIL',
 'KEYACOSMET',
 'AAMRATECH',
 'ESQUIRENIT',
 'SBACBANK',
 'INTECH',
 'PRAGATIINS',
 'MTB',
 'BSRMSTEEL',
 'ADNTEL',
 'ECABLES',
 'RAHIMTEXT',
 'SAIFPOWER',
 'LEGACYFOOT',
 'AMANFEED',
 'GOLDENSON',
 'FEDERALINS',
 'SEMLLECMF',
 'METROSPIN',
 'NURANI',
 'UTTARAFIN',
 'ORIONINFU',
 'AOL',
 'GBBPOWER',
 'NATLIFEINS',
 'PROGRESLIF',
 'YPL',
 'ORIONPHARM',
 'TAMIJTEX',
 'PF1STMF',
 'SEMLFBSLGF',
 'ADVENT',
 'FIRSTFIN',
 'AFTABAUTO',
 'MIDASFIN',
 'SKTRIMS',
 'NORTHERN',
 'ALHAJTEX',
 'ANLIMAYARN',
 'JMISMDL',
 'EXIM1STMF',
 'SIMTEX',
 'MIDLANDBNK',
 'RUPALIINS',
 'PTL',
 'GLOBALINS',
 'USMANIAGL',
 'PADMAOIL',
 'LANKABAFIN',
 'NAHEEACP',
 'RNSPIN',
 'KDSALTD',
 'AMCLPRAN',
 'KOHINOOR',
 'ALARABANK',
 'DHAKABANK',
 'MEGHNAPET',
 'BDFINANCE',
 'RANFOUNDRY',
 'TOSRIFA',
 'BDSERVICE',
 'UTTARABANK',
 '1JANATAMF',
 'PENINSULA',
 'PREMIERLEA',
]

company_lst_5 = [
 'SPCERAMICS',
 'DULAMIACOT',
 'APEXSPINN',
 'DELTASPINN',
 'KTL',
 'REGENTTEX',
 'EBLNRBMF',
 'BXPHARMA',
 'ISLAMIBANK',
 'EPGL',
 'STANDBANKL',
 'ASIAPACINS',
 'MONNOFABR',
 'VAMLRBBF',
 'NORTHRNINS',
 'SINOBANGLA',
 'UNIONBANK',
 'TUNGHAI',
 'FAREASTFIN',
 'EBL1STMF',
 'REPUBLIC',
 'ABBANK',
 'ISLAMIINS',
 'BANKASIA',
 'PRAGATILIF',
 'PRIME1ICBA',
 'PRIMEFIN',
 'SHAHJABANK',
 'BAYLEASING',
 'PROVATIINS',
 'BRACBANK',
 'AGNISYSL',
 'OAL',
 'SALAMCRST',
 'UNITEDFIN',
 'UNIQUEHRL',
 'SIBL',
 'ABB1STMF',
 'SILVAPHL',
 'MIRAKHTER',
 'ZAHEENSPIN',
 'RENWICKJA',
 'UNIONINS',
 'JUTESPINN',
 'ISNLTD',
 'POPULAR1MF',
 'PRIMELIFE',


# company_lst_6 = [
 'SONALILIFE',
 'AGRANINS',
 'KBPPWBIL',
 'NBL',
 'VFSTDL',
 'SEAPEARL',
 'BBSCABLES',
 'MITHUNKNIT',
 'GENNEXT',
 'JANATAINS',
 'BGIC',
 'CONFIDCEM',
 'PREMIERCEM',
 'SAMATALETH',
 'SONARGAON',
 'NTC',
 'RUNNERAUTO',
 'LIBRAINFU',
 'BANGAS',
 'KARNAPHULI',
 'APEXFOOT',
 'SHEPHERD',
 'NAVANACNG',
 'ATLASBANG',
 'ARGONDENIM',
 'FARCHEM',
 'BEACONPHAR',
 '1STPRIMFMF',
 'CROWNCEMNT',
 'LOVELLO',
 'GENEXIL',
 'CITYGENINS'
                ]

len(company_lst_5)
# Out:
# 79

# %%
company_lst_4[125]
# Out:
# 'PREMIERLEA'
