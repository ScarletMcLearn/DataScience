# %%
import pickle
 
with open('pd_df_twt_res.pkl', 'rb') as f:
    pd_df_twt_res = pickle.load(f)
    
print("Done!")
# Out:
# Done!

# %%
import pandas 

pd_df_twt_res.head(n=1000)
# Out:
#                  URL ID        USER NAME  \
# 0    973810713079812099   Hannasuewilson
# 1    973675167229489152    showupforthis
# 2                XXXXXX          jdickie
# 3    973675167229489152    showupforthis
# 4    973675167229489152    showupforthis
# 5    973675167229489152    showupforthis
# 6                XXXXXX            XXXXX
# 7                XXXXXX            XXXXX
# 8                XXXXXX            XXXXX
# 9    973810713079812099   Hannasuewilson
# 10   973675167229489152    showupforthis
# 11   974211675552436225     Innomatijane
# 12   973675167229489152    showupforthis
# 13   973675167229489152    showupforthis
# 14   973989761781260289          louewts
# 15   972994439126937605          maceoxo
# 16   973603138908426242      SethEverman
# 17   973675167229489152    showupforthis
# 18   972260283640172545         EmyAziiz
# 19   968913271720996864       ShawnLeard
# 20   973675167229489152    showupforthis
# 21   973810713079812099   Hannasuewilson
# ...
