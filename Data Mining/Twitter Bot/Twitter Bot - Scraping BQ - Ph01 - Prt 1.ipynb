# %%
import requests
from bs4 import BeautifulSoup
import pickle

# %%
class BQScraper:
    '''Scrapes BQ for links, images and quotes.'''
    base_url = 'https://www.brainyquote.com/topics'
    
    def get_catagory_bq(self):
        name_2_link = {}
        try:
            base_site = requests.get(self.base_url)
        except requests.ConnectionError:
            print('Connection Error(s) occured. :( : ' + requests.ConnectionError)
            return

        soup = BeautifulSoup(base_site.content, 'html5lib')

        for div in soup.findAll('div', attrs={'class' : 'row bq_left'}):
            temp_res_1 = (div.findAll('div', attrs={'class':'bqLn'}))

        for item in temp_res_1:
            temp_link = item.find('div', attrs={'class':'bqLn'})
            temp_name = item.find('span', attrs={'class':'topicContentName'})

            name = ""
            link = ""

            if(temp_name):

                name = temp_name.text

            if(temp_link):
                if temp_link.find('a', href=True):
                    link = (temp_link.find('a').get('href'))
                    name_2_link[name] = self.base_url+link   
        return name_2_link
    
    
    def txt_img_extract(self, res_page):
        txt_img_dic = {}
        try:
            res_pg = requests.get(res_page)


        except requests.ConnectionError:
            print('Connection Error(s) occured. :( : ' + requests.ConnectionError)

        res_page_soup = BeautifulSoup(res_pg.content, 'html5lib')

        img_box = res_page_soup.findAll('div', {'class':'m-brick grid-item boxy bqQt'})

        for itm in img_box:
            try:
                img_t = itm.find('img')['alt']
                img_l = 'https://www.brainyquote.com' + itm.find('img')['src'].replace('.jpg', '-2x.jpg')

                txt_img_dic[img_t] = img_l
            except:
                pass

        return txt_img_dic
    
    
    def txt_img_d2l(self, dict_t_i):
        img_lst = []
        for i in range(len(dict_t_i)):
            img_lst.append([list(dict_t_i.keys())[i], list(dict_t_i.values())[i]])
        return img_lst 
    
    def complete_img_l(self, img_lst):
        for i in range(len(img_lst)):
            frm_2 = img_lst[i][1].replace('1-2x.jpg', '2-2x.jpg')
            frm_3 = img_lst[i][1].replace('1-2x.jpg', '3-2x.jpg')
            frm_4 = img_lst[i][1].replace('1-2x.jpg', '4-2x.jpg')
            frm_5 = img_lst[i][1].replace('1-2x.jpg', '5-2x.jpg')

            img_lst[i].append(frm_2)
            img_lst[i].append(frm_3)
            img_lst[i].append(frm_4)
            img_lst[i].append(frm_5)

        return img_lst
    
    def picklify_lst(self, lst, fn):
        with open(fn+".txt", "wb") as fp:   #Pickling
            pickle.dump(lst, fp)
        print('Completed Picklifying.\n\n')

    def pickle_loader(self, fn):
        with open(fn, "rb") as fp:   # Unpickling
            b = pickle.load(fp)
        print('Completed Loading.\n\n')
        return b

# %%
def get_catagory_bq():
    name_2_link = {}
    base_url = 'https://www.brainyquote.com/topics'
    
    try:
        base_site = requests.get(base_url)
    except requests.ConnectionError:
        print('Connection Error(s) occured. :( : ' + requests.ConnectionError)
        return
    
    soup = BeautifulSoup(base_site.content, 'html5lib')
    
    for div in soup.findAll('div', attrs={'class' : 'row bq_left'}):
        temp_res_1 = (div.findAll('div', attrs={'class':'bqLn'}))
        
    for item in temp_res_1:
        temp_link = item.find('div', attrs={'class':'bqLn'})
        temp_name = item.find('span', attrs={'class':'topicContentName'})

        name = ""
        link = ""
        
        if(temp_name):

            name = temp_name.text
            
        if(temp_link):
            if temp_link.find('a', href=True):
                link = (temp_link.find('a').get('href'))
                name_2_link[name] = base_url+link   
    return name_2_link

# tst = get_catagory_bq()

# tst_2 = BQScraper().get_catagory_bq()

# %%
# tst_2

BQ = BQScraper()

a = BQ.txt_img_extract('https://www.brainyquote.com/topics/topics/age')

# %%
a
# Out:
# {"Age is a case of mind over matter. If you don't mind, it don't matter. - Satchel Paige": 'https://www.brainyquote.com/photos_tr/en/s/satchelpaige/164448/satchelpaige1-2x.jpg',
#  "Age is an issue of mind over matter. If you don't mind, it doesn't matter. - Mark Twain": 'https://www.brainyquote.com/photos_tr/en/m/marktwain/103892/marktwain1-2x.jpg',
#  "Age is something that doesn't matter, unless you are a cheese. - Luis Bunuel": 'https://www.brainyquote.com/photos_tr/en/l/luisbunuel/120110/luisbunuel1-2x.jpg',
#  'Aging is not lost youth but a new stage of opportunity and strength. - Betty Friedan': 'https://www.brainyquote.com/photos_tr/en/b/bettyfriedan/383994/bettyfriedan1-2x.jpg',
#  'Cherish all your happy moments; they make a fine cushion for old age. - Booth Tarkington': 'https://www.brainyquote.com/photos_tr/en/b/boothtarkington/160153/boothtarkington1-2x.jpg',
#  'Common sense is the collection of prejudices acquired by age eighteen. - Albert Einstein': 'https://www.brainyquote.com/photos_tr/en/a/alberteinstein/125365/alberteinstein1-2x.jpg',
#  'Do not go gentle into that good night but rage, rage against the dying of the light. - Dylan Thomas': 'https://www.brainyquote.com/photos_tr/en/d/dylanthomas/101660/dylanthomas1-2x.jpg',
#  'Forty is the old age of youth; fifty the youth of old age. - Victor Hugo': 'https://www.brainyquote.com/photos_tr/en/v/victorhugo/103906/victorhugo1-2x.jpg',
#  'Let us never know what old age is. Let us know the happiness time brings, not count the years. - Ausonius': 'https://www.brainyquote.com/photos_tr/en/a/ausonius/390441/ausonius1-2x.jpg',
#  "Marriage is not about age; it's about finding the right person. - Sophia Bush": 'https://www.brainyquote.com/photos_tr/en/s/sophiabush/197197/sophiabush1-2x.jpg',
#  'Men are like wine - some turn to vinegar, but the best improve with age. - Pope John XXIII': 'https://www.brainyquote.com/photos_tr/en/p/popejohnxxiii/137073/popejohnxxiii1-2x.jpg',
#  "The age of a woman doesn't mean a thing. The best tunes are played on the oldest fiddles. - Ralph Waldo Emerson": 'https://www.brainyquote.com/photos_tr/en/r/ralphwaldoemerson/385877/ralphwaldoemerson1-2x.jpg',
#  'Try to keep your soul young and quivering right up to old age. - George Sand': 'https://www.brainyquote.com/photos_tr/en/g/georgesand/154924/georgesand1-2x.jpg',
#  'Wrinkles should merely indicate where smiles have been. - Mark Twain': 'https://www.brainyquote.com/photos_tr/en/m/marktwain/103897/marktwain1-2x.jpg',
#  'Youth has no age. - Pablo Picasso': 'https://www.brainyquote.com/photos_tr/en/p/pablopicasso/138408/pablopicasso1-2x.jpg',
#  'Youth is the gift of nature, but age is a work of art. - Stanislaw Jerzy Lec': 'https://www.brainyquote.com/photos_tr/en/s/stanislawjerzylec/120623/stanislawjerzylec1-2x.jpg'}

# %%
BQ.txt_img_d2l(a)
# Out:
# [['Try to keep your soul young and quivering right up to old age. - George Sand',
#   'https://www.brainyquote.com/photos_tr/en/g/georgesand/154924/georgesand1-2x.jpg'],
#  ['Men are like wine - some turn to vinegar, but the best improve with age. - Pope John XXIII',
#   'https://www.brainyquote.com/photos_tr/en/p/popejohnxxiii/137073/popejohnxxiii1-2x.jpg'],
#  ['Cherish all your happy moments; they make a fine cushion for old age. - Booth Tarkington',
#   'https://www.brainyquote.com/photos_tr/en/b/boothtarkington/160153/boothtarkington1-2x.jpg'],
#  ["Age is something that doesn't matter, unless you are a cheese. - Luis Bunuel",
#   'https://www.brainyquote.com/photos_tr/en/l/luisbunuel/120110/luisbunuel1-2x.jpg'],
#  ['Wrinkles should merely indicate where smiles have been. - Mark Twain',
#   'https://www.brainyquote.com/photos_tr/en/m/marktwain/103897/marktwain1-2x.jpg'],
#  ["Marriage is not about age; it's about finding the right person. - Sophia Bush",
#   'https://www.brainyquote.com/photos_tr/en/s/sophiabush/197197/sophiabush1-2x.jpg'],
#  ['Youth has no age. - Pablo Picasso',
#   'https://www.brainyquote.com/photos_tr/en/p/pablopicasso/138408/pablopicasso1-2x.jpg'],
#  ['Let us never know what old age is. Let us know the happiness time brings, not count the years. - Ausonius',
#   'https://www.brainyquote.com/photos_tr/en/a/ausonius/390441/ausonius1-2x.jpg'],
#  ["Age is a case of mind over matter. If you don't mind, it don't matter. - Satchel Paige",
#   'https://www.brainyquote.com/photos_tr/en/s/satchelpaige/164448/satchelpaige1-2x.jpg'],
#  ['Common sense is the collection of prejudices acquired by age eighteen. - Albert Einstein',
#   'https://www.brainyquote.com/photos_tr/en/a/alberteinstein/125365/alberteinstein1-2x.jpg'],
#  ['Youth is the gift of nature, but age is a work of art. - Stanislaw Jerzy Lec',
#   'https://www.brainyquote.com/photos_tr/en/s/stanislawjerzylec/120623/stanislawjerzylec1-2x.jpg'],
#  ["Age is an issue of mind over matter. If you don't mind, it doesn't matter. - Mark Twain",
#   'https://www.brainyquote.com/photos_tr/en/m/marktwain/103892/marktwain1-2x.jpg'],
#  ['Aging is not lost youth but a new stage of opportunity and strength. - Betty Friedan',
#   'https://www.brainyquote.com/photos_tr/en/b/bettyfriedan/383994/bettyfriedan1-2x.jpg'],
#  ['Do not go gentle into that good night but rage, rage against the dying of the light. - Dylan Thomas',
#   'https://www.brainyquote.com/photos_tr/en/d/dylanthomas/101660/dylanthomas1-2x.jpg'],
#  ["The age of a woman doesn't mean a thing. The best tunes are played on the oldest fiddles. - Ralph Waldo Emerson",
#   'https://www.brainyquote.com/photos_tr/en/r/ralphwaldoemerson/385877/ralphwaldoemerson1-2x.jpg'],
#  ['Forty is the old age of youth; fifty the youth of old age. - Victor Hugo',
#   'https://www.brainyquote.com/photos_tr/en/v/victorhugo/103906/victorhugo1-2x.jpg']]

# %%
BQ.pickle_loader('as.txt')
# Out:
# Completed Loading.
# [['Try to keep your soul young and quivering right up to old age. - George Sand',
#   'https://www.brainyquote.com/photos_tr/en/g/georgesand/154924/georgesand1-2x.jpg',
#   'https://www.brainyquote.com/photos_tr/en/g/georgesand/154924/georgesand2-2x.jpg',
#   'https://www.brainyquote.com/photos_tr/en/g/georgesand/154924/georgesand3-2x.jpg',
#   'https://www.brainyquote.com/photos_tr/en/g/georgesand/154924/georgesand4-2x.jpg',
#   'https://www.brainyquote.com/photos_tr/en/g/georgesand/154924/georgesand5-2x.jpg'],
#  ['Men are like wine - some turn to vinegar, but the best improve with age. - Pope John XXIII',
#   'https://www.brainyquote.com/photos_tr/en/p/popejohnxxiii/137073/popejohnxxiii1-2x.jpg',
#   'https://www.brainyquote.com/photos_tr/en/p/popejohnxxiii/137073/popejohnxxiii2-2x.jpg',
#   'https://www.brainyquote.com/photos_tr/en/p/popejohnxxiii/137073/popejohnxxiii3-2x.jpg',
#   'https://www.brainyquote.com/photos_tr/en/p/popejohnxxiii/137073/popejohnxxiii4-2x.jpg',
#   'https://www.brainyquote.com/photos_tr/en/p/popejohnxxiii/137073/popejohnxxiii5-2x.jpg'],
#  ['Cherish all your happy moments; they make a fine cushion for old age. - Booth Tarkington',
#   'https://www.brainyquote.com/photos_tr/en/b/boothtarkington/160153/boothtarkington1-2x.jpg',
#   'https://www.brainyquote.com/photos_tr/en/b/boothtarkington/160153/boothtarkington2-2x.jpg',
#   'https://www.brainyquote.com/photos_tr/en/b/boothtarkington/160153/boothtarkington3-2x.jpg',
#   'https://www.brainyquote.com/photos_tr/en/b/boothtarkington/160153/boothtarkington4-2x.jpg',
#   'https://www.brainyquote.com/photos_tr/en/b/boothtarkington/160153/boothtarkington5-2x.jpg'],
#  ["Age is something that doesn't matter, unless you are a cheese. - Luis Bunuel",
#   'https://www.brainyquote.com/photos_tr/en/l/luisbunuel/120110/luisbunuel1-2x.jpg',
#   'https://www.brainyquote.com/photos_tr/en/l/luisbunuel/120110/luisbunuel2-2x.jpg',
#   'https://www.brainyquote.com/photos_tr/en/l/luisbunuel/120110/luisbunuel3-2x.jpg',
#   'https://www.brainyquote.com/photos_tr/en/l/luisbunuel/120110/luisbunuel4-2x.jpg',
#   'https://www.brainyquote.com/photos_tr/en/l/luisbunuel/120110/luisbunuel5-2x.jpg'],
#  ["You can't help getting older, but you don't have to get old. - George Burns",
#   'https://www.brainyquote.com/photos_tr/en/g/georgeburns/103932/georgeburns1-2x.jpg',
#   'https://www.brainyquote.com/photos_tr/en/g/georgeburns/103932/georgeburns2-2x.jpg',
#   'https://www.brainyquote.com/photos_tr/en/g/georgeburns/103932/georgeburns3-2x.jpg',
#   'https://www.brainyquote.com/photos_tr/en/g/georgeburns/103932/georgeburns4-2x.jpg',
#   'https://www.brainyquote.com/photos_tr/en/g/georgeburns/103932/georgeburns5-2x.jpg'],
#  ["Marriage is not about age; it's about finding the right person. - Sophia Bush",
#   'https://www.brainyquote.com/photos_tr/en/s/sophiabush/197197/sophiabush1-2x.jpg',
#   'https://www.brainyquote.com/photos_tr/en/s/sophiabush/197197/sophiabush2-2x.jpg',
#   'https://www.brainyquote.com/photos_tr/en/s/sophiabush/197197/sophiabush3-2x.jpg',
#   'https://www.brainyquote.com/photos_tr/en/s/sophiabush/197197/sophiabush4-2x.jpg',
#   'https://www.brainyquote.com/photos_tr/en/s/sophiabush/197197/sophiabush5-2x.jpg'],
#  ['Youth has no age. - Pablo Picasso',
#   'https://www.brainyquote.com/photos_tr/en/p/pablopicasso/138408/pablopicasso1-2x.jpg',
#   'https://www.brainyquote.com/photos_tr/en/p/pablopicasso/138408/pablopicasso2-2x.jpg',
#   'https://www.brainyquote.com/photos_tr/en/p/pablopicasso/138408/pablopicasso3-2x.jpg',
#   'https://www.brainyquote.com/photos_tr/en/p/pablopicasso/138408/pablopicasso4-2x.jpg',
#   'https://www.brainyquote.com/photos_tr/en/p/pablopicasso/138408/pablopicasso5-2x.jpg'],
#  ['Let us never know what old age is. Let us know the happiness time brings, not count the years. - Ausonius',
#   'https://www.brainyquote.com/photos_tr/en/a/ausonius/390441/ausonius1-2x.jpg',
#   'https://www.brainyquote.com/photos_tr/en/a/ausonius/390441/ausonius2-2x.jpg',
#   'https://www.brainyquote.com/photos_tr/en/a/ausonius/390441/ausonius3-2x.jpg',
#   'https://www.brainyquote.com/photos_tr/en/a/ausonius/390441/ausonius4-2x.jpg',
#   'https://www.brainyquote.com/photos_tr/en