# %%
import twitter

# %%
api = twitter.Api(consumer_key='4fsyL9GWIQkbXi9hHJcVDpm4L',
                      consumer_secret='ekOHjtbvWCltUTkMX9qC3YwxAZmU9QgnIetKd1hfzMLKP41HIn',
                      access_token_key='149863732-hCncnsL7EDkgaujC5WRZl3oGCYNaaCDttyjcYVxU',
                      access_token_secret='AcELcldQyLIIKz78LLr6JYiscjRBMJKM7b6CLA1gg86rS')

# %%
print(api.VerifyCredentials())
# Out:
# {"created_at": "Sun May 30 12:36:34 +0000 2010", "default_profile_image": true, "favourites_count": 110, "followers_count": 35, "friends_count": 68, "id": 149863732, "lang": "en", "listed_count": 2, "name": "Essence Primus", "profile_background_color": "000000", "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png", "profile_image_url": "http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png", "profile_link_color": "FAB81E", "profile_sidebar_fill_color": "000000", "profile_text_color": "000000", "screen_name": "essenceprimus", "status": {"created_at": "Sun Mar 04 15:57:11 +0000 2018", "id": 970327302180450305, "id_str": "970327302180450305", "lang": "und", "possibly_sensitive": true, "source": "<a href=\"http://www.facebook.com/twitter\" rel=\"nofollow\">Facebook</a>", "text": "https://t.co/I2S1L5ACrL"}, "statuses_count": 35817, "time_zone": "Pacific Time (US & Canada)", "utc_offset": -28800}

# %%
help(api.rate_limit)
# Out:
# Help on RateLimit in module twitter.ratelimit object:
#
# class RateLimit(builtins.object)
#  |  Object to hold the rate limit status of various endpoints for
#  |  the twitter.Api object.
#  |
#  |  This object is generally attached to the API as Api.rate_limit, but is not
#  |  created until the user makes a method call that uses _RequestUrl() or calls
#  |  Api.InitializeRateLimit(), after which it get created and populated with
#  |  rate limit data from Twitter.
#  |
#  |  Calling Api.InitializeRateLimit() populates the object with all of the
#  |  rate limits for the endpoints defined by Twitter; more info is available
#  |  here:
#  |
#  |      https://dev.twitter.com/rest/public/rate-limits
#  |
#  |      https://dev.twitter.com/rest/public/rate-limiting
#  |
#  |      https://dev.twitter.com/rest/reference/get/application/rate_limit_status
#  |
#  |  Once a resource (i.e., an endpoint) has been requested, Twitter's response
# ...

# %%
api.InitializeRateLimit()

# %%
api.rate_limit.get_limit('statuses/user_timeline')
# Out:
# EndpointRateLimit(limit=15, remaining=15, reset=0)

# %% [markdown]
# Creation
# Objects such as Tweets, Direct Messages, user profile pictures, hosted Ads cards, etc. can contain one or more media objects. These top-level objects are collectively known as entities. The relevant entity creation API (e.g. POST statuses/update) can be passed one or more media objects using a unique media_id.
#
# An entity which contains media object(s) can be created by following these steps:
#
# Upload the media file(s) using either the recommended chunked upload (images/GIF/video), or the older simple upload (images only).
# Receive a media_id from step 1. This step may be repeated multiple times with different media if the entity allows multiple media_id parameters to be passed in.
# Create the entity by calling the appropriate endpoint, including the media_id and other required parameters. For example, attach a media_id to a Tweet using the POST statuses/update endpoint.

# %%
api.rate_limit.get_limit('POST statuses/update')
# Out:
# EndpointRateLimit(limit=15, remaining=15, reset=0)

# %%
api.rate_limit.get_limit('statuses/update')
# Out:
# EndpointRateLimit(limit=15, remaining=15, reset=0)

# %%
help(api.PostUpdate)
# Out:
# Help on method PostUpdate in module twitter.api:
#
# PostUpdate(status, media=None, media_additional_owners=None, media_category=None, in_reply_to_status_id=None, auto_populate_reply_metadata=False, exclude_reply_user_ids=None, latitude=None, longitude=None, place_id=None, display_coordinates=False, trim_user=False, verify_status_length=True, attachment_url=None) method of twitter.api.Api instance
#     Post a twitter status message from the authenticated user.
#
#     https://dev.twitter.com/docs/api/1.1/post/statuses/update
#
#     Args:
#         status (str):
#             The message text to be posted. Must be less than or equal to 140
#             characters.
#         media (int, str, fp, optional):
#             A URL, a local file, or a file-like object (something with a
#             read() method), or a list of any combination of the above.
#         media_additional_owners (list, optional):
#             A list of user ids representing Twitter users that should be able
# ...

# %%
import requests
import os

def tweet_post(message, url=None):
#     api = twitter_api()
    filename = 'temp.jpg'
    request = requests.get(url, stream=True)
    if request.status_code == 200:
        with open(filename, 'wb') as image:
            for chunk in request:
                image.write(chunk)

        api.PostUpdate(media=filename, status=message)
        os.remove(filename)
    else:
        print("Unable to download image")


url = "https://www.brainyquote.com/photos_tr/en/s/stjerome/389605/stjerome1-2x.jpg"
message = "Nice one"
tweet_image(url, message)

# %%
api.rate_limit.get_limit('statuses/post')
# Out:
# EndpointRateLimit(limit=15, remaining=15, reset=0)

# %%
import pprint

pprint.pprint(api.rate_limit.resources)
# Out:
# {'account': {'/account/login_verification_enrollment': {'limit': 15,
#                                                         'remaining': 15,
#                                                         'reset': 1520182032},
#              '/account/settings': {'limit': 15,
#                                    'remaining': 15,
#                                    'reset': 1520182032},
#              '/account/update_profile': {'limit': 15,
#                                          'remaining': 15,
#                                          'reset': 1520182032},
#              '/account/verify_credentials': {'limit': 75,
#                                              'remaining': 75,
#                                              'reset': 1520182032}},
#  'account_activity': {'/account_activity/all/:instance_name/subscriptions': {'limit': 15,
#                                                                              'remaining': 15,
# ...

# %%
api.rate_limit.

# %%
import tweepy
from __future__ import unicode_literals


consumer_key='4fsyL9GWIQkbXi9hHJcVDpm4L'
consumer_secret='ekOHjtbvWCltUTkMX9qC3YwxAZmU9QgnIetKd1hfzMLKP41HIn'
access_token_key='149863732-hCncnsL7EDkgaujC5WRZl3oGCYNaaCDttyjcYVxU'
access_token_secret='AcELcldQyLIIKz78LLr6JYiscjRBMJKM7b6CLA1gg86rS'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token_key, access_token_secret)

api = tweepy.API(auth)

# %%
api

# %%
print(api)

# %%
public_tweets = api.home_timeline()

for tweet in public_tweets:
    print(tweet.text)
# Out:
# RT @MirrorTV: #Corrie's Brooke Vincent in tears after criticism from Jason on #DancingOnIce
#
# https://t.co/iPBFL4W5Bq https://t.co/PAgqQwQyej
# RT @MirrorFighting: Anthony Joshua under fire after Twitter users discover 'sexist' comments in interview
# https://t.co/NNLDZCSOsK https://t…
# Wishing #uss #uuk #acas and #UCU negotiators a good evening, a good night’s sleep, and pleasant dreams in preparati… https://t.co/6oBXC5KMtK
# You Need To Watch 'SNL's 2018 Oscars Parody "The Grabbies"
# https://t.co/wyzIEoNhUK https://t.co/KrS28TANNB
# The ultimate his ‘n’ hers diet plan - easy but effective shape-up plan made for two
# https://t.co/5Y1P9dWldU https://t.co/lIlr1VkMGB
# Mum of girl, 5, who died after being turned away by GP blasts compensation offer
# https://t.co/kQImDJsGsT https://t.co/ZWsfrq9oDf
# Just a thought:
# What if the people in 2 Girls 1 Cup (and the remakes) were forced into it like in Black Mirror or... https://t.co/6lynvgfVUp
# https://t.co/RxxwhgKmSH
# ...

# %%
import requests
import os

def tweepy_image(url, message):
#     api = twitter_api()
    filename = 'temp.jpg'
    request = requests.get(url, stream=True)
    if request.status_code == 200:
        with open(filename, 'wb') as image:
            for chunk in request:
                image.write(chunk)

        api.update_with_media(filename=filename, status=message)
        os.remove(filename)
    else:
        print("Unable to download image")


url = "https://www.brainyquote.com/photos_tr/en/s/stjerome/389605/stjerome1-2x.jpg"
message = "Nice one"
tweepy_image(url, message)

# %%
api.rate_limit_status()
# Out:
# {'rate_limit_context': {'access_token': '149863732-hCncnsL7EDkgaujC5WRZl3oGCYNaaCDttyjcYVxU'},
#  'resources': {'account': {'/account/login_verification_enrollment': {'limit': 15,
#     'remaining': 15,
#     'reset': 1520192567},
#    '/account/settings': {'limit': 15, 'remaining': 15, 'reset': 1520192567},
#    '/account/update_profile': {'limit': 15,
#     'remaining': 15,
#     'reset': 1520192567},
#    '/account/verify_credentials': {'limit': 75,
#     'remaining': 75,
#     'reset': 1520192567}},
#   'account_activity': {'/account_activity/all/:instance_name/subscriptions': {'limit': 15,
#     'remaining': 15,
#     'reset': 1520192567},
#    '/account_activity/all/:instance_name/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1520192567},
#    '/account_activity/all/webhooks': {'limit': 15,
#     'remaining': 15,
#     'reset': 1520192567},
#    '/account_activity/direct_messages/:instance_name/subscriptions': {'limit': 15,
#     'remaining': 15,
# ...

# %%
api.ra
