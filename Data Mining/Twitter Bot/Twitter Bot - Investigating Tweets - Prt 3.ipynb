# %%
import json

# %%
data_list = []

for line in open('depression_1.json', 'r'):
    data_list.append(eval(line.replace('null', 'None').replace('false', 'False').replace('true', 'True')))

# %%
type(data_list[0])
# Out:
# dict

# %%
data_list[0]
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Thu Mar 15 17:55:20 +0000 2018',
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'urls': [],
#   'user_mentions': [{'id': 1272273181,
#     'id_str': '1272273181',
#     'indices': [3, 18],
#     'name': 'Living Loved',
#     'screen_name': 'Hannasuewilson'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 974343304837042178,
#  'id_str': '974343304837042178',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'place': None,
#  'retweet_count': 5861,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Mar 14 06:39:01 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
# ...

# %%
a_1 = [data_list[0], data_list[1]]

# %%
a_1
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Thu Mar 15 17:55:20 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 1272273181,
#      'id_str': '1272273181',
#      'indices': [3, 18],
#      'name': 'Living Loved',
#      'screen_name': 'Hannasuewilson'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 974343304837042178,
#   'id_str': '974343304837042178',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 5861,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Mar 14 06:39:01 +0000 2018',
# ...

# %%
#  Its important to use binary mode
file = open('examplePickle', 'ab')

# %%
# source, destination
import pickle

pickle.dump(a_1, file)                  
file.close()

# %%
file = open('examplePickle', 'rb')     
    
db = pickle.load(file)

# %%
db
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Thu Mar 15 17:55:20 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 1272273181,
#      'id_str': '1272273181',
#      'indices': [3, 18],
#      'name': 'Living Loved',
#      'screen_name': 'Hannasuewilson'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 974343304837042178,
#   'id_str': '974343304837042178',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 5861,
#   'retweeted': False,
#   'retweeted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Wed Mar 14 06:39:01 +0000 2018',
# ...

# %%
type(db)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3053775d8b15> in <module>()
# ----> 1 type(db)
#
# NameError: name 'db' is not defined

# %%
file = open('depression_1.pkle', 'ab')

# %%
# source, destination
import pickle

print("Dumping.")
pickle.dump(data_list, file)   
print("Dumping Complete.")
file.close()
# Out:
# Dumping.
# Dumping Complete.
