# %%
                      print(("""consumer_key='4fsyL9GWIQkbXi9hHJcVDpm4L',
                      consumer_secret='ekOHjtbvWCltUTkMX9qC3YwxAZmU9QgnIetKd1hfzMLKP41HIn',
                      access_token_key='149863732-hCncnsL7EDkgaujC5WRZl3oGCYNaaCDttyjcYVxU',
                      access_token_secret='AcELcldQyLIIKz78LLr6JYiscjRBMJKM7b6CLA1gg86rS'""").replace(',', ''))
# Out:
# consumer_key='4fsyL9GWIQkbXi9hHJcVDpm4L'
# consumer_secret='ekOHjtbvWCltUTkMX9qC3YwxAZmU9QgnIetKd1hfzMLKP41HIn'
# access_token_key='149863732-hCncnsL7EDkgaujC5WRZl3oGCYNaaCDttyjcYVxU'
# access_token_secret='AcELcldQyLIIKz78LLr6JYiscjRBMJKM7b6CLA1gg86rS'

# %%
consumer_key='4fsyL9GWIQkbXi9hHJcVDpm4L'
consumer_secret='ekOHjtbvWCltUTkMX9qC3YwxAZmU9QgnIetKd1hfzMLKP41HIn'
access_token_key='149863732-hCncnsL7EDkgaujC5WRZl3oGCYNaaCDttyjcYVxU'
access_token_secret='AcELcldQyLIIKz78LLr6JYiscjRBMJKM7b6CLA1gg86rS'

# %%
import twitter

# %%
api = twitter.Api(consumer_key,
                      consumer_secret,
                      access_token_key,
                      access_token_secret)

# %%
print(api.VerifyCredentials())
# Out:
# {"created_at": "Sun May 30 12:36:34 +0000 2010", "favourites_count": 346, "followers_count": 86, "friends_count": 696, "geo_enabled": true, "id": 149863732, "lang": "en", "listed_count": 2, "name": "Essence Primus", "profile_background_color": "000000", "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png", "profile_banner_url": "https://pbs.twimg.com/profile_banners/149863732/1520207671", "profile_image_url": "http://pbs.twimg.com/profile_images/970447491282841600/QWPlQw5r_normal.jpg", "profile_link_color": "FAB81E", "profile_sidebar_fill_color": "000000", "profile_text_color": "000000", "screen_name": "essenceprimus", "status": {"created_at": "Thu May 03 18:54:29 +0000 2018", "id": 992115194116505600, "id_str": "992115194116505600", "lang": "en", "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>", "text": "How to Cancel All Sent Friend Requests at Once in 1 second on Facebook https://t.co/nbY5PYzYmu"}, "statuses_count": 3
# ...

# %%
credentials = api.VerifyCredentials()

# %%
import pprint

pprint.pprint(credentials.AsJsonString())
# Out:
# ('{"created_at": "Sun May 30 12:36:34 +0000 2010", "favourites_count": 346, '
#  '"followers_count": 86, "friends_count": 696, "geo_enabled": true, "id": '
#  '149863732, "lang": "en", "listed_count": 2, "name": "Essence Primus", '
#  '"profile_background_color": "000000", "profile_background_image_url": '
#  '"http://abs.twimg.com/images/themes/theme1/bg.png", "profile_banner_url": '
#  '"https://pbs.twimg.com/profile_banners/149863732/1520207671", '
#  '"profile_image_url": '
#  '"http://pbs.twimg.com/profile_images/970447491282841600/QWPlQw5r_normal.jpg", '
#  '"profile_link_color": "FAB81E", "profile_sidebar_fill_color": "000000", '
#  '"profile_text_color": "000000", "screen_name": "essenceprimus", "status": '
#  '{"created_at": "Thu May 03 18:54:29 +0000 2018", "id": 992115194116505600, '
#  '"id_str": "992115194116505600", "lang": "en", "source": "<a '
#  'href=\\"http://twitter.com\\" rel=\\"nofollow\\">Twitter Web Client</a>", '
# ...

# %%
statuses = api.GetUserTimeline(screen_name='Phil_Lewis_')

# %%
help(api)
# Out:
# Help on Api in module twitter.api object:
#
# class Api(builtins.object)
#  |  A python interface into the Twitter API
#  |
#  |  By default, the Api caches results for 1 minute.
#  |
#  |  Example usage:
#  |
#  |    To create an instance of the twitter.Api class, with no authentication:
#  |
#  |      >>> import twitter
#  |      >>> api = twitter.Api()
#  |
#  |    To fetch a single user's public status messages, where "user" is either
#  |    a Twitter "short name" or their user id.
#  |
#  |      >>> statuses = api.GetUserTimeline(user)
#  |      >>> print([s.text for s in statuses])
#  |
#  |    To use authentication, instantiate the twitter.Api class with a
#  |    consumer key and secret; and the oAuth key and secret:
#  |
#  |      >>> api = twitter.Api(consumer_key='twitter consumer key',
#  |                            consumer_secret='twitter consumer secret',
#  |                            access_token_key='the_key_given',
# ...

# %%
help(api.GetReplies)
# Out:
# Help on method GetReplies in module twitter.api:
#
# GetReplies(since_id=None, count=None, max_id=None, trim_user=False) method of twitter.api.Api instance
#     Get a sequence of status messages representing the 20 most
#     recent replies (status updates prefixed with @twitterID) to the
#     authenticating user.
#
#     Args:
#       since_id:
#         Returns results with an ID greater than (that is, more recent
#         than) the specified ID. There are limits to the number of
#         Tweets which can be accessed through the API. If the limit of
#         Tweets has occurred since the since_id, the since_id will be
#         forced to the oldest ID available. [Optional]
#       max_id:
#         Returns results with an ID less than (that is, older than) or
#         equal to the specified ID. [Optional]
#       trim_user:
#         If True the returned payload will only contain the user IDs,
#         otherwise the payload will contain the full user data item.
# ...

# %%
api.GetReplies()
# Out:
# [Status(ID=992115194116505600, ScreenName=essenceprimus, Created=Thu May 03 18:54:29 +0000 2018, Text='How to Cancel All Sent Friend Requests at Once in 1 second on Facebook https://t.co/nbY5PYzYmu'),
#  Status(ID=990181216132317184, ScreenName=essenceprimus, Created=Sat Apr 28 10:49:33 +0000 2018, Text='How to Cancel All Sent Friend Requests at Once in 1 second on Facebook https://t.co/nbY5PYzYmu'),
#  Status(ID=988817736879915009, ScreenName=essenceprimus, Created=Tue Apr 24 16:31:34 +0000 2018, Text='Question on @Quora: How is the living expenses in Greenwich? What job opportunities for international students? How… https://t.co/Rl60vRaBYd'),
#  Status(ID=977050573500440577, ScreenName=essenceprimus, Created=Fri Mar 23 05:13:04 +0000 2018, Text='How to Cancel All Sent Friend Requests at Once in 1 second on Facebook https://t.co/nbY5PYzYmu'),
# ...

# %%
api.GetStatus('988016857251631104')
# Out:
# Status(ID=988016857251631104, ScreenName=Nike, Created=Sun Apr 22 11:29:09 +0000 2018, Text="1, 2, 3. Men's and Women's in London. \n\U0001f947\U0001f948\U0001f949 #JustDoIt \n\n@EliudKipchoge \nTola Shura Kitata \n@Mo_Farah… https://t.co/A7kdRrIDm1")

# %%
statuses
# Out:
# [Status(ID=999292317482831872, ScreenName=Phil_Lewis_, Created=Wed May 23 14:13:49 +0000 2018, Text='RT @CNN: Christian "Riley" Garcia, 15, is being hailed as a hero after he died while blocking an art classroom door to keep other students…'),
#  Status(ID=999263525200592896, ScreenName=Phil_Lewis_, Created=Wed May 23 12:19:24 +0000 2018, Text='I will never complain about my student loans again https://t.co/YXsKXowAcF'),
#  Status(ID=999150622883614720, ScreenName=Phil_Lewis_, Created=Wed May 23 04:50:46 +0000 2018, Text='RT @Travis_Waldron: Two months after teacher protests, a Kentucky high school teacher knocks off the state House majority leader in a GOP p…'),
#  Status(ID=999102606881558529, ScreenName=Phil_Lewis_, Created=Wed May 23 01:39:58 +0000 2018, Text='Stacey Abrams has won the Democratic nomination for governor of Georgia. If elected, she’d be the first black woman… https://t.co/zJLlxzLrjl'),
# ...

# %%
import tweepy

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)

# %%
consumer_key,
                      consumer_secret,
                      access_token_key,
                      access_token_secret
# Out:
# Help on API in module tweepy.api object:
#
# class API(builtins.object)
#  |  Twitter API
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, auth_handler=None, host='api.twitter.com', search_host='search.twitter.com', upload_host='upload.twitter.com', cache=None, api_root='/1.1', search_root='', upload_root='/1.1', retry_count=0, retry_delay=0, retry_errors=None, timeout=60, parser=None, compression=False, wait_on_rate_limit=False, wait_on_rate_limit_notify=False, proxy='')
#  |      Api instance Constructor
#  |
#  |      :param auth_handler:
#  |      :param host:  url of the server of the rest api, default:'api.twitter.com'
#  |      :param search_host: url of the search server, default:'search.twitter.com'
#  |      :param upload_host: url of the upload server, default:'upload.twitter.com'
#  |      :param cache: Cache to query if a GET method is used, default:None
#  |      :param api_root: suffix of the api version, default:'/1.1'
# ...

# %%
auth.set_access_token(access_token_key, access_token_secret)

apy = tweepy.API(auth)

# %%
apy.verify_credentials()
# Out:
# User(has_extended_profile=False, protected=False, default_profile=False, favourites_count=346, url=None, profile_background_color='000000', entities={'description': {'urls': []}}, profile_background_tile=False, id_str='149863732', follow_request_sent=False, friends_count=696, name='Essence Primus', geo_enabled=True, status=Status(in_reply_to_status_id_str='922148512787247107', favorite_count=0, source='Twitter Web Client', geo=None, contributors=None, in_reply_to_user_id=45646060, is_quote_status=False, in_reply_to_status_id=922148512787247107, entities={'hashtags': [], 'symbols': [], 'user_mentions': [{'id_str': '45646060', 'screen_name': '_Zeets', 'name': 'Zito', 'id': 45646060, 'indices': [0, 7]}], 'urls': []}, lang='en', in_reply_to_user_id_str='45646060', coordinates=None, text='@_Zeets test', in_reply_to_screen_name='_Zeets', favorited=False, _api=<tweepy.api.API object at 0x7f241616e438>, place=None, source_url='http://twitter.com', truncated=False, created_at=datetime.datetim
# ...

# %%
help(apy)
# Out:
# Help on API in module tweepy.api object:
#
# class API(builtins.object)
#  |  Twitter API
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, auth_handler=None, host='api.twitter.com', search_host='search.twitter.com', upload_host='upload.twitter.com', cache=None, api_root='/1.1', search_root='', upload_root='/1.1', retry_count=0, retry_delay=0, retry_errors=None, timeout=60, parser=None, compression=False, wait_on_rate_limit=False, wait_on_rate_limit_notify=False, proxy='')
#  |      Api instance Constructor
#  |
#  |      :param auth_handler:
#  |      :param host:  url of the server of the rest api, default:'api.twitter.com'
#  |      :param search_host: url of the search server, default:'search.twitter.com'
#  |      :param upload_host: url of the upload server, default:'upload.twitter.com'
#  |      :param cache: Cache to query if a GET method is used, default:None
#  |      :param api_root: suffix of the api version, default:'/1.1'
# ...

# %%
help(apy.search_users)
# Out:
# Help on function _call in module tweepy.binder:
#
# _call(*args, **kwargs)

# %%
help(apy.search)
# Out:
# Help on function _call in module tweepy.binder:
#
# _call(*args, **kwargs)

# %%
a = apy.search('@Nike')

# %%
help(a[0])
# Out:
# Help on Status in module tweepy.models object:
#
# class Status(Model)
#  |  Method resolution order:
#  |      Status
#  |      Model
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __eq__(self, other)
#  |      Return self==value.
#  |
#  |  __ne__(self, other)
#  |      Return self!=value.
#  |
#  |  destroy(self)
#  |
#  |  favorite(self)
#  |
#  |  retweet(self)
#  |
#  |  retweets(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  parse(api, json) from builtins.type
#  |      Parse a JSON object into a model instance.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __hash__ = None
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from Model:
#  |
#  |  __getstate__(self)
#  |
#  |  __init__(self, api=None)
# ...

# %%
(a[0]._json)
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Wed May 23 15:48:40 +0000 2018',
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'urls': [],
#   'user_mentions': [{'id': 32027571,
#     'id_str': '32027571',
#     'indices': [3, 13],
#     'name': 'Aaron Dodson',
#     'screen_name': 'aardodson'},
#    {'id': 23083404,
#     'id_str': '23083404',
#     'indices': [44, 54],
#     'name': 'LeBron James',
#     'screen_name': 'KingJames'},
#    {'id': 415859364,
#     'id_str': '415859364',
#     'indices': [82, 87],
#     'name': 'Nike',
#     'screen_name': 'Nike'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 999316190093864963,
#  'id_str': '999316190093864963',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
# ...

# %%
a[0]._json[('created_at')]
# Out:
# 'Wed May 23 15:48:40 +0000 2018'

# %%
len(a)
# Out:
# 15

# %%
for _ in range(15):
    if a(_)._json[('in_reply_to_status_id_str')] != None:
        print(a[_]._json[('in_reply_to_status_id_str')])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-8bd351570718> in <module>()
#       1 for _ in range(15):
# ----> 2     if a(_)._json[('in_reply_to_status_id_str')] != None:
#       3         print(a[_]._json[('in_reply_to_status_id_str')])
#
# TypeError: 'SearchResults' object is not callable

# %%
for _ in range(15):
    if a(_)._json[('in_reply_to_status_id_str')] != None:
        print(a[_]._json[('in_reply_to_status_id_str')])
