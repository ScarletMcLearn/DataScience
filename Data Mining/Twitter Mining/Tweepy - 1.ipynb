# %% [markdown]
# ## Importing Tweepy

# %%
import tweepy

# %% [markdown]
# ## Setting Up Tweepy
#
# ### Printing tweets

# %%
consumer_key = 'F8rPAdtXOLkmrKQySWE0APDaa'
consumer_secret = 'TtD0czxBRcydqEDtC80X2lqM7lPUigVumUuBZS3K94a27uriuG'
access_token = '149863732-xSwmL051gcdlpAVeFMN3nvjoLEkFGup1DPPPd6VK'
access_token_secret = 'B55TjcosWOSLodPSyWhK37MGTk0u3xFWISI7MvaW5SDyG'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth) 
public_tweets = api.home_timeline()

for tweet in public_tweets:
    print (tweet.text)
# Out:
# So apparently my little school-going cousin tells his parents 'cash me ousside' to take 'bhara' from them before going outside.
# RT @MirrorTravel: Sneak peek at Disney's new #StarWars land as plans revealed  https://t.co/BgPNIFy9d8 https://t.co/jLcRJksf0k
# Pampered pooch goes on a weight loss detox retreat - where it gets its own personal training plan https://t.co/8nGqlQhNZ5
# RT @MirrorTV: Phillip Schofield moves This Morning viewers to tears as he agrees to pay a mum's debt
# https://t.co/L6Opg25NhX https://t.co/X…
# Planned Parenthood Slams The Second Senate Health Care Bill For Being The Actual Worst https://t.co/BYhi4EHzAS https://t.co/dMZzWqqeJw
# https://t.co/HLXd3wNaHb
# RT @MirrorTech: Moon Express says it's on track to start mining the lunar surface by 2020 https://t.co/0Lf3PEranQ https://t.co/TvQhLmw59v
# Airport worker tries to stop plane rolling back on to runway with his bare hands
# https://t.co/wRUQePHg0C https://t.co/ZGYpMeF2Lo
# Coach driver flicks V-sign at champion cyclist after cutting him up
# https://t.co/sJnZaS2qtJ https://t.co/FLEKDKAzpL
# Katie Piper calls for more to be done to stop acid attacks
# https://t.co/plZasMBrj6 https://t.co/YFRqhn50RG
# Donors raised over $18k for a beloved community member after learning he needed a double #lungtransplant. https://t.co/WQA0KOehQE
# Donald Trump caught in ridiculously long handshake battle with Emmanuel Macron https://t.co/tftLRA8J0k https://t.co/Aogp9x8jPo
# RT @MirrorCeleb: Sharon Stone says she won't be 'pitted against' Madonna after singer's insult
# https://t.co/szFga8k0uk https://t.co/cz99WFT…
# OUP author Roger Crisp is discussing 'Moral Luck and Equality of Moral Opportunity’ at the Inaugural Address, chaired by @timcrane102
# That's a wrap on #BSPS2017! Luckily for us #JointSession2017 starts right after it. Make sure to come and browse the OUP stand all weekend!
# 👸 (@BuzzFeedFashion) https://t.co/eXLE3bHRYd
# That dress in Beyonce's baby reveal photo is from a MENSWEAR line https://t.co/Ai5rUFBGzG
# https://t.co/hvjd062DHA
# Grandparents are UK's main suppliers of childcare as parents try to save cash
# https://t.co/4g2s7OvZzV https://t.co/lNfVqvFIbK

# %% [markdown]
# ## Posting Tweet

# %%
def get_api(cfg):
      auth = tweepy.OAuthHandler(cfg['consumer_key'], cfg['consumer_secret'])
      auth.set_access_token(cfg['access_token'], cfg['access_token_secret'])
      return tweepy.API(auth)

def main():
      # Fill in the values noted in previous step here
      cfg = { 
        "consumer_key"        : consumer_key,
        "consumer_secret"     : consumer_secret,
        "access_token"        : access_token,
        "access_token_secret" : access_token_secret 
        }

      api = get_api(cfg)
      tweet = "Hello, world!"
      status = api.update_status(status=tweet) 
      # Yes, tweet is called 'status' rather confusing

if __name__ == "__main__":
#       main()
# Out:
#   File "<ipython-input-3-14abaa9268c2>", line 21
#     #       main()
#                   ^
# SyntaxError: unexpected EOF while parsing

# %%
import json
import tweepy
# t = tweepy.Twitter(domain='api.twitter.com', api_version='1')
# print (json.dumps(t.trends(), indent=1))

# %% [markdown]
# # This is the listener, resposible for receiving data
# class StdOutListener(tweepy.StreamListener):
#     def on_data(self, data):
#         # Twitter returns data in JSON format - we need to decode it first
#         decoded = json.loads(data)
#
#         # Also, we convert UTF-8 to ASCII ignoring all bad characters sent by users
#         print ('@%s: %s' % (decoded['user']['screen_name'], decoded['text'].encode('ascii', 'ignore')))
#         print ('')
#         return True
#
#     def on_error(self, status):
#         print (status)
#
# if __name__ == '__main__':
#     l = StdOutListener()
#     auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
#     auth.set_access_token(access_token, access_token_secret)
#
#     print ("Showing all new tweets for #programming:")
#
#     # There are different kinds of streams: public stream, user stream, multi-user streams
#     # In this example follow #programming tag
#     # For more details refer to https://dev.twitter.com/docs/streaming-apis
#     stream = tweepy.Stream(auth, l)
#     stream.filter(track=['programming'])

# %% [markdown]
# stream = tweepy.Stream(auth, l)

# %% [markdown]
# stream.listener

# %%
from tweepy.streaming import StreamListener

class listener(StreamListener):

    def on_data(self, data):
        all_data = json.loads(data)
        
        tweet = all_data["text"]
        
        username = all_data["user"]["screen_name"]
        
#         c.execute("INSERT INTO taula (time, username, tweet) VALUES (%s,%s,%s)",
#             (time.time(), username, tweet))

#         conn.commit()

        print((username,tweet))
        
        return True

    def on_error(self, status):
        print (status)


auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

twitterStream = tweepy.Stream(auth, listener())
twitterStream.filter(track=["book"])
# Out:
# ('MBridegam', "RT @espiers: I am skeptical that he's reading anything longer than two pages. Getting him to read his own newspaper was like pul… ")
# ('Phil_254', 'RT @leemakwiny: Retweet this if you believe @RailaOdinga has the best chance of winning the election as he launch his book… ')
# ('navesha_', 'That book just broke my heart. 😢')
# ('hplbot', "RT @MaxwellMudd: Here's a link to my Kickstarter! You can get a Cthulhu print and custom art!\nhttps://t.co/HL78e7t2Xp\n#art #books #HPLovecr…")
# ('lazarhart', 'Agree w/ @johncatucci "I think there is still something about holding a book in your hands and flipping through it" https://t.co/yp67HlwVHm')
# ('GallagherAuthor', '@littlehummertwo I just wanted to let you know that all my books are available here: https://t.co/fVzEXFkO1E including my latest book Serial')
# ('BrenFrancisco', 'RT @elleryschneider: [wedding]\n\n"and now the groom will read his vows"\nme: you make every day feel like a scholastic book fair')
# ('2901_xa', 'RT @shyymal: The book i need rn https://t.co/zPkz9C0ubo')
# ('stlucysASB', 'The online book store is now available. To download and purchase your books check-out https://t.co/rnObwQXiDt')
# ('mawico1938', 'Please read book:  "MALCOLM X" (autiobio as told to ALEX HALEY). A revealing account of much of Anti-USA Black-Muslim activism in America.)')
# ('jessmoneeyy', "RT @AndrewKanatsky: This intimate af, don't @ me... https://t.co/APbvUGwIYy")
# ('febreezyfresh', 'Mostly agree--reading is questionable. Or at least reading for substance is questionable. https://t.co/SIwUMqh5Fv')
# ('SCBWI_BI', 'RT @JonnyGeller: The Perfect Book Cover. https://t.co/pomdQNQlQ2')
# ('Taryn_Cymone', 'RT @jl__anderson: Someone should write a book on how black people have transformed the culture of marketing in social media. https://t.co/W…')
# ('BonnieKHunter', "Garden Party from the Addicted to Scraps book -  group2!  It's a beautiful day in Bedford, PA!… https://t.co/d9J4KMhwIA")
# ('ClouDatAI', 'squideye : Quantum Big Data Cloud AI Book Chapter 7 - https://t.co/VuZ8ulTcvP Business Plans Handbook : https://t.co/8Y8FvnzSYH')
# ('JesseWh43000630', 'RT @_netscribe_: 68% done with TROTR by Edmund Morris. #currentlyreading \n\nhttps://t.co/CZLOaHFujE')
# ('jnpkrishna', "RT @rajkumar8973: #जीने_की_राह know from the book, What is Krishna's sign to the Satguru in Gita?; \nhttps://t.co/Y1HRcTd7HR\n@PMOIndia \n@raj…")
# ('CarolinejGoode', "@KalbirBains @Sharan_Project @OurGirlUK Giving a voice to the voiceless, Kalbir. Can't wait to read the book 😉")
# ('awhjaa', '@JoeyGraceffa Book tour for Elites of Eden confirmed yet?')
# ('Now_Wud_Be_Nice', 'RT @AndrewFairbairn: RT if you have more followers than Milo has book sales https://t.co/6rEPgiCW3i')
# ('DNChamber', 'Don’t miss out on the BCC’s biggest international #trade event of the year. Book your tickets now: https://t.co/MZ63l2K3Us #bcctrade')
# ('MacyLewis6', 'Which Version of my book would you prefer?')
# ('sonokocentral', "RT @espiers: I am skeptical that he's reading anything longer than two pages. Getting him to read his own newspaper was like pul… ")
# ('ClouDatAI', 'MissKMcD : Quantum Big Data Cloud AI Book Chapter 1 - https://t.co/BP4uI1MGzT Air Transportation John G Wensveen : https://t.co/jbIUDeEAYB')
# ('bisignanovadino', "@itsamazingamy And yes, this novella not being in a bookstore doesn't mean that I'll never have a book in a booksto… https://t.co/mdD3LMOYvX")
# ('DrawDownBooks', 'BUSAN ART BOOK FAIR @B_S_P_L - July 15-16\nFind our titles and MANY others 💕 at #PostPoetics Booth 46 ☛… https://t.co/WK7UoafG6p')
# ('Soapy_Wit_Tank', "RT @espiers: I am skeptical that he's reading anything longer than two pages. Getting him to read his own newspaper was like pul… ")
# ('dawsons_creek12', 'RT @AndrewFairbairn: RT if you have more followers than Milo has book sales https://t.co/6rEPgiCW3i')
# ('StephLIngram', "#RRBC The Benefits of Attending a Virtual Writers' #Conference &amp; Book Expo https://t.co/pijPcFDlEb via @LauraLibricz")
# ('MattSBritton', '@YoktanBenEber @splcenter Corporal Punishment in a Sexually Gratifying way in order to become closer to God, and ev… https://t.co/vlCBcgg5rN')
# ('Wazirsi14412326', 'RT @Wazirsi14412326: The most famous E-book #जीने_की_राह\nAfter reading this your misconception for GOD IS FORMLESS., Will surely  change\n\nh…')
# ('GallagherAuthor', '@sadiefranklin44 I just wanted to let you know that all my books are available here: https://t.co/fVzEXFkO1E including my latest book Serial')
# ('KaneAnderson_', "RT @Mark__Lawrence: A random someone retweeting this will win a signed Red Sister!\n\n(UK trade paperback)\n\nJust because it's Friday.… ")
# ('hannah_bstt', 'RT @AndrewFairbairn: RT if you have more followers than Milo has book sales https://t.co/6rEPgiCW3i')
# ('PTMcBriarty', 'Trailer for City Railways a new picture book about Elevated &amp; Subway Trains! #STEM #KidLit 4 little Engineers… https://t.co/iluLXNEiJI')
# ('CamKLivingston', 'RT @KELLYROWLAND: ❤️❤️❤️❤️❤️❤️❤️ https://t.co/icshBNIC2Q')
# ('ChrisSullivan19', 'yea! 💜 👆 https://t.co/xIuqToyXFt')
# ('dawnetteb04', "@pagepublishing - Can't  wait for my book to arrive! #Author #pagepublishing #books #read #fantasyfiction https://t.co/6bi42zwgFS")
# ('isissosilly', 'RT @iamwilliewill: Mfs used to come back to class with book marks, stretchable pencils, colorful markers all type of shit. I damn near… ')
# ('Loremonteiro2', 'RT @EmmaWatson: I interviewed @MargaretAtwood for @EW and my book club https://t.co/jzDJYb7bi0. Such an honour! Full interview here… ')
# ('dkelly_11', 'Hurling and Camogie @Cúlcamp takes place in Dr Tierney Park @Graiggaa Mon 24th July- Fri 28th 10 - 2:30 daily. Cost 60 euro. Book online.')
# ('JoyShepD', "1/3 I had a teenage scrap book with Goran's almost-Grand Slam wins, hearts and all, and sad moments like these.💔… https://t.co/VMoucPbq0z")
# ('Akku11577606', '#जीने_की_राह book changes the general perception of human life.\n#BhagwatUPAPlot\n@VijayGoelBJP\n@VasundharaBJP\n#NewSKODAOctavia\n#DDNews')
# ('LouiseO85770034', 'RT @LamaJabr: Start Here: How to Write a Book Proposal https://t.co/WSEfGplATS')
# ('NickKilpatrick', "RT @deadmau5: Thanks kiddo... I'm eternally grateful that your doing your own thing. That's why you're a winner in my book... too… ")
# ('tomservo10', 'RT @ddale8: The book is being published by a HarperCollins imprint. It\'ll look at Trump\'s "rarely discussed, but deeply important, religiou…')
# ('jai_dai2x', "RT @AndrewKanatsky: This intimate af, don't @ me... https://t.co/APbvUGwIYy")
# ('shahsuneel', '@digvijaya_28  planned it &amp; released a book named  26/11 RSS ki Sajish.\n\nNIA should pour petrol in his ass than wil… https://t.co/1vqLTZ9EuY')
# ('SelmaJenny', 'RT @felixhagman: Anna Book är? Helt? https://t.co/b57d5o18uR')
# ('BywordtheBook', 'Biblephobia: BYWORD THE BOOK: THE IDENTITY CRISIS DISCONTINUES https://t.co/9CNGjUFOIj')
# ('BeTheZeitgeist', 'RT @jl__anderson: Someone should write a book on how black people have transformed the culture of marketing in social media. https://t.co/W…')
# ('short_sb', "RT @CHICKLET_HF: Don't judge a book by its cover https://t.co/eFO1Y6tEvi")
# ('mikereidchef', "RT @InnWestEnd: To book your table for Taylor's takeover on August 1st, follow this link: https://t.co/oN74SgEYJM \n\nEvery vote counts!!\n\n#y…")
# ('archivesplus', 'Book benches trail #readmcr 26 down 32 to go https://t.co/YqF8D12jGi')
# ('maryfaithpeace', 'Stackable Sherlock 🔬\n\nhttps://t.co/TT5EahJ2Ah... https://t.co/qnWlGN35EM')
# ('shownushields', 'RT @archiveshownu: #BEAUTIFULINSEOUL — program book https://t.co/43shkl4WNA')
# ('sugarslimmm', 'book: this will allow you to be seen and loved for who you are instead of hiding out and pushing people away. \nme: https://t.co/1YJn4oBryA')
# ('luvbourbon', '@SassyProf diss/book re: Daughters of the Confederacy was rejected multiple times. Then won the SAWH prize! Look at… https://t.co/CF2aItSdAp')
# ('_bettayy_', 'RT @jl__anderson: Someone should write a book on how black people have transformed the culture of marketing in social media. https://t.co/W…')
# ('AlexsBitch_', 'RT @jl__anderson: Someone should write a book on how black people have transformed the culture of marketing in social media. https://t.co/W…')
# ('mnicula', '@CNN These self-righteous Congressmen. They do everything by the book. They only sell influence to registered lobbyists.')
# ('A_Zbookstore', 'オリジナル補機ベルトセット 4PK820/4PK940/4PK1090 トヨタ/TOYOTA サイノス EL44 ... (店舗名：オートパーツエージェンシー)https://t.co/YOVVvnsvtm')
# ('beanhanseul', '@zendayahoIIand @PalaisPlastique @katya_zamo so you dont understand sarcasm. how about you buy a book about humor?')
# ('samuelpalin', ".@goodwroter has done the thing in his tweet which I won't write out more times than Milo has sold a book. https://t.co/radxT6nVnF")
# ('EerieNotions', "@wizardofcause Actually, it's because there are no more Harry Potter book coming out.")
# ('alwatin58', 'RT @AndrewFairbairn: RT if you have more followers than Milo has book sales https://t.co/6rEPgiCW3i')
# 
'#जीने_की_राह book changes the general perception of human life.\n#BhagwatUPAPlot\n@VijayGoelBJP\n@VasundharaBJP… https://t.co/1obUsIPrvr')
# ('VickyBookworm', 'Yes please!! Looks amazing #tbr https://t.co/bfgb2JNLi0')
# ('karenkirakosya4', 'Мне понравилось видео "Слот Book of Ra. Реально дает! Эпичная концовка!"')
# ('Arjunkumarsalv2', 'RT @DrRupeshDas1: #जीने_की_राह \nThis book teaches us how to Live in society and also in our family\nhttps://t.co/iIPZsbpFaj https://t.co/fN3…')
# ('aizydaisy', 'RT @iamwilliewill: Mfs used to come back to class with book marks, stretchable pencils, colorful markers all type of shit. I damn near… ')
# ('jaggadasstailor', '#DilliKiRaat\n#जीने_की_राह is a book guiding us to establish peaceful world without any discrimination\n https://t.co/skZqDPNOn5')
# ('AziHeron', "At work: that feeling when you're editing someone else's book &amp; know it will be a classic the moment it hits bookshelves. #editing #wonder")
# ('wakeupamericas2', 'RT @RealJamesWoods: Dear #Numbskull, open a history book sometime. Nixon was never impeached. Only two presidents ever were, Andrew Joh… ')
# ('Angelina898B', '#जीने_की_राह book changes the general perception of human life.\n#BhagwatUPAPlot\n@VijayGoelBJP\n@VasundharaBJP… https://t.co/KmVz6iMIyQ')
# ('Jawaheer47', "and maybe when it's a popular book i'll admit that i wrote it who knows🤔")
# ('AgamAnEntity', 'RT @nikifyinglife: a comic book coming alive in the form of a perfect musical. What a treat! #JaggaJasoos')
# ('bettyblue37degr', '@OvendenLaura we need this book! https://t.co/D6IGMOPUlK')
# ('MaryamAK96', 'RT @AAAlGosaibi: Turn the page or burn the book.')
# ('LDNIrishCentre', 'And finally, lots of good shows coming in through @CamdenFringe. See and book them here: https://t.co/oo6gSwpFXH.')
# ('mix_mix_1', 'Мне понравилось видео "Слот Book of Ra. Реально дает! Эпичная концовка!"')
# ('VaughnDarritt', '#Fiction https://t.co/b99rAISQ06')
# ('SuzySindy', 'RT @TheCrimeVault: RT before midnight to #win a copy of the book everyone is talking about @laurajm8\xa0 #FriendRequestFridays (UK) T&amp;Cs:… ')
# ('Unmagiically', 'RT @AndrewFairbairn: RT if you have more followers than Milo has book sales https://t.co/6rEPgiCW3i')
# ('akansha_rawat98', '#जीने_की_राह book changes the general perception of human life.\n#BhagwatUPAPlot\n@VijayGoelBJP\n@VasundharaBJP… https://t.co/wNdRzuNJIn')
# ('__nxvvn__', 'RT @13ReasonsLife: one of the best lines in the book https://t.co/52Jwzf1yBH')
# ('SamiiiLB', 'RT @camphalfblood: One month until the Percy Jackson Coloring Book comes out Aug. 15! What colors should we make these lovely ladies? https…')
# ---------------------------------------------------------------------------
# IncompleteRead                            Traceback (most recent call last)
# /home/scarlet/anaconda3/envs/my_env/lib/python3.6/http/client.py in _readinto_chunked(self, b)
#     587                 temp_mvb = mvb[:chunk_left]
# --> 588                 n = self._safe_readinto(temp_mvb)
#     589                 mvb = mvb[n:]
#
# /home/scarlet/anaconda3/envs/my_env/lib/python3.6/http/client.py in _safe_readinto(self, b)
#     629             if not n:
# --> 630                 raise IncompleteRead(bytes(mvb[0:total_bytes]), len(b))
#     631             mvb = mvb[n:]
#
# IncompleteRead: IncompleteRead(0 bytes read, 4048 more expected)
#
# During handling of the above exception, another exception occurred:
#
# IncompleteRead                            Traceback (most recent call last)
# /home/scarlet/anaconda3/envs/my_env/lib/python3.6/site-packages/requests/packages/urllib3/response.py in _error_catcher(self)
#     301             try:
# --> 302                 yield
#     303
#
# /home/scarlet/anaconda3/envs/my_env/lib/python3.6/site-packages/requests/packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     383                 cache_content = False
# --> 384                 data = self._fp.read(amt)
#     385                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#
# /home/scarlet/anaconda3/envs/my_env/lib/python3.6/http/client.py in read(self, amt)
#     448             b = bytearray(amt)
# --> 449             n = self.readinto(b)
#     450             return memoryview(b)[:n].tobytes()
#
# /home/scarlet/anaconda3/envs/my_env/lib/python3.6/http/client.py in readinto(self, b)
#     482         if self.chunked:
# --> 483             return self._readinto_chunked(b)
#     484
#
# /home/scarlet/anaconda3/envs/my_env/lib/python3.6/http/client.py in _readinto_chunked(self, b)
#     593         except IncompleteRead:
# --> 594             raise IncompleteRead(bytes(b[0:total_bytes]))
#     595
#
# IncompleteRead: IncompleteRead(1482 bytes read)
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# /home/scarlet/anaconda3/envs/my_env/lib/python3.6/site-packages/tweepy/streaming.py in _run(self)
#     269                     self.retry_time = self.retry_time_start
# --> 270                     self.snooze_time = self.snooze_time_step
#     271                     self.listener.on_connect()
#
# /home/scarlet/anaconda3/envs/my_env/lib/python3.6/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     329                 else:
# --> 330                     raise TweepError('Expecting length, unexpected value found')
#     331
#
# /home/scarlet/anaconda3/envs/my_env/lib/python3.6/site-packages/tweepy/streaming.py in read_len(self, length)
#     162             if len(self._buffer) >= length:
# --> 163                 return self._pop(length)
#     164             read_len = max(self._chunk_size, length - len(self._buffer))
#
# /home/scarlet/anaconda3/envs/my_env/lib/python3.6/site-packages/requests/packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     400                         # Content-Length are caught.
# --> 401                         raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#     402
#
# /home/scarlet/anaconda3/envs/my_env/lib/python3.6/contextlib.py in __exit__(self, type, value, traceback)
#      99             try:
# --> 100                 self.gen.throw(type, value, traceback)
#     101                 raise RuntimeError("generator didn't stop after throw()")
#
# /home/scarlet/anaconda3/envs/my_env/lib/python3.6/site-packages/requests/packages/urllib3/response.py in _error_catcher(self)
#     319                 # This includes IncompleteRead.
# --> 320                 raise ProtocolError('Connection broken: %r' % e, e)
#     321
#
# ProtocolError: ('Connection broken: IncompleteRead(1482 bytes read)', IncompleteRead(1482 bytes read))
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-f4427e54c9e2> in <module>()
#      27
#      28 twitterStream = tweepy.Stream(auth, listener())
# ---> 29 twitterStream.filter(track=["book"])
#
# /home/scarlet/anaconda3/envs/my_env/lib/python3.6/site-packages/tweepy/streaming.py in filter(self, follow, track, async, locations, stall_warnings, languages, encoding, filter_level)
#     453         if filter_level:
#     454             self.body['filter_level'] = filter_level.encode(encoding)
# --> 455         self.session.params = {'delimited': 'length'}
#     456         self.host = 'stream.twitter.com'
#     457         self._start(async)
#
# /home/scarlet/anaconda3/envs/my_env/lib/python3.6/site-packages/tweepy/streaming.py in _start(self, async)
#     367         if async:
#     368             self._thread = Thread(target=self._run)
# --> 369             self._thread.start()
#     370         else:
#     371             self._run()
#
# /home/scarlet/anaconda3/envs/my_env/lib/python3.6/site-packages/tweepy/streaming.py in _run(self)
#     286                 sleep(self.snooze_time)
#     287                 self.snooze_time = min(self.snooze_time + self.snooze_time_step,
# --> 288                                        self.snooze_time_cap)
#     289             except Exception as exc:
#     290                 exc_info = sys.exc_info()
#
# NameError: name 'sys' is not defined

# %% [markdown]
# Fixed working code below

# %%
import tweepy

consumer_key = 'F8rPAdtXOLkmrKQySWE0APDaa'
consumer_secret = 'TtD0czxBRcydqEDtC80X2lqM7lPUigVumUuBZS3K94a27uriuG'
access_token = '149863732-xSwmL051gcdlpAVeFMN3nvjoLEkFGup1DPPPd6VK'
access_token_secret = 'B55TjcosWOSLodPSyWhK37MGTk0u3xFWISI7MvaW5SDyG'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)
public_tweets = api.home_timeline()

for tweet in public_tweets:
    print (tweet.text)


import json
import tweepy
# t = tweepy.Twitter(domain='api.twitter.com', api_version='1')
# print (json.dumps(t.trends(), indent=1))

from tweepy.streaming import StreamListener

class listener(StreamListener):

    def on_data(self, data):
        all_data = json.loads(data)

        tweet = all_data["text"]

        username = all_data["user"]["screen_name"]

#         c.execute("INSERT INTO taula (time, username, tweet) VALUES (%s,%s,%s)",
#             (time.time(), username, tweet))

#         conn.commit()

        print((username,tweet))

        return True

    def on_error(self, status):
        print (status)


auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

# twitterStream = tweepy.Stream(auth, listener())
# twitterStream.filter(track=["book"])



# def start_stream():
#     while True:
#         try:
#             sapi = tweepy.streaming.Stream(auth, CustomStreamListener(api))
#             sapi.filter(track=['book'])
#         except:
#             continue
#
# start_stream()


while True:
    try:
        twitterStream = tweepy.Stream(auth, listener())
        twitterStream.filter(track=["book"])
    except:
        continue
