# %% [markdown]
# # Introduction to Blog Recommendation System

# %% [markdown]
# In today's information age, tech blogs have become an invaluable source of knowledge, insights, and entertainment. With the ever-growing abundance of blog content, finding the most relevant and engaging articles can be a daunting task for users. To address this challenge, we need a comprehensive blog recommendation system, leveraging cutting-edge techniques and machine learning algorithms to enhance the user experience on blog platforms.
#
# In this kernel we will build blog recommendation system based on <a href="https://www.kaggle.com/datasets/yakshshah/blog-recommendation-data?datasetId=3253367&sortBy=dateRun&tab=profile">Blog Recommendation Data</a> published by me. Which consists of blog data collected from __Medium__ and the ratings collected from over 5000 users by traking their activity.
#
# ### Their are two types of Recommendation System
#
# 1. **Collaborative Filtering**:
#
# Collaborative filtering is a popular recommendation technique that leverages the collective wisdom of users to make recommendations. It analyzes user behavior and item similarity to identify patterns and generate personalized suggestions. There are two main approaches within collaborative filtering:
#
# > * **User-Based Collaborative Filtering**: This approach recommends items to a user based on the preferences of similar users. It identifies users with similar tastes and recommends items that those similar users have enjoyed. For example, if User A and User B have similar preferences and User A likes a specific blog post, the system will recommend that post to User B.
#
# > * **Item-Based Collaborative Filtering**: Instead of focusing on similar users, item-based collaborative filtering recommends items similar to those a user has previously enjoyed. It analyzes the relationships between items and suggests new items based on their similarities. For instance, if User A likes Blog Post X, and Blog Post Y is similar to Blog Post X, the system will recommend Blog Post Y to User A.

# %% [markdown]
# 2.  __Content-Based Filtering__:
#
# Content-based filtering recommends items based on their attributes or characteristics. It uses user preferences and item features to make recommendations. This approach builds user profiles based on their historical preferences and item attributes. It then recommends items that align with the user's preferences and exhibit similar features. For instance, if a user has shown interest in technology-related blog posts, the system will recommend more articles with similar technological topics.

# %% [markdown]
# 3.
# __Hybrid Recommendation Systems__:
# Hybrid recommendation systems combine multiple recommendation approaches to provide more accurate and diverse suggestions. They leverage the strengths of different techniques to overcome limitations and offer enhanced recommendations. For example, a hybrid system might combine collaborative filtering and content-based filtering to balance between user preferences and item attributes. By using collaborative filtering to capture user behavior and content-based filtering to capture item characteristics, a hybrid system can provide more accurate and personalized recommendations.

# %% [markdown]
# We will be using Content Based Filtering approach filtering based for building our recommendation system.

# %% [markdown]
# ### Let's get started

# %%
# import required packages

import pandas as pd
import numpy as np
import nltk
import re
from nltk import corpus
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk import wsd
from nltk.corpus import wordnet as wn

nltk.download('omw-1.4')
nltk.download('wordnet')
nltk.download('wordnet2022')

! cp -rf /usr/share/nltk_data/corpora/wordnet2022 /usr/share/nltk_data/corpora/wordnet # temp fix for lookup error.
# Out:
# [nltk_data] Downloading package omw-1.4 to /usr/share/nltk_data...
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package wordnet2022 to /usr/share/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet2022.zip.

# %% [markdown]
# Let us load the data now

# %%
blog_df = pd.read_csv('/kaggle/input/blog-recommendation-data/Medium Blog Data.csv')
author_df = pd.read_csv('/kaggle/input/blog-recommendation-data/Author Data.csv')
ratings_df = pd.read_csv('/kaggle/input/blog-recommendation-data/Blog Ratings.csv')

# %% [markdown]
# The first dataset has following features,
#
# * blog_id : Unique ID given to the blog
# * author_id : Unique ID given to the author of the blog
# * blog_title : Title of the Blog
# * blog _ content : Brief Summary of what the blog content is about
# * blog_link : link to the specific blog
# * blog_img : image related to that blog
# * blog_topic : domain it belongs to for eg. AI,Data Science etc.
#
# The Second dataset has following features,
#
# * author_id : Unique ID given to the author
# * author_name : Name of the author
#
# The Third dataset has following features,
#
# * blog_id : ID of the blog
# * user_id : ID of the User
# * ratings : ratings given by the user

# %% [markdown]
# # Content Based Filtering

# %% [markdown]
# Let us first see how many blogs we have for each domain

# %%
blog_df['topic'].value_counts()
# Out:
# ai                      736
# blockchain              644
# cybersecurity           642
# web-development         635
# data-analysis           594
# cloud-computing         589
# security                527
# web3                    471
# machine-learning        467
# nlp                     453
# data-science            444
# deep-learning           430
# android                 426
# dev-ops                 384
# information-security    374
# image-processing        354
# flutter                 343
# backend                 341
# cloud-services          339
# Cryptocurrency          331
# app-development         322
# backend-development     312
# Software-Development    309
# Name: topic, dtype: int64

# %% [markdown]
# ### Remove the columns from blog data that are not needed
# Let us remove __author_id__, __blog_link__, __blog_img__ and __scrape_time__ from blog_df

# %%
blog_df.drop(['author_id','blog_link','blog_img','scrape_time'],axis='columns',inplace=True)

# %% [markdown]
# We need to remove duplicate blog data

# %%
blog_df.drop_duplicates(['blog_title','blog_content'],inplace=True)

# %% [markdown]
# ### Preprocessing Text Data
# It is necessary to remove the stopwords from blog content and also apply lemmatization to bring all the words to theirt root word this is the basic step we need to perform before we move forward

# %%
lst_stopwords=corpus.stopwords.words('english')
def pre_process_text(text, flg_stemm=False, flg_lemm=True, lst_stopwords=None):
    text=str(text).lower()
    text=text.strip()
    text = re.sub(r'[^\w\s]', '', text)
    lst_text = text.split()
    if lst_stopwords is not None:
        lst_text=[word for word in lst_text if word not in lst_stopwords]
    if flg_lemm:
        lemmatizer = WordNetLemmatizer()
        lst_text = [lemmatizer.lemmatize(word) for word in lst_text]
    if flg_stemm:
        stemmer = PorterStemmer()
        lst_text = [stemmer.stem(word) for word in lst_text]
    text=" ".join(lst_text)
    return text

# %%
blog_df['clean_blog_content'] = blog_df['blog_content'].apply(lambda x: pre_process_text(x,flg_stemm=False,flg_lemm=True,lst_stopwords=lst_stopwords))

# %% [markdown]
# ### Using TFIDF Vectorizer to vectorize the blog content

# %% [markdown]
# TF-IDF, short for Term Frequency-Inverse Document Frequency, is a widely used technique in natural language processing and information retrieval to quantify the importance of a term in a document within a collection of documents. TF-IDF combines two factors: term frequency (TF) and inverse document frequency (IDF).
#
# > * **Term Frequency (TF)**:
# TF measures the frequency of a term within a document. It calculates the number of times a term appears in a document and represents it as a raw count or a normalized value. The rationale behind TF is that terms that appear more frequently in a document are likely to be more important or relevant to that document.
#
# > * **Inverse Document Frequency (IDF)**:
# IDF measures the significance of a term in the entire collection of documents. It calculates the logarithm of the inverse fraction of the number of documents that contain the term. The idea behind IDF is that terms that occur in a small number of documents are more informative and valuable than those that appear in a large number of documents.
#
# The TF-IDF calculation is performed by multiplying the TF and IDF values together. The resulting score represents the importance of a term within a document in the context of the entire collection of documents. Higher scores indicate that a term is more relevant or distinctive to a specific document.
#
# The formula for calculating TF-IDF for a term (t) in a document (d) within a collection of documents is as follows:
#
# <img src="https://ptime.s3.ap-northeast-1.amazonaws.com/media/natural_language_processing/text_feature_Engineering/tf-idf-formula.PNG">

# %%
tfidf_vecotorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vecotorizer.fit_transform(blog_df['clean_blog_content'])
print(tfidf_matrix.shape)
# Out:
# (10466, 25157)

# %% [markdown]
# Hence, thier are 25157 unique words or vectors used to describe total 10467 blogs we have in our dataset

# %% [markdown]
# # Using Cosine Similarity for content based filtering

# %% [markdown]
# Cosine similarity is a measure used to determine the similarity between two vectors in a multi-dimensional space. It calculates the cosine of the angle between the vectors, which indicates how closely related the vectors are in terms of their orientation and direction.
#
# Here is the formula to calculate cosine similarity,
#
# <img src="https://clay-atlas.com/wp-content/uploads/2020/03/cosine-similarity.png">
#
# It will return how similar two vectors are based on the distance between them. This value ranges from 0 to 1 . Where 0 represents least similar and 1 the most similar content. It is very widely used and efficient method for building content based recommendation systems. Thats the only reason we are using it for building our blog recommendation system.

# %%
cosine_sim = cosine_similarity(tfidf_matrix)
print(cosine_sim)
# Out:
# [[1.         0.         0.         ... 0.02173711 0.         0.        ]
#  [0.         1.         0.         ... 0.00452585 0.00905365 0.00985712]
#  [0.         0.         1.         ... 0.         0.         0.        ]
#  ...
#  [0.02173711 0.00452585 0.         ... 1.         0.         0.        ]
#  [0.         0.00905365 0.         ... 0.         1.         0.03097127]
#  [0.         0.00985712 0.         ... 0.         0.03097127 1.        ]]

# %%
# Let us have the blogs rated by user with user id 12
user_rating = ratings_df[ratings_df['userId']==12]

# consider blogs with ratings greater than or equal to 3.5 just for simplification
blogs_to_consider = user_rating[user_rating['ratings']>=3.5]['blog_id']

# Now we need Id's of this blogs in form of a list
high_rated_blogs = blogs_to_consider.values

# %%
rated_blogs = blog_df[blog_df['blog_id'].isin(high_rated_blogs)]
rated_blogs
# Out:
#       blog_id                                         blog_title  \
# 198       217                          Stream Builder in Flutter
# 1301     1328              April 1st Recommendation on Alignment
# 1377     1404  How ServiceNow users can use AI and what AI se...
# 3375     3402  Realtime Object detection using TensorFlow in ...
# 3432     3459  2 ChatGPT (Free) Chrome Extensions so Useful T...
# 8696     8723                   Testing and Debugging in Flutter
# 8719     8746  Exploring Flutter Stream Builder: A Beginner’s...
# 8720     8747  Getting Started with Augmented Reality Mobile ...
# 8722     8749          Mastering Bloc with ‘GetCubit’ in Flutter
# 8730     8757  Flutter State Management: An In-Depth Explorat...
# 8733     8760  Why choose flutter for mobile development? Her...
# 8734     8761  Animating Like a Pro: A Step-by-Step Guide to ...
# 8739     8766  Real-time Weight data reading from a Bluetooth...
# 8759     8786  Apple Calendar’s events sync in the Flutter ap...
# 8764     8791  Flutter Portability: Making Apps Adaptable and...
# 8772     8799  Introduction to Dart Programming Language for ...
# 8774     8801                       Row Column Widget in Flutter
# 8776     8803  Testing your Flutter app? For smooth sailing, ...
# 8779     8806                 A month of Flutter — February 2023
# 8789     8816                   Dart (Flutter) constructor types
# 8792     8819  Discover How Flutter is Built with Dart Using ...
# 8794     8821  Diving into Flutter State Management: Riverpod...
# 8797     8824  Learn Appwrite x Flutter (Riverpod) Part 4: Au...
# 8798     8825          Networking and API integration in Flutter
# 8800     8827                  State Management types in Flutter
# 8831     8858  Using the Model-View-Controller (MVC) pattern ...
# 8834     8861  Example of a ChangeNotifier class that can be ...
# 8837     8864  Creating Beautiful UIs with Flutter Widgets: T...
# 8845     8872  Forms, user input widgets and validation techn...
# 8848     8875    Working Effectively with Legacy Code in Flutter
# 8869     8896                              Flutter E-commerce Ui
# 8905     8932                        Server Driven UI in Flutter
# 8919     8946                            Flutter | ChatGPT-Clone
# 8930     8957           Extensions In Flutter. with (CaseStudy).
# 8947     8974             Protect your Flutter app with freeRASP
# 8964     8991         Implementing Firebase Email Authentication
# 8968     8995        A beginner’s guide to animations in Flutter
# 8970     8997               Deep Dive into Lists in Dart|Flutter
# 8979     9006  Flutter into Faster Apps: Optimizing Performan...
# 8983     9010              How to disable screenshots on Flutter
# 8984     9011                                       What is MVVM
#
#                                            blog_content    topic  \
# 198   How to use StreamBuilder in Flutter? Flutter i...  flutter
# 1301  I want to make a basic assumption here, becaus...       ai
# 1377  ServiceNow is a cloud computing company that p...       ai
# 3375  Real-time object detection using TensorFlow ca...       ai
# 3432  Save hours on writing emails, googling, learni...       ai
# 8696  Testing in Flutter: Testing is crucial for any...  flutter
# 8719  Hello there, little friend! Do you want to lea...  flutter
# 8720  A Comprehensive Guide to Learning and Building...  flutter
# 8722  When you’re working with Flutter, you might wa...  flutter
# 8730  Learn how to efficiently manage state in your ...  flutter
# 8733  In 2017, Google unveiled Flutter, an open-sour...  flutter
# 8734  Flutter is a powerful mobile app development f...  flutter
# 8739  Add flutter_blue_plus as dependency Add to you...  flutter
# 8759  This article shows you how to fetch the apple ...  flutter
# 8764  How Flutter’s Cross-Platform Development Appro...  flutter
# 8772  Dart is a modern, object-oriented programming ...  flutter
# 8774  To start making Flutter UI, the use of Row and...  flutter
# 8776  Ensure that your app is reliable and user-frie...  flutter
# 8779  A selection of stories and libraries from last...  flutter
# 8789  In this article, I will discuss constructor ty...  flutter
# 8792  Building Better Mobile Apps with Flutter and S...  flutter
# 8794  In this series of short articles, I am showing...  flutter
# 8797  Hola Riverpod and Appwrite enthusiast! Welcome...  flutter
# 8798  Flutter is a popular cross-platform mobile dev...  flutter
# 8800  In Flutter, state management refers to the way...  flutter
# 8831  Introduction Flutter is a popular cross-platfo...  flutter
# 8834  First, let’s start by adding the http package ...  flutter
# 8837  Creating beautiful user interfaces is a critic...  flutter
# 8845  Forms and user input are crucial aspects of an...  flutter
# 8848  Working with legacy code can be challenging, e...  flutter
# 8869  with ecommerce_kit package Flutter Package to ...  flutter
# 8905  good News: mirai the new open-source project h...  flutter
# 8919  Flutter JarvisGPT Firstly, let’s talk about Ch...  flutter
# 8930  Extensions are a powerful feature in the Dart ...  flutter
# 8947  In today’s world of digitalisation, securing m...  flutter
# 8964  Welcome to the continuation of my blog on Flut...  flutter
# 8968  Overview —  Flutter animations come in two fla...  flutter
# 8970  Lists are an important data structure in progr...  flutter
# 8979  Flutter is a popular open-source framework tha...  flutter
# 8983  hello everyone today we will talk about how to...  flutter
# 8984  Model-View-ViewModel In Flutter —  Introductio...  flutter
#
#                                      clean_blog_content
# 198   use streambuilder flutter flutter popular open...
# 1301  want make basic assumption date youre truly ra...
# 1377  servicenow cloud computing company provides so...
# 3375  realtime object detection using tensorflow ach...
# 3432  save hour writing email googling learning unle...
# 8696  testing flutter testing crucial app developmen...
# 8719  hello little friend want learn something calle...
# 8720  comprehensive guide learning building immersiv...
# 8722  youre working flutter might want manage state ...
# 8730  learn efficiently manage state flutter applica...
# 8733  2017 google unveiled flutter opensource platfo...
# 8734  flutter powerful mobile app development framew...
# 8739  add flutter_blue_plus dependency add pubspecya...
# 8759  article show fetch apple calendar event flutte...
# 8764  flutter crossplatform development approach cha...
# 8772  dart modern objectoriented programming languag...
# 8774  start making flutter ui use row column useful ...
# 8776  ensure app reliable userfriendly testing artic...
# 8779  selection story library last month flutter dev...
# 8789  article discus constructor type dart programmi...
# 8792  building better mobile apps flutter solid prin...
# 8794  series short article showing journey diving wo...
# 8797  hola riverpod appwrite enthusiast welcome back...
# 8798  flutter popular crossplatform mobile developme...
# 8800  flutter state management refers way manage mai...
# 8831  introduction flutter popular crossplatform mob...
# 8834  first let start adding http package flutter pr...
# 8837  creating beautiful user interface critical par...
# 8845  form user input crucial aspect application inv...
# 8848  working legacy code challenging especially you...
# 8869  ecommerce_kit package flutter package create e...
# 8905  good news mirai new opensource project publish...
# 8919  flutter jarvisgpt firstly let talk chatgpt cha...
# 8930  extension powerful feature dart programming la...
# 8947  today world digitalisation securing mobile app...
# 8964  welcome continuation blog flutter firebase aut...
# 8968  overview flutter animation come two flavor imp...
# 8970  list important data structure programming allo...
# 8979  flutter popular opensource framework enables d...
# 8983  hello everyone today talk disable screenshots ...
# 8984  modelviewviewmodel flutter introduction mvvm s...

# %% [markdown]
# Let us create a function to recommended blogs based on the how similar blogs are.

# %%
def get_similar_blog(high_rated_blogs):
    """
        Args:
            high_rated_blogs : list of blog id's of the blogs rated by the user
        Returns:
            recommended_blogs : list of blog id's of the blogs that are to be recommended
    """

    recommended_blogs = []
    
    for blog_id in high_rated_blogs:
        
        # Find out the index value of particular blog
        temp_id = blog_df[blog_df['blog_id'] == blog_id].index.values[0]
        
        # Find out the index value of all the blogs which have similarity greater than 0.95
        temp_blog_id = blog_df[cosine_sim[temp_id] > 0.95]['blog_id'].index.values
        
        # Check whether the blog is already recommended or not and also verify that it is not seen by user previously
        for b_id in temp_blog_id:
            if b_id not in recommended_blogs and b_id not in high_rated_blogs:
                recommended_blogs.append(b_id)
                
    return recommended_blogs

# %% [markdown]
# # Generating Recommendation

# %%
recommended_blogs=get_similar_blog(high_rated_blogs)

# %%
blog_df.iloc[recommended_blogs]
# Out:
#       blog_id                                         blog_title  \
# 3377     3404  Here are the 3 ideas that you can use for Noti...
# 3434     3461  Reading Herculaneum Scrolls: $250,000 Challeng...
# 1379     1406  Unbabel — The AI-powered Translation Solution ...
# 1303     1330                   ChatGPT tweets, and it’s painful
# 8799     8826     10 Widgets Every Flutter Developer Must Master
# 8907     8934                        Data Persistence in Flutter
# 8698     8725  The Ultimate Flutter Navigator 2.0 series usin...
# 8871     8898             Google Pay: A success story of Flutter
# 8836     8863      Flutter vs React Native: Which One is Better?
# 200       219  Building beautiful product item widget in Flut...
# 8721     8748                           Layout Builder — Flutter
# 8794     8821  Diving into Flutter State Management: Riverpod...
# 8949     8976          Implementing the Network Layer in Flutter
# 8839     8866                 InheritedWidget — Flutter Advanced
# 8966     8993  Understanding Flutter LimitedBox: A Comprehens...
# 8778     8805  Diving into Flutter State Management: Riverpod...
# 8254     8281               Feature Flags inside our Android App
# 8932     8959  Learn Flutter as a beginner from scratch in 2023!
# 8776     8803  Testing your Flutter app? For smooth sailing, ...
# 8833     8860  Complete guide to implement Pushy push notific...
# 8796     8823  From API to UI: Simplifying data retrieval for...
# 8985     9012    Add Multiple Language With Easy_Localizations 🌍
# 8972     8999  Flutter for Beginners: A Comprehensive Introdu...
# 8741     8768  How to Get Started with Flutter Development: A...
# 8970     8997               Deep Dive into Lists in Dart|Flutter
# 8791     8818                The Magic of BuildContext | Flutter
# 8981     9008                               List Methods in Dart
# 8781     8808  Bootstrapping Riverpod The Expert Way In Flutt...
# 8847     8874        Firebase Cloud Messaging (FCM) with Flutter
# 8921     8948  CI/CD for a Flutter app with Github Actions: b...
# 8850     8877  Creating a method channel using the Complex An...
# 8732     8759     Flutter Widget Testing: Ensuring a Bug-free UI
# 8722     8749          Mastering Bloc with ‘GetCubit’ in Flutter
# 8766     8793  A Simple Guide to Teach Your Users How to Use ...
# 8735     8762  [SOLVED] Flutter pub get took long Time and fi...
# 8736     8763  AI-Powered Flutter Mobile App Development: Str...
# 8774     8801                       Row Column Widget in Flutter
# 8986     9013                    The LazyLoad | Flutter-Firebase
#
#                                            blog_content    topic  \
# 3377  Leverage Notion using AI. —  3 ideas for Notio...       ai
# 3434  Scientists have announced a contest with a pri...       ai
# 1379  In today’s global economy, language barriers c...       ai
# 1303  OpenAI’s ChaptGPT engine has taken the world b...       ai
# 8799  A Comprehensive Guide to Flutter Widgets for B...  flutter
# 8907  Data persistence is an essential aspect of any...  flutter
# 8698  In the first part, you learned about how you c...  flutter
# 8871  Google Pay is a popular digital wallet and onl...  flutter
# 8836  When it comes to mobile app development, there...  flutter
# 200   Product item widgets are a fundamental aspect ...  flutter
# 8721  Flutter is a popular cross-platform app develo...  flutter
# 8794  In this series of short articles, I am showing...  flutter
# 8949  One of the most critical aspects of any mobile...  flutter
# 8839  In this article, we will explore one of the ad...  flutter
# 8966  Flutter LimitedBox: A Comprehensive Guide Flut...  flutter
# 8778  In this series of short articles, I am showing...  flutter
# 8254  This article was originally written on 18th No...  android
# 8932  Here are two free courses that will help you s...  flutter
# 8776  Ensure that your app is reliable and user-frie...  flutter
# 8833  Register for Pushy Account and obtain API key ...  flutter
# 8796  Fetching and displaying the necessary data can...  flutter
# 8985  What is easy_localizations? Add to project Per...  flutter
# 8972  If you’re new to app development, you may have...  flutter
# 8741  Introduction: Flutter is a mobile app developm...  flutter
# 8970  Lists are an important data structure in progr...  flutter
# 8791  The BuildContext in Flutter can certainly be s...  flutter
# 8981  List Methods in Dart A List is an ordered coll...  flutter
# 8781  In the Provider and Riverpod world of widget s...  flutter
# 8847  Firebase Cloud Messaging (FCM) is a powerful t...  flutter
# 8921  Welcome to this CI/CD series! 👋 In this articl...  flutter
# 8850  There are SDKs available specifically for Andr...  flutter
# 8732  A Guide to Basic Testing and Stateful/Stateles...  flutter
# 8722  When you’re working with Flutter, you might wa...  flutter
# 8766  Here are some suggestions: 1.Onboarding Screen...  flutter
# 8735  The semaphore timeout period has expired. pub ...  flutter
# 8736  Artificial intelligence (AI) has become an int...  flutter
# 8774  To start making Flutter UI, the use of Row and...  flutter
# 8986  Build a LazyLoad feed with Firebase real data ...  flutter
#
#                                      clean_blog_content
# 3377  leverage notion using ai 3 idea notionaiwwwins...
# 3434  scientist announced contest prize quarter mill...
# 1379  today global economy language barrier major ob...
# 1303  openais chaptgpt engine taken world storm beco...
# 8799  comprehensive guide flutter widget building am...
# 8907  data persistence essential aspect mobile appli...
# 8698  first part learned set auto_route package flut...
# 8871  google pay popular digital wallet online payme...
# 8836  come mobile app development two major player m...
# 200   product item widget fundamental aspect ecommer...
# 8721  flutter popular crossplatform app development ...
# 8794  series short article showing journey diving wo...
# 8949  one critical aspect mobile application network...
# 8839  article explore one advanced topic flutter ie ...
# 8966  flutter limitedbox comprehensive guide flutter...
# 8778  series short article showing journey diving wo...
# 8254  article originally written 18th november 2021 ...
# 8932  two free course help start journey flutter dev...
# 8776  ensure app reliable userfriendly testing artic...
# 8833  register pushy account obtain api key go pushy...
# 8796  fetching displaying necessary data challenging...
# 8985  easy_localizations add project permission crea...
# 8972  youre new app development may heard flutter fl...
# 8741  introduction flutter mobile app development fr...
# 8970  list important data structure programming allo...
# 8791  buildcontext flutter certainly seen powerful t...
# 8981  list method dart list ordered collection objec...
# 8781  provider riverpod world widget service locatio...
# 8847  firebase cloud messaging fcm powerful tool sen...
# 8921  welcome cicd series article implement continuo...
# 8850  sdks available specifically android allow acce...
# 8732  guide basic testing statefulstateless widget t...
# 8722  youre working flutter might want manage state ...
# 8766  suggestion 1onboarding screen provides brief o...
# 8735  semaphore timeout period expired pub get faile...
# 8736  artificial intelligence ai become integral par...
# 8774  start making flutter ui use row column useful ...
# 8986  build lazyload feed firebase real data lazy lo...
