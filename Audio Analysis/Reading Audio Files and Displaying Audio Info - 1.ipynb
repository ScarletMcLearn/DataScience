# %%
from python_speech_features import mfcc
from python_speech_features import logfbank
import scipy.io.wavfile as wav
import matplotlib.pyplot as plt



# ffmpeg -i 03-01-01-01-01-01-01.wav -c:a pcm_s32le output.wav

#Read in the audio file
(rate,sig) = wav.read("/home/scarlet/Projects/Data Science/Resources/Audio/Raw Files/output.wav")

# Calculate the mfcc features based on the file data
mfcc_feat = mfcc(sig, rate, nfft=1200)

# Calculate the filterbank from the audio file
fbank_feat = logfbank(sig, rate, nfft=1200)

#Print the result
print(fbank_feat[1:3, :])

filterbank_features = fbank_feat.T
plt.matshow(filterbank_features)
plt.title('Filter bank')

plt.show()
# Out:
# [[-36.04365339 -36.04365339 -36.04365339 -36.04365339 -36.04365339
#   -36.04365339 -36.04365339 -36.04365339 -36.04365339 -36.04365339
#   -36.04365339 -36.04365339 -36.04365339 -36.04365339 -36.04365339
#   -36.04365339 -36.04365339 -36.04365339 -36.04365339 -36.04365339
#   -36.04365339 -36.04365339 -36.04365339 -36.04365339 -36.04365339
#   -36.04365339]
#  [  9.16534855   9.75164021  10.46405662  11.13664094  11.77578947
#    12.33560702  12.85497956  13.41560473  14.02042581  14.51032986
#    14.91193959  15.38393702  15.87136901  16.33096378  16.76264457
#    17.16682363  17.57220935  17.997942    18.39468895  18.78273322
#    19.15382248  19.52050208  19.85896534  20.16611623  20.4478733
#    20.67403449]]

# %%
# ffmpeg -i 03-01-01-01-01-01-01.wav -c:a pcm_f32le output2.wav


#Read in the audio file
(rate,sig) = wav.read("/home/scarlet/Projects/Data Science/Resources/Audio/Raw Files/output2.wav")

# Calculate the mfcc features based on the file data
mfcc_feat = mfcc(sig, rate, nfft=1200)

# Calculate the filterbank from the audio file
fbank_feat = logfbank(sig, rate, nfft=1200)

#Print the result
print(fbank_feat[1:3, :])

filterbank_features = fbank_feat.T
plt.matshow(filterbank_features)
plt.title('Filter bank')

plt.show()
# Out:
# [[-36.04365339 -36.04365339 -36.04365339 -36.04365339 -36.04365339
#   -36.04365339 -36.04365339 -36.04365339 -36.04365339 -36.04365339
#   -36.04365339 -36.04365339 -36.04365339 -36.04365339 -36.04365339
#   -36.04365339 -36.04365339 -36.04365339 -36.04365339 -36.04365339
#   -36.04365339 -36.04365339 -36.04365339 -36.04365339 -36.04365339
#   -36.04365339]
#  [-33.80977824 -33.22348605 -32.51106917 -31.83848459 -31.19933591
#   -30.63951828 -30.1201457  -29.55952049 -28.95469939 -28.46479533
#   -28.06318559 -27.59118816 -27.10375616 -26.64416139 -26.21248061
#   -25.80830154 -25.40291582 -24.97718317 -24.58043622 -24.19239194
#   -23.82130269 -23.45462309 -23.11615983 -22.80900894 -22.52725186
#   -22.30109068]]

# %%
# ffmpeg -i 03-01-01-01-01-01-01.wav -c:a pcm_s16le output3.wav


#Read in the audio file
(rate,sig) = wav.read("/home/scarlet/Projects/Data Science/Resources/Audio/Raw Files/output3.wav")

# Calculate the mfcc features based on the file data
mfcc_feat = mfcc(sig, rate, nfft=1200)

# Calculate the filterbank from the audio file
fbank_feat = logfbank(sig, rate, nfft=1200)

#Print the result
print(fbank_feat[1:3, :])

filterbank_features = fbank_feat.T
plt.matshow(filterbank_features)
plt.title('Filter bank')

plt.show()
# Out:
# [[-36.04365339 -36.04365339 -36.04365339 -36.04365339 -36.04365339
#   -36.04365339 -36.04365339 -36.04365339 -36.04365339 -36.04365339
#   -36.04365339 -36.04365339 -36.04365339 -36.04365339 -36.04365339
#   -36.04365339 -36.04365339 -36.04365339 -36.04365339 -36.04365339
#   -36.04365339 -36.04365339 -36.04365339 -36.04365339 -36.04365339
#   -36.04365339]
#  [-13.01536122 -12.42906957 -11.71665316 -11.04406884 -10.40492031
#    -9.84510276  -9.32573022  -8.76510505  -8.16028397  -7.67037992
#    -7.26877019  -6.79677276  -6.30934077  -5.849746    -5.41806521
#    -5.01388614  -4.60850042  -4.18276778  -3.78602083  -3.39797655
#    -3.0268873   -2.6602077   -2.32174444  -2.01459355  -1.73283648
#    -1.50667529]]

# %%
# ffmpeg -i 03-01-01-01-01-01-01.wav -c:a pcm_s16le output4.wav


#Read in the audio file
(rate,sig) = wav.read("/home/scarlet/Projects/Data Science/Resources/Audio/Raw Files/output4.wav")

# Calculate the mfcc features based on the file data
mfcc_feat = mfcc(sig, rate, nfft=1200)

# Calculate the filterbank from the audio file
fbank_feat = logfbank(sig, rate, nfft=1200)

#Print the result
print(fbank_feat[1:3, :])

filterbank_features = fbank_feat.T
plt.matshow(filterbank_features)
plt.title('Filter bank')

plt.show()
# Out:
# [[-36.04365339 -36.04365339 -36.04365339 -36.04365339 -36.04365339
#   -36.04365339 -36.04365339 -36.04365339 -36.04365339 -36.04365339
#   -36.04365339 -36.04365339 -36.04365339 -36.04365339 -36.04365339
#   -36.04365339 -36.04365339 -36.04365339 -36.04365339 -36.04365339
#   -36.04365339 -36.04365339 -36.04365339 -36.04365339 -36.04365339
#   -36.04365339]
#  [-13.01536122 -12.42906957 -11.71665316 -11.04406884 -10.40492031
#    -9.84510276  -9.32573022  -8.76510505  -8.16028397  -7.67037992
#    -7.26877019  -6.79677276  -6.30934077  -5.849746    -5.41806521
#    -5.01388614  -4.60850042  -4.18276778  -3.78602083  -3.39797655
#    -3.0268873   -2.6602077   -2.32174444  -2.01459355  -1.73283648
#    -1.50667529]]

# %%
#  ffmpeg -i 03-01-01-01-01-01-01.wav -c:a pcm_s32le output5.wav


#Read in the audio file
(rate,sig) = wav.read("/home/scarlet/Projects/Data Science/Resources/Audio/Raw Files/output5.wav")

# Calculate the mfcc features based on the file data
mfcc_feat = mfcc(sig, rate, nfft=1200)

# Calculate the filterbank from the audio file
fbank_feat = logfbank(sig, rate, nfft=1200)

#Print the result
print(fbank_feat[1:3, :])

filterbank_features = fbank_feat.T
plt.matshow(filterbank_features)
plt.title('Filter bank')

plt.show()
# Out:
# [[-36.04365339 -36.04365339 -36.04365339 -36.04365339 -36.04365339
#   -36.04365339 -36.04365339 -36.04365339 -36.04365339 -36.04365339
#   -36.04365339 -36.04365339 -36.04365339 -36.04365339 -36.04365339
#   -36.04365339 -36.04365339 -36.04365339 -36.04365339 -36.04365339
#   -36.04365339 -36.04365339 -36.04365339 -36.04365339 -36.04365339
#   -36.04365339]
#  [  9.16534855   9.75164021  10.46405662  11.13664094  11.77578947
#    12.33560702  12.85497956  13.41560473  14.02042581  14.51032986
#    14.91193959  15.38393702  15.87136901  16.33096378  16.76264457
#    17.16682363  17.57220935  17.997942    18.39468895  18.78273322
#    19.15382248  19.52050208  19.85896534  20.16611623  20.4478733
#    20.67403449]]

# %%
# WORKS
#  sox 03-01-01-01-01-01-01.wav -e signed-integer output7.wav


#Read in the audio file
(rate,sig) = wav.read("/home/scarlet/Projects/Data Science/Resources/Audio/Raw Files/output7.wav")

# Calculate the mfcc features based on the file data
mfcc_feat = mfcc(sig, rate, nfft=1200)

# Calculate the filterbank from the audio file
fbank_feat = logfbank(sig, rate, nfft=1200)

#Print the result
print(fbank_feat[1:3, :])

filterbank_features = fbank_feat.T
plt.matshow(filterbank_features)
plt.title('Filter bank')

plt.show()
# Out:
# [[-36.04365339 -36.04365339 -36.04365339 -36.04365339 -36.04365339
#   -36.04365339 -36.04365339 -36.04365339 -36.04365339 -36.04365339
#   -36.04365339 -36.04365339 -36.04365339 -36.04365339 -36.04365339
#   -36.04365339 -36.04365339 -36.04365339 -36.04365339 -36.04365339
#   -36.04365339 -36.04365339 -36.04365339 -36.04365339 -36.04365339
#   -36.04365339]
#  [-13.01536122 -12.42906957 -11.71665316 -11.04406884 -10.40492031
#    -9.84510276  -9.32573022  -8.76510505  -8.16028397  -7.67037992
#    -7.26877019  -6.79677276  -6.30934077  -5.849746    -5.41806521
#    -5.01388614  -4.60850042  -4.18276778  -3.78602083  -3.39797655
#    -3.0268873   -2.6602077   -2.32174444  -2.01459355  -1.73283648
#    -1.50667529]]

# %%
plt.matshow(mfcc_feat.T)
plt.title('MFCC Features')
plt.show()

# %%
logfbank_feat = logfbank(sig, rate, nfft=1200)
plt.matshow(logfbank_feat.T)
plt.title('Logfbank Features')
plt.show()

# %%
from python_speech_features import ssc
ssc_feat = ssc(sig, rate, nfft=1200)
plt.matshow(ssc_feat.T)
plt.title('ssc Features')
plt.show()

# %%
# s $ sox --i output7.wav

# Input File     : 'output7.wav'
# Channels       : 1
# Sample Rate    : 48000
# Precision      : 16-bit
# Duration       : 00:00:03.30 = 158558 samples ~ 247.747 CDDA sectors
# File Size      : 317k
# Bit Rate       : 768k
# Sample Encoding: 16-bit Signed Integer PCM

# %%
# ffmpeg -i output7.wav -hide_banner
# Guessed Channel Layout for  Input Stream #0.0 : mono
# Input #0, wav, from 'output7.wav':
#   Duration: 00:00:03.30, bitrate: 768 kb/s
#     Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, 1 channels, s16, 768 kb/s

# %%
# python_speech_features.base.mfcc(signal, samplerate=16000, winlen=0.025, winstep=0.01, numcep=13, nfilt=26, nfft=512, lowfreq=0, highfreq=None, preemph=0.97, ceplifter=22, appendEnergy=True, winfunc=<function <lambda>>)

# samplerate = sox --i output7.wav
