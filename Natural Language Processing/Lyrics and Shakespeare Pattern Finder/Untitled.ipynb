# %%
import pickle

# %%
with open('lp_lyrics_list.pkl', 'rb') as f:
    linkin_park = pickle.load(f)

# %%
len(linkin_park)
# Out:
# 17

# %%
from TextCleaner import *

import re
import string

from contractions import CONTRACTION_MAP

import nltk

from textstat.textstat import textstat

import obo

from textblob import TextBlob

import preprocessor as p

# %%
class TextCleaner:
    '''Cleans text for Analysis.'''
    
    def __init__(self):
        pass
    
    def remove_characters_before_tokenization(sentence,
         keep_apostrophes=False):
        
         '''
         remove_characters_before_tokenization('Test sentence 1 2 3 4 @')
         >>> Test sentence 1 2 3 4
         '''
        
         sentence = sentence.strip()
         if keep_apostrophes:
             PATTERN = r'[?|$|&|*|%|@|(|)|~]' # add other characters here to remove them
             filtered_sentence = re.sub(PATTERN, r'', sentence)
         else:
             PATTERN = r'[^a-zA-Z0-9 ]' # only extract alpha-numeric characters
             filtered_sentence = re.sub(PATTERN, r'', sentence)
         return filtered_sentence 
    
    def expand_contractions(sentence, contraction_mapping):
         '''
          expand_contractions("This is a test sentence. But this isn't one. hasn't she hearten?", CONTRACTION_MAP)
          >>> This is a test sentence. But this is not one. has not she hearten?
         '''
         contractions_pattern = re.compile('({})'.format('|'.join(contraction_mapping.keys())),
         flags=re.IGNORECASE|re.DOTALL)
            
         def expand_match(contraction):
             match = contraction.group(0)
             first_char = match[0]
             expanded_contraction = contraction_mapping.get(match)\
                 if contraction_mapping.get(match)\
                 else contraction_mapping.get(match.lower())
             expanded_contraction = first_char+expanded_contraction[1:]
             return expanded_contraction
         expanded_sentence = contractions_pattern.sub(expand_match, sentence)
         return expanded_sentence 
        
    def remove_stopwords(tokens):
         '''
        remove_stopwords(nltk.word_tokenize("This is a test sentence. But this isn't one. hasn't she hearten?".lower()))
        >>> ['test', 'sentence', '.', "n't", 'one', '.', "n't", 'hearten', '?']
         '''
         stopword_list = nltk.corpus.stopwords.words('english')
         filtered_tokens = [token for token in tokens if token not in stopword_list]
         return filtered_tokens 
        
    def stat_text_analysis(test_data):
        '''
        Returns list of statistical text test results.
        '''
        fre = textstat.flesch_reading_ease(test_data)
        si = textstat.smog_index(test_data)
        fkg = textstat.flesch_kincaid_grade(test_data)
        cli = textstat.coleman_liau_index(test_data)
        ari = textstat.automated_readability_index(test_data)
        dcri = textstat.dale_chall_readability_score(test_data)
        dw = textstat.difficult_words(test_data)
        lwf = textstat.linsear_write_formula(test_data)
        gf = textstat.gunning_fog(test_data)
        ts = textstat.text_standard(test_data)
        
        return ([
            ['fre', fre],
            ['si', si],
            ['fkg', fkg],
            ['cli', cli],
            ['ari', ari],
            ['dcri', dcri],
            ['dw', dw],
            ['lwf', lwf],
            ['gf', gf],
            ['ts', ts],            
                ])
    
    def word_freq_pair(wordstring):
        '''
        print((word_freq_pair('this is a test sentence is is is.')))
        [('this', 1), ('is', 3), ('a', 1), ('test', 1), ('sentence', 1), ('is', 3), ('is', 3), ('is.', 1)]
        '''
        wordlist = wordstring.split()

        wordfreq = []

        for w in wordlist:
            wordfreq.append(wordlist.count(w))

        return list(zip(wordlist, wordfreq))
    
    
    def removeStopwords(wordlist):
        '''
        removeStopwords("this is a test sentence.".split(" "))
        >>> ['test', 'sentence.']
        '''
        return [w for w in wordlist if w not in nltk.corpus.stopwords.words('english')]
    
    
    

    def nGramsToKWICDict(ngrams):
        '''
        ngrams = obo.getNGrams('this test sentence has eight words in it'.split(), 5)
        print(ngrams)
        >>> [['this', 'test', 'sentence', 'has', 'eight'],
             ['test', 'sentence', 'has', 'eight', 'words'],
             ['sentence', 'has', 'eight', 'words', 'in'],
             ['has', 'eight', 'words', 'in', 'it']]
        '''
        keyindex = len(ngrams[0]) // 2

        return keyindex
    
    
    def nGramsToKWICDict(ngrams):
        '''
        print(nGramsToKWICDict(
                             [['this', 'test', 'sentence', 'has', 'eight'],
                             ['test', 'sentence', 'has', 'eight', 'words'],
                             ['sentence', 'has', 'eight', 'words', 'in'],
                             ['has', 'eight', 'words', 'in', 'it']]
                             ))
                             
        >>> {'words': [['has', 'eight', 'words', 'in', 'it']], 
            'sentence': [['this', 'test', 'sentence', 'has', 'eight']], 
            'has': [['test', 'sentence', 'has', 'eight', 'words']], 
            'eight': [['sentence', 'has', 'eight', 'words', 'in']]}
        
        '''
        keyindex = len(ngrams[0]) // 2

        kwicdict = {}

        for k in ngrams:
            if k[keyindex] not in kwicdict:
                kwicdict[k[keyindex]] = [k]
            else:
                kwicdict[k[keyindex]].append(k)
        return kwicdict
    
    def get_n_grams(allMyWords, n):
        return obo.getNGrams(allMyWords, n)
    
    def getNGrams(wordlist, n):
        '''
        tNGrams(test2.split(), 5)
        # -> [['this', 'test', 'sentence', 'has', 'eight'],
        # ['test', 'sentence', 'has', 'eight', 'words'],
        # ['sentence', 'has', 'eight', 'words', 'in'],
        # ['has', 'eight', 'words', 'in', 'it']]
        '''
        ngrams = []
        for i in range(len(wordlist)-(n-1)):
            ngrams.append(wordlist[i:i+n])
        return ngrams
    
    
    
    def clean_tweet(tweet):
        '''
        Utility function to clean the text in a tweet by removing 
        links and special characters using regex.
        '''
        return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

    def analize_sentiment(tweet):
        '''
        Utility function to classify the polarity of a tweet
        using textblob.
        '''
        analysis = TextBlob(clean_tweet(tweet))
        if analysis.sentiment.polarity > 0:
            return 1
        elif analysis.sentiment.polarity == 0:
            return 0
        else:
            return -1
        
    def cln_twt(twt):
        return p.clean(twt)
    
    def tkn_twt(twt):
        return p.tokenize(twt)
    
    def prs_twt(twt):
        return p.parse(twt)

# %%
cleaned_lyrics = [['Text', 'Expanded', 'Cleaned']]

for _3 in range(len(linkin_park)):
    print("New Song")

    for _ in linkin_park[_3][1].split('\n'):
        print(TextCleaner.remove_stopwords(nltk.word_tokenize(TextCleaner.expand_contractions(_, CONTRACTION_MAP))))
        _text = _.lower()
        clnd_txt = TextCleaner.remove_stopwords(nltk.word_tokenize(TextCleaner.expand_contractions(_text, CONTRACTION_MAP)))
        expnded_txt = nltk.word_tokenize(TextCleaner.expand_contractions(_text, CONTRACTION_MAP))
        cleaned_lyrics.append([_text, expnded_txt, clnd_txt])
    #     _))
# Out:
# New Song
# []
# ['I', 'tired', 'want']
# ['Feeling', 'faithless', ',', 'lost', 'surface']
# ['I', 'know', 'expecting']
# ['Put', 'pressure', 'walking', 'shoes']
# ['Caught', 'undertow', ',', 'caught', 'undertow']
# ['Every', 'step', 'I', 'take', 'another', 'mistake']
# ['Caught', 'undertow', ',', 'caught', 'undertow']
# ['I', 'become', 'numb', ',', 'I', 'feel']
# ['Become', 'tired', ',', 'much', 'aware']
# ['By', 'becoming', 'I', 'want']
# ['Is', 'like', 'less', 'like']
# ['Can', 'see', 'smothering', '?']
# ['Holding', 'tightly', ',', 'afraid', 'lose', 'control']
# ["'ecause", 'everything', 'thought', 'I', 'would']
# ['Has', 'fallen', 'apart', 'right', 'front']
# ['Caught', 'undertow', ',', 'caught', 'undertow']
# ['Every', 'step', 'I', 'take', 'another', 'mistake']
# ['Caught', 'undertow', ',', 'caught', 'undertow']
# ['And', 'every', 'second', 'I', 'waste', 'I', 'take', '!']
# ['I', 'become', 'numb', ',', 'I', 'feel']
# ['Become', 'tired', ',', 'much', 'aware']
# ['By', 'becoming', 'I', 'want']
# ['Is', 'like', 'less', 'like']
# ['And', 'I', 'know', 'I', 'may', 'end', 'failing']
# ['But', 'I', 'know', 'like', 'someone', 'disappointed']
# ['I', 'become', 'numb', ',', 'I', 'feel']
# ['Become', 'tired', ',', 'much', 'aware']
# ['By', 'becoming', 'I', 'want']
# ['Is', 'like', 'less', 'like']
# ['I', 'become', 'numb', ',', 'I', 'feel']
# ['I', 'tired', 'want']
# ['I', 'become', 'numb', ',', 'I', 'feel']
# ['I', 'tired', 'want']
# []
# New Song
# []
# ['It', 'starts', 'one', 'thing']
# ['I', 'know']
# ['It', 'even', 'matter', 'hard', 'try']
# ['Keep', 'mind']
# ['I', 'designed', 'rhyme']
# ['To', 'explain', 'due', 'time']
# ['All', 'I', 'know']
# ['Time', 'valuable', 'thing']
# ['Watch', 'fly', 'pendulum', 'swings']
# ['Watch', 'count', 'end', 'day']
# ['The', 'clock', 'ticks', 'life', 'away']
# ['It', 'unreal']
# ['Did', 'look']
# ['Watch', 'time', 'go', 'right', 'window']
# ['Trying', 'hold', ',', 'even', 'know']
# ['Wasted', 'watch', 'go']
# ['I', 'kept', 'everything', 'inside']
# ['And', 'even', 'though', 'I', 'tried', ',', 'fell', 'apart']
# ['What', 'meant']
# ['Will', 'eventually', 'memory', 'time']
# ['I', 'tried', 'hard']
# ['And', 'got', 'far']
# ['But', 'end']
# ['It', 'even', 'matter']
# ['I', 'fall']
# ['To', 'lose']
# ['But', 'end']
# ['It', 'even', 'matter']
# ['One', 'thing', ',', 'I', 'know']
# ['It', 'even', 'matter', 'hard', 'try']
# ['Keep', 'mind']
# ['I', 'designed', 'rhyme']
# ['To', 'remind', 'time']
# ['I', 'tried', 'hard']
# ['In', 'spite', 'way', 'mocking']
# ['Acting', 'like', 'I', 'part', 'property']
# ['Remembering', 'times', 'fought']
# ['I', 'surprised', 'got']
# ['Things', 'way']
# ['You', 'would', 'even', 'recognize', 'anymore']
# ['Not', 'knew', 'back']
# ['But', 'comes', 'back', 'end']
# ['You', 'kept', 'everything', 'inside']
# ['And', 'even', 'though', 'I', 'tried', ',', 'fell', 'apart']
# ['What', 'meant', 'eventually', 'memory', 'time']
# ['I', 'tried', 'hard']
# ['And', 'got', 'far']
# ['But', 'end']
# ['It', 'even', 'matter']
# ['I', 'fall']
# ['To', 'lose']
# ['But', 'end']
# ['It', 'even', 'matter']
# ['I', 'put', 'trust']
# ['Pushed', 'far', 'I', 'go']
# ['For']
# ['There', 'one', 'thing', 'know']
# ['I', 'put', 'trust']
# ['Pushed', 'far', 'I', 'go']
# ['For']
# ['There', 'one', 'thing', 'know']
# ['I', 'tried', 'hard']
# ['And', 'got', 'far']
# ['But', 'end']
# ['It', 'even', 'matter']
# ['I', 'fall']
# ['To', 'lose']
# ['But', 'end']
# ['It', 'even', 'matter']
# []
# New Song
# []
# ['I', 'remember', 'black', 'skies']
# ['The', 'lightning', 'around']
# ['I', 'remember', 'flash']
# ['As', 'time', 'began', 'blur']
# ['Like', 'startling', 'sign']
# ['That', 'fate', 'finally', 'found']
# ['And', 'voice', 'I', 'heard']
# ['That', 'I', 'get', 'I', 'deserve']
# ['So', 'give', 'reason']
# ['To', 'prove', 'wrong']
# ['To', 'wash', 'memory', 'clean']
# ['Let', 'floods', 'cross']
# ['The', 'distance', 'eyes']
# ['Give', 'reason']
# ['To', 'fill', 'hole']
# ['Connect', 'space']
# ['Let', 'enough', 'reach', 'truth', 'lies']
# ['Across', 'new', 'divide']
# ['There', 'nothing', 'inside']
# ['The', 'memories', 'left', 'abandoned']
# ['There', 'nowhere', 'hide']
# ['The', 'ashes', 'fell', 'like', 'snow']
# ['And', 'ground', 'caved']
# ['Between', 'standing']
# ['And', 'voice', 'I', 'heard']
# ['That', 'I', 'get', 'I', 'deserve']
# ['So', 'give', 'reason']
# ['To', 'prove', 'wrong']
# ['To', 'wash', 'memory', 'clean']
# ['Let', 'floods', 'cross']
# ['The', 'distance', 'eyes']
# ['Across', 'new', 'divide']
# ['In', 'every', 'loss', 'every', 'lie']
# ['In', 'every', 'truth', 'deny']
# ['And', 'regret', 'goodbye']
# ['Was', 'mistake', 'great', 'hide']
# ['And', 'voice', 'I', 'heard']
# ['That', 'I', 'get', 'I', 'deserve']
# ['So', 'give', 'reason']
# ['To', 'prove', 'wrong']
# ['To', 'wash', 'memory', 'clean']
# ['Let', 'floods', 'cross']
# ['The', 'distance', 'eyes']
# ['Give', 'reason']
# ['To', 'fill', 'hole']
# ['Connect', 'space']
# ['Let', 'enough', 'reach', 'truth', 'lies']
# ['Across', 'new', 'divide']
# ['Across', 'new', 'divide']
# ['Across', 'new', 'divide']
# []
# New Song
# []
# ['Take', 'river', 'bend']
# ['Take', 'fighting', 'end']
# ['Wash', 'poison', 'skin']
# ['Show', 'whole']
# ['Fly', 'silver', 'wing']
# ['Past', 'black', 'sirens', 'sing']
# ['Warm', 'nova', "'s", 'glow']
# ['And', 'drop', 'dream']
# ["'ecause", 'I', 'crack', 'castle', 'glass']
# ['Hardly', 'anything', 'see']
# ['For', 'see']
# ['Bring', 'home', 'blinding', 'dream']
# ['Through', 'secrets', 'I', 'seen']
# ['Wash', 'sorrow', 'skin']
# ['Show', 'whole']
# ["'ecause", 'I', 'crack', 'castle', 'glass']
# ['Hardly', 'anything', 'see']
# ['For', 'see']
# ["'ecause", 'I', 'crack', 'castle', 'glass']
# ['Hardly', 'anything', 'else', 'I', 'need']
# ["'ecause", 'I', 'crack', 'castle', 'glass']
# ['Hardly', 'anything', 'see']
# ['For', 'see']
# ['For', 'see']
# []
# New Song
# []
# ['I', 'dreamed', 'I', 'missing']
# ['You', 'scared']
# ['But', 'one', 'would', 'listen']
# ['Cause', 'one', 'else', 'cared']
# ['After', 'dreaming']
# ['I', 'woke', 'fear']
# ['What', 'I', 'leaving']
# ['When', 'I', 'done', '?']
# ['So', ',', 'asking', ',', 'I', 'want', 'know']
# ['When', 'time', 'comes']
# ['Forget', 'wrong', 'I', 'done']
# ['Help', 'leave', 'behind', 'reasons', 'missed']
# ['And', 'resent']
# ['And', 'feeling', 'empty']
# ['Keep', 'memory']
# ['Leave', 'rest']
# ['Leave', 'rest']
# ['Do', 'afraid']
# ['I', 'taken', 'beating']
# ['I', 'shared', 'I', 'made']
# ['I', 'strong', 'surface']
# ['Not', 'way']
# ['I', 'never', 'perfect']
# ['But', 'neither']
# ['So', ',', 'asking', ',', 'I', 'want', 'know']
# ['When', 'time', 'comes']
# ['Forget', 'wrong', 'I', 'done']
# ['Help', 'leave', 'behind', 'reasons', 'missed']
# ['And', 'resent']
# ['And', 'feeling', 'empty']
# ['Keep', 'memory']
# ['Leave', 'rest']
# ['Leave', 'rest']
# ['Forgetting']
# ['All', 'hurt', 'inside', 'learned', 'hide', 'well']
# ['Pretending']
# ['Someone', 'else', 'come', 'save']
# ['I']
# ['When', 'time', 'comes']
# ['Forget', 'wrong', 'I', 'done']
# ['Help', 'leave', 'behind', 'reasons', 'missed']
# ['And', 'resent']
# ['And', 'feeling', 'empty']
# ['Keep', 'memory']
# ['Leave', 'rest']
# ['Leave', 'rest']
# ['Forgetting']
# ['All', 'hurt', 'inside', 'learned', 'hide', 'well']
# ['Pretending']
# ['Someone', 'else', 'come', 'save']
# ['I']
# ['I']
# []
# New Song
# []
# ['Telling', 'go']
# ['But', 'hands', 'beg', 'stay']
# ['Your', 'lips', 'say', 'love']
# ['Your', 'eyes', 'say', 'hate']
# ['There', 'truth', 'lies']
# ['Doubt', 'faith']
# ['What', 'build', 'lay', 'waste']
# ['There', 'truth', 'lies']
# ['Doubt', 'faith']
# ['All', 'I', 'got', "'s", 'take']
# ['So', 'I', ',', 'I', 'one']
# ['Be', 'one', 'leave']
# ['In', 'pieces']
# ['And', ',', 'alone']
# ['Alone', 'secrets']
# ['And', 'regrets']
# ['Do', 'lie']
# ['You', 'promise', 'sky']
# ['Then', 'toss', 'like', 'stone']
# ['You', 'wrap', 'arms']
# ['And', 'chill', 'bone']
# ['There', 'truth', 'lies']
# ['Doubt', 'faith']
# ['All', 'I', 'got', "'s", 'take']
# ['So', 'I', ',', 'I', 'one']
# ['Be', 'one', 'leave']
# ['In', 'pieces']
# ['And', ',', 'alone']
# ['Alone', 'secrets']
# ['And', 'regrets']
# ['Do', 'lie']
# ['So', 'I', ',', 'I', 'one']
# ['Be', 'one', 'leave']
# ['In', 'pieces']
# ['And', ',', 'alone']
# ['Alone', 'secrets']
# ['And', 'regrets']
# ['Do', 'lie']
# []
# New Song
# []
# ['I', 'like', 'mind', 'right']
# ['Stacking', 'problems', 'unnecessary']
# ['Wish', 'I', 'could', 'slow', 'things']
# ['I', 'wan', 'na', 'let', 'go', 'comfort', 'panic']
# ['And', 'I', 'drive', 'crazy']
# ['Thinking', 'everything', "'s"]
# ['Yeah', ',', 'I', 'drive', 'crazy']
# ["'ecause", 'I', '’', 'escape', 'gravity']
# ['I', 'holding']
# ['Why', 'everything', 'heavy', '?']
# ['Holding']
# ['So', 'much', 'I', 'carry']
# ['I', 'keep', 'dragging', 'around', 'bringing']
# ['If', 'I', 'let', 'go', ',', 'I', 'would', 'set', 'free']
# ['Holding']
# ['Why', 'everything', 'heavy', '?']
# ['You', 'say', 'I', 'paranoid']
# ['But', 'I', 'pretty', 'sure', 'world', 'get']
# ['It', 'like', 'I', 'make', 'choice']
# ['To', 'let', 'mind', 'stay', 'fucking', 'messy']
# ['I', 'know', 'I', 'center', 'universe']
# ['But', 'keep', 'spinning', "'round"]
# ['I', 'know', 'I', 'center', 'universe']
# ['But', 'keep', 'spinning', "'round"]
# ['I', 'holding']
# ['Why', 'everything', 'heavy', '?']
# ['Holding']
# ['So', 'much', 'I', 'carry']
# ['I', 'keep', 'dragging', 'around', 'bringing']
# ['If', 'I', 'let', 'go', ',', 'I', 'would', 'set', 'free']
# ['Holding']
# ['Why', 'everything', 'heavy', '?']
# ['I', 'know', 'I', 'center', 'universe']
# ['But', 'keep', 'spinning', "'round"]
# ['I', 'know', 'I', 'center', 'universe']
# ['But', 'keep', 'spinning', "'round"]
# ['And', 'I', 'drive', 'crazy']
# ['Thinking', 'everything', '’']
# ['Holding']
# ['Why', 'everything', 'heavy', '?']
# ['Holding']
# ['So', 'much', 'I', 'carry']
# ['I', 'keep', 'dragging', 'around', 'bringing']
# ['If', 'I', 'let', 'go', ',', 'I', 'would', 'set', 'free']
# ['Holding']
# ['Why', 'everything', 'heavy', '?']
# ['Why', 'everything', 'heavy', '?']
# ['Why', 'everything', 'heavy', '?']
# []
# New Song
# []
# ['Put', "'em", 'like']
# ['Let', 'see', "'em", ',', 'yeah']
# ['I', 'like']
# ['Yeah']
# ['This', 'end']
# ['This', 'beginning']
# ['Just', 'voice', 'like', 'riot']
# ['Rocking', 'every', 'revision']
# ['But', 'listen', 'tone']
# ['And', 'violent', 'rhythm']
# ['And', 'though', 'words', 'sound', 'steady']
# ['Something', 'empty', "'s", 'within', "'em"]
# ['We', 'say', ',', '``', 'yeah', "''"]
# ['Fists', 'flying', 'air']
# ['Like', 'holding', 'onto', 'something']
# ['That', 'invisible']
# ["'ecause", 'living', 'mercy']
# ['The', 'pain', 'fear']
# ['Until', 'tell', ',', 'forget']
# ['Let', 'disappear']
# ['Waiting', 'end', 'come']
# ['Wishing', 'I', 'strength', 'stand']
# ['This', 'I', 'planned']
# ['It', 'control']
# ['Flying', 'speed', 'light']
# ['Thoughts', 'spinning', 'head']
# ['So', 'many', 'things', 'left', 'unsaid']
# ['It', 'hard', 'let', 'go']
# ['I', 'know', 'takes', 'move']
# ['(', 'Oh', ')', 'I', 'know', 'feels', 'lie']
# ['(', 'Oh', ')', 'I', 'wan', 'na', 'trade', 'life', 'something', 'new']
# ['Holding', 'I', 'got']
# ['Sitting', 'empty', 'room']
# ['Trying', 'forget', 'past']
# ['This', 'never', 'meant', 'last']
# ['I', 'wish']
# ['I', 'know', 'takes', 'move']
# ['(', 'Oh', ')', 'I', 'know', 'feels', 'lie']
# ['(', 'Oh', ')', 'I', 'wan', 'na', 'trade', 'life', 'something', 'new']
# ['Holding', 'I', 'got']
# ['Yeah', ',', 'yeah']
# ['What', 'left', 'fire', 'gone', '?']
# ['I', 'thought', 'felt', 'right', 'right', 'wrong']
# ['All', 'caught', 'eye', 'storm']
# ['And', 'trying', 'figure', 'like', 'moving']
# ['And', 'I', 'even', 'know', 'kind', 'things', 'I', 'said']
# ['My', 'mouth', 'kept', 'moving', 'mind', 'went', 'dead']
# ['So', ',', 'picking', 'pieces', ',', 'begin', '?']
# ['The', 'hardest', 'part', 'ending', 'starting']
# ['All', 'I', 'wan', 'na', 'trade', 'life', 'something', 'new']
# ['Holding', 'I', 'got']
# ['This', 'end']
# ['This', 'beginning']
# ['Just', 'voice', 'like', 'riot']
# ['Rocking', 'every', 'revision']
# ['But', 'listen', 'tone', '(', 'holding', 'I', 'got', ')']
# ['And', 'violent', 'rhythm']
# ['Though', 'words', 'sound', 'steady']
# ['Something', 'empty', "'s", 'within', "'em"]
# ['We', 'say', ',', '``', 'yeah', "''"]
# ['With', 'fists', 'flying', 'air']
# ['Like', 'holding', 'onto', 'something']
# ['That', 'invisible']
# ["'ecause", 'living', 'mercy', '(', 'holding', 'I', 'got', ')']
# ['The', 'pain', 'fear']
# ['Until', 'get', ',', 'forget']
# ['Let', 'disappear']
# ['Thank']
# []
# New Song
# []
# ['Water', 'gray']
# ['Through', 'windows', ',', 'stairs']
# ['Chilling', 'rain']
# ['Like', 'ocean', 'everywhere']
# ['Do', 'wan', 'na', 'reach', ',', '?']
# ['I', 'mean', 'nothin', "'"]
# ['The', 'little', 'things', 'give', 'away']
# ['And', 'mistakin', "'"]
# ['The', 'levees', 'breakin', "'"]
# ['All', 'ever', 'wanted']
# ['Was', 'someone', 'truly', 'look']
# ['And', 'six', 'feet', 'water']
# ['I']
# ['Hope', 'decays']
# ['Generations', 'disappear']
# ['Washed', 'away']
# ['As', 'nation', 'simply', 'stares']
# ['Do', 'wan', 'na', 'reach']
# ['I', 'mean', 'nothin', "'"]
# ['The', 'little', 'things', 'give', 'away']
# ['But', 'mistakin', "'"]
# ['The', 'levees', 'breakin', "'"]
# ['All', 'ever', 'wanted']
# ['Was', 'someone', 'truly', 'look']
# ['And', 'six', 'feet', 'water']
# ['I']
# ['All', 'ever', 'wanted']
# ['Was', 'someone', 'truly', 'look']
# ['And', 'six', 'feet', 'ground']
# ['Now', 'I']
# ['Now', 'I']
# ['Little', 'things', 'give', 'away']
# ['Little', 'things', 'give', 'away']
# ['Little', 'things', 'give', 'away']
# ['Little', 'things', 'give', 'away']
# ['All', 'ever', 'wanted', '(', 'Little', 'things', 'give', 'away', ')']
# ['Was', 'someone', 'truly', 'look', '(', 'Little', 'things', 'give', 'away', ')']
# ['All', 'ever', 'wanted', '(', 'Little', 'things', 'give', 'away', ')']
# ['Was', 'someone', 'truly', 'look', '(', 'Little', 'things', 'give', 'away', ')']
# ['All', 'ever', 'wanted', '(', 'Little', 'things', 'give', 'away', ')']
# ['Was', 'someone', 'truly', 'look', '(', 'Little', 'things', 'give', 'away', ')']
# ['All', 'ever', 'wanted', '(', 'Little', 'things', 'give', 'away', ')']
# ['Was', 'someone', 'truly', 'look', '(', 'Little', 'things', 'give', 'away', ')']
# ['All', 'ever', 'wanted', '(', 'Little', 'things', 'give', 'away', ')']
# ['Was', 'someone', 'truly', 'look', '(', 'Little', 'things', 'give', 'away', ')']
# ['All', 'ever', 'wanted', '(', 'Little', 'things', 'give', 'away', ')']
# ['Was', 'someone', 'truly', 'look', '(', 'Little', 'things', 'give', 'away', ')']
# []
# New Song
# []
# ['Yeah', ',', 'go', 'hundredth', 'time']
# ['Hand', 'grenade', 'pins', 'every', 'line']
# ['Throw', "'em", 'let', 'something', 'shine']
# ['Going', 'fucking', 'mind']
# ['Filthy', 'mouth', ',', 'excuse']
# ['Find', 'new', 'place', 'hang', 'noose']
# ['String', 'atop', 'roofs']
# ['Knot', 'tight', 'I', 'get', 'loose']
# ['Truth', 'stop', 'stare']
# ['Bled', 'one', 'cares']
# ['Dug', 'trench', ',', 'laid']
# ['With', 'shovel', 'reach', 'somewhere']
# ['Yeah', ',', 'someone', 'pour']
# ['Make', 'dirt', 'dance', 'floor']
# ['Say', 'prayers', 'stomp']
# ['When', 'bring', 'chorus']
# ['I', 'bleed']
# ['Digging', 'deeper', 'throw', 'away']
# ['I', 'bleed']
# ['Digging', 'deeper', 'throw', 'away']
# ['I', 'bleed']
# ['Digging', 'deeper', 'throw', 'away']
# ['Just', 'throw', 'away']
# ['Just', 'throw', 'away']
# ['I', 'bleed']
# ['Go', ',', 'stop', 'show']
# ['Choppy', 'words', 'sloppy', 'flow']
# ['Shotgun', 'opera', ',', 'lock', 'load']
# ['Cock', 'back', 'watch', 'go']
# ['Mama', ',', 'help', ',', 'I', 'cursed']
# ['Death', 'rolling', 'every', 'verse']
# ['Candy', 'paint', 'brand', 'new', 'hearse']
# ['Can', 'contain', ';']
# ['He', 'knows', 'works']
# ['Fuck', 'hurts', ',', 'I', 'lie']
# ['Does', 'matter', 'hard', 'I', 'try']
# ['Half', 'words', 'mean', 'thing']
# ['And', 'I', 'know', 'I', 'satisfied']
# ['So', ',', 'try', 'ignoring', '?']
# ['Make', 'dirty', 'dance', 'floor']
# ['Say', 'prayers', 'stomp']
# ['When', 'bring', 'chorus']
# ['I', 'bleed']
# ['Digging', 'deeper', 'throw', 'away']
# ['I', 'bleed']
# ['Digging', 'deeper', 'throw', 'away']
# ['I', 'bleed']
# ['Digging', 'deeper', 'throw', 'away']
# ['Just', 'throw', 'away']
# ['Just', 'throw', 'away']
# ['I', 'bleed']
# ['I', 'opened', 'scars']
# ['I', 'make', 'face']
# ['I', 'pulled', 'far']
# ['I', 'make', 'face']
# ['I', 'bleed']
# ['Digging', 'deeper', 'throw', 'away']
# ['I', 'bleed']
# ['Digging', 'deeper', 'throw', 'away']
# ['I', 'bleed']
# ['Digging', 'deeper', 'throw', 'away']
# ['Just', 'throw', 'away']
# ['Just', 'throw', 'away']
# ['I', 'bleed']
# ['Digging', 'deeper', 'throw', 'away']
# ['I', 'bleed']
# ['Digging', 'deeper', 'throw', 'away']
# ['I', 'bleed']
# ['Digging', 'deeper', 'throw', 'away']
# ['Just', 'throw', 'away']
# ['Just', 'throw', 'away']
# ['I', 'bleed']
# ['I', 'bleed']
# ['I', 'bleed']
# []
# New Song
# []
# ['I', 'stuck', 'bed', 'made']
# ['Alone', 'sinking', 'feeling']
# ['I', 'saw', 'words', 'said']
# ['To', 'secrets', 'would', 'keeping']
# ['It', 'written', 'upon', 'face']
# ['All', 'lies', 'cut', 'deeply']
# ['You', 'get', 'enough', 'take', 'take', 'take', 'never', 'say']
# []
# ['No', ',', 'got', 'ta', 'get', 'inside']
# ['You', 'push', 'back']
# ['You', 'push', 'back']
# ['No', ',', 'never', 'get', 'inside']
# ['Push', 'back']
# ['Blackout']
# ['Blood', 'eye']
# []
# ['You', 'say', 'fault']
# ['And', 'swear', 'I', 'mistaken']
# ['You', 'said', 'seems']
# ['No', 'remorse', 'trust', 'breaking']
# ['You', 'run', 'back', 'fall']
# ['Suffocate', 'mess', 'making']
# ['You', 'get', 'enough', 'take', 'take', 'take', 'take']
# ['Fuck', ',', 'listening', '?']
# []
# ['No', ',', 'got', 'ta', 'get', 'inside']
# ['You', 'push', 'back']
# ['You', 'push', 'back']
# ['No', ',', 'never', 'get', 'inside']
# ['Push', 'back']
# ['You', 'push', 'back']
# ['No', ',', 'got', 'ta', 'get', 'inside']
# ['You', 'push', 'back']
# ['You', 'push', 'back']
# ['No', 'never', 'get', 'inside']
# ['Push', 'back']
# ['Blackout']
# ['Blood', 'eye']
# []
# ['Floating']
# ['As', 'colors', 'fill', 'light']
# ['We', 'look', 'ground']
# ['In', 'fields', 'paper-white']
# ['And', 'floating']
# ['You', 'passed', 'us', 'night']
# ['A', 'future', 'gazing']
# ['A', 'past', 'overwrite']
# ['So', 'come']
# ['Far']
# ['We', 'waiting', 'collect', 'things', 'know']
# ['Come']
# ['Far']
# ['We', 'waiting', 'collect', 'let', 'go']
# ['Come', ',', 'oh']
# ['Come', ',', 'oh']
# ['Come', ',', 'oh']
# ['Come', ',', 'oh']
# ['Come', ',', 'oh']
# []
# New Song
# []
# ['Yo', ',', 'yo']
# ['Forfeit', 'game', ',', 'somebody', 'takes', 'frame']
# ['Put', 'name', 'shame', ',', 'cover', 'face']
# ['You', 'run', 'race', ',', 'pace', 'fast', ',', 'last']
# ['Will', 'last', ',', 'last', ',', 'last', ',', 'last', ',']
# ['Will', 'last', ',', 'last', ',', 'last', ',', 'last', ',', 'last', ',', 'last', ',', 'last', ',']
# ['Will', 'last', ',', 'last']
# ['You', 'love', 'way', ',', 'I', 'look']
# ['While', 'taking', 'pleasure', 'awful', 'things', 'put']
# ['You', 'take', 'away', 'I', 'give']
# ['My', 'life', ',', 'pride', ',', 'broken']
# ['You', 'like', 'think', 'never', 'wrong']
# ['(', 'You', 'like', 'think', 'never', 'wrong', ')']
# ['You', 'act', 'like', 'someone']
# ['(', 'You', 'act', 'like', 'someone', ')']
# ['You', 'want', 'someone', 'hurt', 'like']
# ['(', 'You', 'want', 'someone', 'hurt', 'like', ')']
# ['You', 'want', 'share']
# ['(', 'You', 'live', 'learned', ')']
# ['Learned', ',', 'learned', ',', 'learned', ',', 'learned', ',', 'learned']
# ['You', 'love', 'things', ',', 'I', 'say', 'I']
# ['The', 'way', 'I', 'hurt', ',', 'get', 'back']
# ['You', 'take', 'away', ',', 'I', 'give']
# ['My', 'life', ',', 'pride', ',', 'broken']
# ['You', 'like', 'think', 'never', 'wrong']
# ['(', 'You', 'like', 'think', 'never', 'wrong', ')']
# ['You', 'act', 'like', 'someone']
# ['(', 'You', 'act', 'like', 'someone', ')']
# ['You', 'want', 'someone', 'hurt', 'like']
# ['(', 'You', 'want', 'someone', 'hurt', 'like', ')']
# ['You', 'wan', 'na', "'", 'share']
# ['(', 'You', 'live', 'learned', ')']
# ['Yo', ',', 'yo']
# ['Forfeit', 'game', ',', 'somebody', 'takes', 'frame']
# ['Put', 'name', 'shame', ',', 'cover', 'face']
# ['You', 'run', 'race', ',', 'pace', 'fast', ',', 'last']
# ['Forfeit', 'game', ',', 'somebody', 'takes', 'frame']
# ['Put', 'name', 'shame', ',', 'cover', 'face']
# ['You', 'run', 'race', ',', 'pace', 'fast', ',', 'last']
# ['Will', 'last', ',', 'last', ',', 'last', ',', 'last', ',', 'last', ',']
# ['Will', 'last', ',', 'last', ',', 'last', ',', 'last', ',', 'last', ',']
# ['Will', 'last', ',', 'last']
# ['You', 'like', 'think', 'never', 'wrong']
# ['(', 'You', 'like', 'think', 'never', 'wrong', ')']
# ['You', 'act', 'like', 'someone']
# ['(', 'You', 'act', 'like', 'someone', ')']
# ['You', 'want', 'someone', 'hurt', 'like']
# ['(', 'You', 'want', 'someone', 'hurt', 'like', ')']
# ['You', 'want', 'share']
# ['You', 'like', 'think', 'never', 'wrong']
# ['(', 'You', 'like', 'think', 'never', 'wrong', ')']
# ['You', 'act', 'like', 'someone']
# ['(', 'You', 'act', 'like', 'someone', ')']
# ['You', 'want', 'someone', 'hurt', 'like']
# ['(', 'You', 'want', 'someone', 'hurt', 'like', ')']
# ['You', 'want', 'share']
# ['(', 'You', 'live', 'learned', ')']
# ['Oh', ',', 'oh']
# []
# New Song
# []
# ['Memories', 'consume', 'like', 'opening', 'wound']
# ['I', 'picking', 'apart']
# ['You', 'assume']
# ['I', 'safe', 'room']
# ['Unless', 'I', 'try', 'start']
# ['I', 'want', 'one', 'battles', 'always', 'choose']
# ["'ecause", 'inside', 'I', 'realize', 'I', 'one', 'confused']
# ['I', 'know', 'worth', 'fighting']
# ['Or', 'I', 'scream']
# ['I', 'know', 'I', 'instigate']
# ['And', 'say', 'I', 'mean']
# ['I', 'know', 'I', 'got', 'way']
# ['I', 'know', 'alright']
# ['So', 'I', 'breaking', 'habit']
# ['I', 'breaking', 'habit', 'tonight']
# ['Clutching', 'cure']
# ['I', 'tightly', 'lock', 'door']
# ['I', 'try', 'catch', 'breath']
# ['I', 'hurt', 'much', 'time']
# ['I', 'options', 'left']
# ['I', 'want', 'one', 'battles', 'always', 'choose']
# ["'ecause", 'inside', 'I', 'realize', 'I', 'one', 'confused']
# ['I', 'know', 'worth', 'fighting']
# ['Or', 'I', 'scream']
# ['I', 'know', 'I', 'instigate']
# ['And', 'say', 'I', 'mean']
# ['I', 'know', 'I', 'got', 'way']
# ['I', 'never', 'alright']
# ['So', 'I', 'breaking', 'habit']
# ['I', 'breaking', 'habit', 'tonight']
# ['I', 'paint', 'walls']
# ["'ecause", 'I', 'one', 'fault']
# ['I', 'never', 'fight']
# ['And', 'ends']
# ['I', 'know', 'worth', 'fighting']
# ['Or', 'I', 'scream']
# ['But', 'I', 'clarity', 'show', 'I', 'mean']
# ['I', 'know', 'I', 'got', 'way']
# ['I', 'never', 'alright']
# ['So', 'I', 'breaking', 'habit']
# ['I', 'breaking', 'habit']
# ['I', 'breaking', 'habit', 'tonight']
# ['I', 'know', 'worth', 'fighting']
# ['Or', 'I', 'scream']
# ['I', 'know', 'I', 'instigate']
# ['And', 'say', 'I', 'mean']
# ['I', 'know', 'I', 'got', 'way']
# ['I', 'never', 'alright']
# ['So', 'I', 'breaking', 'habit']
# ['I', 'breaking', 'habit', 'tonight']
# ['I', 'breaking', 'habit', '(', 'tonight', ')']
# []
# New Song
# []
# ['God', 'bless', 'us', 'every', 'one']
# ['We', 'broken', 'people', 'living', 'loaded', 'gun']
# ['And', 'outfought']
# ['It', 'outdone']
# ['It', 'outmatched']
# ['It', 'outrun']
# ['No', '!']
# ['Repeat', 'x2']
# []
# ['And', 'I', 'close', 'eyes', 'tonight']
# ['To', 'symphonies', 'blinding', 'light']
# ['God', 'bless', 'us', 'everyone']
# ['We', 'broken', 'people', 'living', 'loaded', 'gun']
# ['Ooh', '!']
# ['Like', 'memories', 'cold', 'decay']
# ['Transmissions', 'echoing', 'away']
# ['Far', 'world', 'I']
# ['Where', 'oceans', 'bleed', 'sky']
# []
# ['God', 'save', 'us', 'every', 'one']
# ['Will', 'burn', 'inside', 'fires', 'thousand', 'suns']
# ['For', 'sins', 'hands']
# ['The', 'sins', 'tongues']
# ['The', 'sins', 'fathers']
# ['The', 'sins', 'young']
# ['No', '!']
# ['Repeat', '2x']
# []
# ['And', 'I', 'close', 'eyes', 'tonight']
# ['To', 'symphonies', 'blinding', 'light']
# ['God', 'save', 'us', 'everyone']
# ['Will', 'burn', 'inside', 'fires', 'thousand', 'suns']
# ['Ooh', '!']
# ['Like', 'memories', 'cold', 'decay']
# ['Transmissions', 'echoing', 'away']
# ['Far', 'world', 'I']
# ['Where', 'oceans', 'bleed', 'sky']
# []
# ['Ooh', '!']
# ['Like', 'memories', 'cold', 'decay']
# ['Transmissions', 'echoing', 'away']
# ['Far', 'world', 'I']
# ['Where', 'oceans', 'bleed', 'sky']
# []
# ['Lift', ',', 'let', 'go']
# ['Repeat', '5x', '(', '10x', ')']
# []
# ['God', 'bless', 'us', 'every', 'one']
# ['We', 'broken', 'people', 'living', 'loaded', 'gun']
# ['And', 'outfought']
# ['It', 'outdone']
# ['It', 'outmatched']
# ['It', 'outrun']
# ['Repeat', '3x']
# New Song
# []
# ['I', 'take', 'anymore']
# ['I', 'saying', 'everything', 'I', 'said']
# ['All', 'words', 'make', 'sense']
# ['I', 'find', 'bliss', 'ignorance']
# ['Less', 'I', 'hear', 'less', 'say']
# ['But', 'find', 'anyway']
# ['Just', 'like']
# ['Everything', 'say']
# ['Takes', 'one', 'step', 'closer', 'edge']
# ['And', 'I', 'break']
# ['I', 'need', 'little', 'room', 'breathe']
# ["'ecause", 'I', 'one', 'step', 'closer', 'edge']
# ['And', 'I', 'break']
# ['I', 'find', 'answers', 'clear']
# ['Wish', 'I', 'could', 'find', 'way', 'disappear']
# ['All', 'thoughts', 'make', 'sense']
# ['I', 'find', 'bliss', 'ignorance']
# ['Nothing', 'seems', 'go', 'away']
# ['Over']
# ['Just', 'like']
# ['Everything', 'say']
# ['Takes', 'one', 'step', 'closer', 'edge']
# ['And', 'I', 'break']
# ['I', 'need', 'little', 'room', 'breathe']
# ["'ecause", 'I', 'one', 'step', 'closer', 'edge']
# ['And', 'I', 'break']
# ['Everything', 'say']
# ['Takes', 'one', 'step', 'closer', 'edge']
# ['And', 'I', 'break']
# ['I', 'need', 'little', 'room', 'breathe']
# ["'ecause", 'I', 'one', 'step', 'closer', 'edge']
# ['And', 'I', ',', 'break']
# ['Shut', 'I', 'talking']
# ['Shut', ',', 'shut', ',', 'shut']
# ['Shut', 'I', 'talking']
# ['Shut', ',', 'shut', ',', 'shut']
# ['Shut', ',', 'I', 'break', '!']
# ['Everything', 'say']
# ['Takes', 'one', 'step', 'closer', 'edge']
# ['And', 'I', 'break']
# ['I', 'need', 'little', 'room', 'breathe']
# ["'ecause", 'I', 'one', 'step', 'closer', 'edge']
# ['And', 'I', 'break']
# ['Everything', 'say']
# ['Takes', 'one', 'step', 'closer', 'edge']
# ['And', 'I', 'break']
# ['I', 'need', 'little', 'room', 'breathe']
# ["'ecause", 'I', 'one', 'step', 'closer', 'edge']
# ['And', 'I', ',', 'brea']
# []
# New Song
# ['I', 'close', 'locks', 'window']
# ['I', 'close', 'blinds', 'turn', 'away']
# ['Sometimes', 'solutions', 'simple']
# ['Sometimes', 'goodbye', "'s", 'way', ',', 'oh']
# ['And', 'sun', 'set']
# ['The', 'sun', 'set']
# ['And', 'shadow', 'day']
# ['Will', 'embrace', 'world', 'gray']
# ['And', 'sun', 'set']
# ['In', 'cards', 'flowers', 'window']
# ['Your', 'friends', 'plead', 'stay']
# ['Sometimes', 'beginnings', 'simple']
# ['Sometimes', 'goodbye', "'s", 'way', ',', 'oh']
# ['And', 'sun', 'set']
# ['The', 'sun', 'set']
# ['And', 'shadow', 'day']
# ['Will', 'embrace', 'world', 'gray']
# ['And', 'sun', 'set']
# ['And', 'shadow', 'day']
# ['Will', 'embrace', 'world', 'gray']
# ['And', 'sun', 'set']
# ['And', 'shadow', 'day']
# ['Will', 'embrace', 'world', 'gray']
# ['And', 'sun', 'set']
# []
# New Song
# []
# ['I', 'little', 'bit', 'loneliness', ',', 'little', 'bit', 'disregard']
# ['Handful', 'complaints', 'I', 'help', 'fact']
# ['That', 'everyone', 'see', 'scars']
# ['I', 'I', 'want', 'want', ',', 'I', 'want', 'feel']
# ['But', 'like', 'matter', 'I', ',', 'I', 'convince']
# ['To', 'believe', 'real']
# ['So', 'I', ',', 'let', 'go', 'watching', 'turn', 'back', 'like', 'always']
# ['Face', 'away', 'pretend', 'I']
# ['But', 'I', "'ecause", 'I', 'got']
# ['I', 'feel', 'way', 'I']
# ['Do', 'turn', 'back']
# ['I', 'ignored']
# ['Time', 'heal', 'damage', 'anymore']
# ['Do', 'turn', 'back', 'I', 'ignored']
# ['I', ',', 'little', 'bit', 'insecure', ',', 'little', 'unconfident']
# ["'ecause", 'understand', 'I', 'I']
# ['But', 'sometimes', 'I', 'make', 'sense']
# ['I', ',', 'never', 'want', 'say', ',', 'I', 'never', 'doubt']
# ['It', 'like', 'matter', 'I', 'I', 'convince', 'hear']
# ['So', 'I', ',', 'let', 'go', 'watching', 'turn', 'back', 'like', 'always']
# ['You', 'face', 'away', 'pretend', 'I']
# ['But', 'I', "'ecause", 'I', 'got']
# ['I', 'feel', 'way', 'I']
# ['Do', 'turn', 'back']
# ['I', 'ignored']
# ['Time', 'heal', 'damage', 'anymore']
# ['Do', 'turn', 'back', 'I', 'ignored']
# ['You', 'hear']
# ['You', 'gon', 'na', 'listen', 'like']
# ['Right', ',', 'hear']
# ['You', 'gon', 'na', 'listen', 'like']
# ['Right']
# ['I', 'feel', 'way', 'I']
# ['Do', 'turn', 'back']
# ['I', 'ignored']
# ['Time', 'heal', 'damage', 'anymore']
# ['Do', 'turn', 'back', 'I', 'ignored']
# ['I', 'feel']
# ['Do', 'turn', 'back']
# ['I', 'ignored']
# ['Time', 'heal']
# ['Do', 'turn', 'back', 'I', 'ignored']

# %%
cleaned_lyrics[1]
# Out:
# ['', [], []]

# %%
import nltk

pos_tag_res = ['Tagged Entries']

for _ in range(1, len(cleaned_lyrics)):
    text = nltk.pos_tag(cleaned_lyrics[_][1])
#     print(cleaned_lyrics[_][1])
    pos_tag_res.append([' '.join(cleaned_lyrics[_][1]), text])

# %%
pos_tag_res
# Out:
# ['Tagged Entries',
#  ['', []],
#  ['i am tired of being what you want me to be',
#   [('i', 'NN'),
#    ('am', 'VBP'),
#    ('tired', 'VBN'),
#    ('of', 'IN'),
#    ('being', 'VBG'),
#    ('what', 'WP'),
#    ('you', 'PRP'),
#    ('want', 'VBP'),
#    ('me', 'PRP'),
#    ('to', 'TO'),
#    ('be', 'VB')]],
#  ['feeling so faithless , lost under the surface',
#   [('feeling', 'VBG'),
#    ('so', 'RB'),
#    ('faithless', 'RB'),
#    (',', ','),
#    ('lost', 'VBN'),
#    ('under', 'IN'),
#    ('the', 'DT'),
#    ('surface', 'NN')]],
#  ['i do not know what you are expecting of me',
#   [('i', 'NNS'),
#    ('do', 'VBP'),
#    ('not', 'RB'),
#    ('know', 'VB'),
#    ('what', 'WP'),
#    ('you', 'PRP'),
#    ('are', 'VBP'),
#    ('expecting', 'VBG'),
#    ('of', 'IN'),
#    ('me', 'PRP')]],
#  ['put under the pressure of walking in your shoes',
#   [('put', 'VBN'),
#    ('under', 'IN'),
#    ('the', 'DT'),
#    ('pressure', 'NN'),
#    ('of', 'IN'),
#    ('walking', 'VBG'),
#    ('in', 'IN'),
#    ('your', 'PRP$'),
#    ('shoes', 'NNS')]],
#  ['caught in the undertow , just caught in the undertow',
#   [('caught', 'NN'),
#    ('in', 'IN'),
#    ('the', 'DT'),
#    ('undertow', 'NN'),
#    (',', ','),
#    ('just', 'RB'),
#    ('caught', 'VBN'),
#    ('in', 'IN'),
#    ('the', 'DT'),
#    ('undertow', 'NN')]],
#  ['every step that i take is another mistake to you',
#   [('every', 'DT'),
#    ('step', 'NN'),
#    ('that', 'IN'),
#    ('i', 'JJ'),
#    ('take', 'VBP'),
#    ('is', 'VBZ'),
#    ('another', 'DT'),
#    ('mistake', 'NN'),
#    ('to', 'TO'),
#    ('you', 'PRP')]],
#  ['caught in the undertow , just caught in the undertow',
#   [('caught', 'NN'),
#    ('in', 'IN'),
#    ('the', 'DT'),
#    ('undertow', 'NN'),
#    (',', ','),
#    ('just', 'RB'),
#    ('caught', 'VBN'),
#    ('in', 'IN'),
#    ('the', 'DT'),
#    ('undertow', 'NN')]],
#  ['i have become so numb , i can not feel you there',
#   [('i', 'NN'),
#    ('have', 'VBP'),
#    ('become', 'VBN'),
#    ('so', 'RB'),
#    ('numb', 'JJ'),
#    (',', ','),
#    ('i', 'NNS'),
#    ('can', 'MD'),
#    ('not', 'RB'),
#    ('feel', 'VB'),
#    ('you', 'PRP'),
#    ('there', 'EX')]],
#  ['become so tired , so much more aware',
#   [('become', 'VBN'),
#    ('so', 'RB'),
#    ('tired', 'JJ'),
#    (',', ','),
#    ('so', 'RB'),
#    ('much', 'RB'),
#    ('more', 'JJR'),
#    ('aware', 'JJ')]],
#  ['by becoming this all i want to do',
#   [('by', 'IN'),
#    ('becoming', 'VBG'),
#    ('this', 'DT'),
#    ('all', 'DT'),
#    ('i', 'VBP'),
#    ('want', 'VBP'),
#    ('to', 'TO'),
#    ('do', 'VB')]],
#  ['is be more like me and be less like you',
#   [('is', 'VBZ'),
#    ('be', 'VB'),
#    ('more', 'RBR'),
#    ('like', 'IN'),
#    ('me', 'PRP'),
#    ('and', 'CC'),
#    ('be', 'VB'),
#    ('less', 'JJR'),
#    ('like', 'IN'),
#    ('you', 'PRP')]],
#  ['can not you see that you are smothering me ?',
#   [('can', 'MD'),
#    ('not', 'RB'),
#    ('you', 'PRP'),
#    ('see', 'VBP'),
#    ('that', 'IN'),
#    ('you', 'PRP'),
#    ('are', 'VBP'),
#    ('smothering', 'VBG'),
#    ('me', 'PRP'),
#    ('?', '.')]],
#  ['holding too tightly , afraid to lose control',
#   [('holding', 'VBG'),
#    ('too', 'RB'),
#    ('tightly', 'RB'),
#    (',', ','),
#    ('afraid', 'JJ'),
#    ('to', 'TO'),
#    ('lose', 'VB'),
#    ('control', 'NN')]],
#  ["'ecause everything that you thought i would be",
#   [("'ecause", 'IN'),
#    ('everything', 'NN'),
#    ('that', 'IN'),
#    ('you', 'PRP'),
#    ('thought', 'VBD'),
#    ('i', 'NNS'),
#    ('would', 'MD'),
#    ('be', 'VB')]],
#  ['has fallen apart right in front of you',
#   [('has', 'VBZ'),
#    ('fallen', 'VBN'),
#    ('apart', 'RB'),
#    ('right', 'JJ'),
#    ('in', 'IN'),
#    ('front', 'NN'),
#    ('of', 'IN'),
#    ('you', 'PRP')]],
#  ['caught in the undertow , just caught in the undertow',
#   [('caught', 'NN'),
#    ('in', 'IN'),
#    ('the', 'DT'),
#    ('undertow', 'NN'),
#    (',', ','),
#    ('just', 'RB'),
#    ('caught', 'VBN'),
#    ('in', 'IN'),
#    ('the', 'DT'),
#    ('undertow', 'NN')]],
#  ['every step that i take is another mistake to you',
#   [('every', 'DT'),
#    ('step', 'NN'),
#    ('that', 'IN'),
#    ('i', 'JJ'),
#    ('take', 'VBP'),
#    ('is', 'VBZ'),
#    ('another', 'DT'),
#    ('mistake', 'NN'),
#    ('to', 'TO'),
#    ('you', 'PRP')]],
#  ['caught in the undertow , just caught in the undertow',
#   [('caught', 'NN'),
#    ('in', 'IN'),
#    ('the', 'DT'),
#    ('undertow', 'NN'),
#    (',', ','),
#    ('just', 'RB'),
#    ('caught', 'VBN'),
#    ('in', 'IN'),
#    ('the', 'DT'),
#    ('undertow', 'NN')]],
#  ['and every second i waste is more than i can take !',
#   [('and', 'CC'),
#    ('every', 'DT'),
#    ('second', 'JJ'),
#    ('i', 'NN'),
#    ('waste', 'NN'),
#    ('is', 'VBZ'),
#    ('more', 'JJR'),
#    ('than', 'IN'),
#    ('i', 'NN'),
#    ('can', 'MD'),
#    ('take', 'VB'),
#    ('!', '.')]],
#  ['i have become so numb , i can not feel you there',
#   [('i', 'NN'),
#    ('have', 'VBP'),
#    ('become', 'VBN'),
#    ('so', 'RB'),
#    ('numb', 'JJ'),
#    (',', ','),
#    ('i', 'NNS'),
#    ('can', 'MD'),
#    ('not', 'RB'),
#    ('feel', 'VB'),
#    ('you', 'PRP'),
#    ('there', 'EX')]],
#  ['become so tired , so much more aware',
#   [('become', 'VBN'),
#    ('so', 'RB'),
#    ('tired', 'JJ'),
#    (',', ','),
#    ('so', 'RB'),
#    ('much', 'RB'),
#    ('more', 'JJR'),
#    ('aware', 'JJ')]],
#  ['by becoming this all i want to do',
#   [('by', 'IN'),
#    ('becoming', 'VBG'),
#    ('this', 'DT'),
#    ('all', 'DT'),
#    ('i', 'VBP'),
#    ('want', 'VBP'),
#    ('to', 'TO'),
#    ('do', 'VB')]],
#  ['is be more like me and be less like you',
#   [('is', 'VBZ'),
#    ('be', 'VB'),
#    ('more', 'RBR'),
#    ('like', 'IN'),
#    ('me', 'PRP'),
#    ('and', 'CC'),
#    ('be', 'VB'),
#    ('less', 'JJR'),
#    ('like', 'IN'),
#    ('you', 'PRP')]],
#  ['and i know i may end up failing too',
#   [('and', 'CC'),
#    ('i', 'NN'),
#    ('know', 'VBP'),
#    ('i', 'NN'),
#    ('may', 'MD'),
#    ('end', 'VB'),
#    ('up', 'RP'),
#    ('failing', 'VBG'),
#    ('too', 'RB')]],
#  ['but i know you were just like me with someone disappointed in you',
#   [('but', 'CC'),
#    ('i', 'NN'),
#    ('know', 'VBP'),
#    ('you', 'PRP'),
#    ('were', 'VBD'),
#    ('just', 'RB'),
#    ('like', 'IN'),
#    ('me', 'PRP'),
#    ('with', 'IN'),
#    ('someone', 'NN'),
#    ('disappointed', 'VBN'),
#    ('in', 'IN'),
#    ('you', 'PRP')]],
#  ['i have become so numb , i can not feel you there',
#   [('i', 'NN'),
#    ('have', 'VBP'),
#    ('become', 'VBN'),
#    ('so', 'RB'),
#    ('numb', 'JJ'),
#    (',', ','),
#    ('i', 'NNS'),
#    ('can', 'MD'),
#    ('not', 'RB'),
#    ('feel', 'VB'),
#    ('you', 'PRP'),
#    ('there', 'EX')]],
#  ['become so tired , so much more aware',
#   [('become', 'VBN'),
#    ('so', 'RB'),
#    ('tired', 'JJ'),
#    (',', ','),
#    ('so', 'RB'),
#    ('much', 'RB'),
#    ('more', 'JJR'),
#    ('aware', 'JJ')]],
#  ['by becoming this all i want to do',
#   [('by', 'IN'),
#    ('becoming', 'VBG'),
#    ('this', 'DT'),
#    ('all', 'DT'),
#    ('i', 'VBP'),
#    ('want', 'VBP'),
#    ('to', 'TO'),
#    ('do', 'VB')]],
#  ['is be more like me and be less like you',
#   [('is', 'VBZ'),
#    ('be', 'VB'),
#    ('more', 'RBR'),
#    ('like', 'IN'),
#    ('me', 'PRP'),
#    ('and', 'CC'),
#    ('be', 'VB'),
#    ('less', 'JJR'),
#    ('like', 'IN'),
#    ('you', 'PRP')]],
#  ['i have become so numb , i can not feel you there',
#   [('i', 'NN'),
#    ('have', 'VBP'),
#    ('become', 'VBN'),
#    ('so', 'RB'),
#    ('numb', 'JJ'),
#    (',', ','),
#    ('i', 'NNS'),
#    ('can', 'MD'),
#    ('not', 'RB'),
#    ('feel', 'VB'),
#    ('you', 'PRP'),
#    ('there', 'EX')]],
#  ['i am tired of being what you want me to be',
#   [('i', 'NN'),
#    ('am', 'VBP'),
#    ('tired', 'VBN'),
#    ('of', 'IN'),
#    ('being', 'VBG'),
#    ('what', 'WP'),
#    ('you', 'PRP'),
#    ('want', 'VBP'),
#    ('me', 'PRP'),
#    ('to', 'TO'),
#    ('be', 'VB')]],
#  ['i have become so numb , i can not feel you there',
#   [('i', 'NN'),
#    ('have', 'VBP'),
#    ('become', 'VBN'),
#    ('so', 'RB'),
#    ('numb', 'JJ'),
#    (',', ','),
#    ('i', 'NNS'),
#    ('can', 'MD'),
#    ('not', 'RB'),
#    ('feel', 'VB'),
#    ('you', 'PRP'),
#    ('there', 'EX')]],
#  ['i am tired of being what you want me to be',
#   [('i', 'NN'),
#    ('am', 'VBP'),
#    ('tired', 'VBN'),
#    ('of', 'IN'),
#    ('being', 'VBG'),
#    ('what', 'WP'),
#    ('you', 'PRP'),
#    ('want', 'VBP'),
#    ('me', 'PRP'),
#    ('to', 'TO'),
#    ('be', 'VB')]],
#  ['', []],
#  ['', []],
#  ['it starts with one thing',
#   [('it', 'PRP'),
#    ('starts', 'VBZ'),
#    ('with', 'IN'),
#    ('one', 'CD'),
#    ('thing', 'NN')]],
#  ['i do not know why',
#   [('i', 'NNS'),
#    ('do', 'VBP'),
#    ('not', 'RB'),
#    ('know', 'VB'),
#    ('why', 'WRB')]],
#  ['it does not even matter how hard you try',
#   [('it', 'PRP'),
#    ('does', 'VBZ'),
#    ('not', 'RB'),
#    ('even', 'RB'),
#    ('matter', 'VB'),
#    ('how', 'WRB'),
#    ('hard', 'JJ'),
#    ('you', 'PRP'),
#    ('try', 'VBP')]],
#  ['keep that in mind',
#   [('keep', 'VB'), ('that', 'DT'), ('in', 'IN'), ('mind', 'NN')]],
#  ['i designed this rhyme',
#   [('i', 'NN'), ('designed', 'VBN'), ('this', 'DT'), ('rhyme', 'NN')]],
#  ['to explain in due time',
#   [('to', 'TO'),
#    ('explain', 'VB'),
#    ('in', 'IN'),
#    ('due', 'JJ'),
#    ('time', 'NN')]],
#  ['all i know', [('all', 'DT'), ('i', 'NN'), ('know', 'VBP')]],
#  ['time is a valuable thing',
#   [('time', 'NN'),
#    ('is', 'VBZ'),
#    ('a', 'DT'),
#    ('valuable', 'JJ'),
#    ('thing', 'NN')]],
#  ['watch it fly by as the pendulum swings',
#   [('watch', 'NN'),
#    ('it', 'PRP'),
#    ('fly', 'VBZ'),
#    ('by', 'IN'),
#    ('as', 'IN'),
#    ('the', 'DT'),
#    ('pendulum', 'NN'),
#    ('swings', 'NNS')]],
#  ['watch it count down to the end of the day',
#   [('watch', 'NN'),
#    ('it', 'PRP'),
#    ('count', 'VBD'),
#    ('down', 'RB'),
#    ('to', 'TO'),
#    ('the', 'DT'),
#    ('end', 'NN'),
#    ('of', 'IN'),
#    ('the', 'DT'),
#    ('day', 'NN')]],
#  ['the clock ticks life away',
#   [('the', 'DT'),
#    ('clock', 'NN'),
#    ('ticks', 'NNS'),
#    ('life', 'NN'),
#    ('away', 'RB')]],
#  ['it is so unreal',
#   [('it', 'PRP'), ('is', 'VBZ'), ('so', 'RB'), ('unreal', 'JJ')]],
#  ['did not look out below',
#   [('did', 'VBD'),
#    ('not', 'RB'),
#    ('look', 'VB'),
#    ('out', 'RP'),
#    ('below', 'IN')]],
#  ['watch the time go right out the window',
#   [('watch', 'VB'),
#    ('the', 'DT'),
#    ('time', 'NN'),
#    ('go', 'VB'),
#    ('right', 'RB'),
#    ('out', 'RP'),
#    ('the', 'DT'),
#    ('window', 'NN')]],
#  ['trying to hold on , but you did not even know',
#   [('trying', 'VBG'),
#    ('to', 'TO'),
#    ('hold', 'VB'),
#    ('on', 'IN'),
#    (',', ','),
#    ('but', 'CC'),
#    ('you', 'PRP'),
#    ('did', 'VBD'),
#    ('not', 'RB'),
#    ('even', 'RB'),
#    ('know', 'VB')]],
#  ['wasted it all just to watch you go',
#   [('wasted', 'VBN'),
#    ('it', 'PRP'),
#    ('all', 'DT'),
#    ('just', 'RB'),
#    ('to', 'TO'),
#    ('watch', 'VB'),
#    ('you', 'PRP'),
#    ('go', 'VB')]],
#  ['i kept everything inside',
#   [('i', 'JJ'), ('kept', 'VBD'), ('everything', 'NN'), ('inside', 'NN')]],
#  ['and even though i tried , it all fell apart',
#   [('and', 'CC'),
#    ('even', 'RB'),
#    ('though', 'IN'),
#    ('i', 'JJ'),
#    ('tried', 'VBD'),
#    (',', ','),
#    ('it', 'PRP'),
#    ('all', 'DT'),
#    ('fell', 'VBD'),
#    ('apart', 'RP')]],
#  ['what it meant to me',
#   [('what', 'WP'),
#    ('it', 'PRP'),
#    ('meant', 'VBD'),
#    ('to', 'TO'),
#    ('me', 'PRP')]],
#  ['will eventually be a memory of a time when',
#   [('will', 'MD'),
#    ('eventually', 'RB'),
#    ('be', 'VB'),
#    ('a', 'DT'),
#    ('memory', 'NN'),
#    ('of', 'IN'),
#    ('a', 'DT'),
#    ('time', 'NN'),
#    ('when', 'WRB')]],
#  ['i tried so hard',
#   [('i', 'NN'), ('tried', 'VBD'), ('so', 'RB'), ('hard', 'JJ')]],
#  ['and got so far',
#   [('and', 'CC'), ('got', 'VBD'), ('so', 'RB'), ('far', 'RB')]],
#  ['but in the end',
#   [('but', 'CC'), ('in', 'IN'), ('the', 'DT'), ('end', 'NN')]],
#  ['it does not even matter',
#   [('it', 'PRP'),
#    ('does', 'VBZ'),
#    ('not', 'RB'),
#    ('even', 'RB'),
#    ('matter', 'RBR')]],
#  ['i had to fall',
#   [('i', 'NN'), ('had', 'VBD'), ('to', 'TO'), ('fall', 'VB')]],
#  ['to lose it all',
#   [('to', 'TO'), ('lose', 'VB'), ('it', 'PRP'), ('all', 'DT')]],
#  ['but in the end',
#   [('but', 'CC'), ('in', 'IN'), ('the', 'DT'), ('end', 'NN')]],
#  ['it does not even matter',
#   [('it', 'PRP'),
#    ('does', 'VBZ'),
#    ('not', 'RB'),
#    ('even', 'RB'),
#    ('matter', 'RBR')]],
#  ['one thing , i do not know why',
#   [('one', 'CD'),
#    ('thing', 'NN'),
#    (',', ','),
#    ('i', 'VB'),
#    ('do', 'VBP'),
#    ('not', 'RB'),
#    ('know', 'VB'),
#    ('why', 'WRB')]],
#  ['it does not even matter how hard you try',
#   [('it', 'PRP'),
#    ('does', 'VBZ'),
#    ('not', 'RB'),
#    ('even', 'RB'),
#    ('matter', 'VB'),
#    ('how', 'WRB'),
#    ('hard', 'JJ'),
#    ('you', 'PRP'),
#    ('try', 'VBP')]],
#  ['keep that in mind',
#   [('keep', 'VB'), ('that', 'DT'), ('in', 'IN'), ('mind', 'NN')]],
#  ['i designed this rhyme',
#   [('i', 'NN'), ('designed', 'VBN'), ('this', 'DT'), ('rhyme', 'NN')]],
#  ['to remind myself of a time when',
#   [('to', 'TO'),
#    ('remind', 'VB'),
#    ('myself', 'PRP'),
#    ('of', 'IN'),
#    ('a', 'DT'),
#    ('time', 'NN'),
#    ('when', 'WRB')]],
#  ['i tried so hard',
#   [('i', 'NN'), ('tried', 'VBD'), ('so', 'RB'), ('hard', 'JJ')]],
#  ['in spite of the way you were mocking me',
#   [('in', 'IN'),
#    ('spite', 'NN'),
#    ('of', 'IN'),
#    ('the', 'DT'),
#    ('way', 'NN'),
#    ('you', 'PRP'),
#    ('were', 'VBD'),
#    ('mocking', 'VBG'),
#    ('me', 'PRP')]],
#  ['acting like i was part of your property',
#   [('acting', 'VBG'),
#    ('like', 'IN'),
#    ('i', 'NN'),
#    ('was', 'VBD'),
#    ('part', 'NN'),
#    ('of', 'IN'),
#    ('your', 'PRP$'),
#    ('property', 'NN')]],
#  ['remembering all the times you fought with me',
#   [('remembering', 'VBG'),
#    ('all', 'PDT'),
#    ('the', 'DT'),
#    ('times', 'NNS'),
#    ('you', 'PRP'),
#    ('fought', 'VBP'),
#    ('with', 'IN'),
#    ('me', 'PRP')]],
#  ['i am surprised it got so',
#   [('i', 'NN'),
#    ('am', 'VBP'),
#    ('surprised', 'VBN'),
#    ('it', 'PRP'),
#    ('got', 'VBD'),
#    ('so', 'RB')]],
#  ['things are not the way they were before',
#   [('things', 'NNS'),
#    ('are', 'VBP'),
#    ('not', 'RB'),
#    ('the', 'DT'),
#    ('way', 'NN'),
#    ('they', 'PRP'),
#    ('were', 'VBD'),
#    ('before', 'IN')]],
#  ['you would not even recognize me anymore',
#   [('you', 'PRP'),
#    ('would', 'MD'),
#    ('not', 'RB'),
#    ('even', 'RB'),
#    ('recognize', 'VB'),
#    ('me', 'PRP'),
#    ('anymore', 'RB')]],
#  ['not that you knew me back then',
#   [('not', 'RB'),
#    ('that', 'IN'),
#    ('you', 'PRP'),
#    ('knew', 'VBD'),
#    ('me', 'PRP'),
#    ('back', 'RP'),
#    ('then', 'RB')]],
#  ['but it all comes back to me in the end',
#   [('but', 'CC'),
#    ('it', 'PRP'),
#    ('all', 'DT'),
#    ('comes', 'VBZ'),
#    ('back', 'RB'),
#    ('to', 'TO'),
#    ('me', 'PRP'),
#    ('in', 'IN'),
#    ('the', 'DT'),
#    ('end', 'NN')]],
#  ['you kept everything inside',
#   [('you', 'PRP'), ('kept', 'VBD'), ('everything', 'NN'), ('inside', 'NN')]],
#  ['and even though i tried , it all fell apart',
#   [('and', 'CC'),
#    ('even', 'RB'),
#    ('though', 'IN'),
#    ('i', 'JJ'),
#    ('tried', 'VBD'),
#    (',', ','),
#    ('it', 'PRP'),
#    ('all', 'DT'),
#    ('fell', 'VBD'),
#    ('apart', 'RP')]],
#  ['what it meant to me will eventually be a memory of a time when',
#   [('what', 'WP'),
#    ('it', 'PRP'),
#    ('meant', 'VBD'),
#    ('to', 'TO'),
#    ('me', 'PRP'),
#    ('will', 'MD'),
#    ('eventually', 'RB'),
#    ('be', 'VB'),
#    ('a', 'DT'),
#    ('memory', 'NN'),
#    ('of', 'IN'),
#    ('a', 'DT'),
#    ('time', 'NN'),
#    ('when', 'WRB')]],
#  ['i tried so hard',
#   [('i', 'NN'), ('tried', 'VBD'), ('so', 'RB'), ('hard', 'JJ')]],
#  ['and got so far',
#   [('and', 'CC'), ('got', 'VBD'), ('so', 'RB'), ('far', 'RB')]],
#  ['but in the end',
#   [('but', 'CC'), ('in', 'IN'), ('the', 'DT'), ('end', 'NN')]],
#  ['it does not even matter',
#   [('it', 'PRP'),
#    ('does', 'VBZ'),
#    ('not', 'RB'),
#    ('even', 'RB'),
#    ('matter', 'RBR')]],
#  ['i had to fall',
#   [('i', 'NN'), ('had', 'VBD'), ('to', 'TO'), ('fall', 'VB')]],
#  ['to lose it all',
#   [('to', 'TO'), ('lose', 'VB'), ('it', 'PRP'), ('all', 'DT')]],
#  ['but in the end',
#   [('but', 'CC'), ('in', 'IN'), ('the', 'DT'), ('end', 'NN')]],
#  ['it does not even matter',
#   [('it', 'PRP'),
#    ('does', 'VBZ'),
#    ('not', 'RB'),
#    ('even', 'RB'),
#    ('matter', 'RBR')]],
#  ['i have put my trust in you',
#   [('i', 'NNS'),
#    ('have', 'VBP'),
#    ('put', 'VBN'),
#    ('my', 'PRP$'),
#    ('trust', 'NN'),
#    ('in', 'IN'),
#    ('you', 'PRP')]],
#  ['pushed as far as i can go',
#   [('pushed', 'VBN'),
#    ('as', 'RB'),
#    ('far', 'RB'),
#    ('as', 'IN'),
#    ('i', 'NN'),
#    ('can', 'MD'),
#    ('go', 'VB')]],
#  ['for all this', [('for', 'IN'), ('all', 'PDT'), ('this', 'DT')]],
#  ['there is only one thing you should know',
#   [('there', 'EX'),
#    ('is', 'VBZ'),
#    ('only', 'RB'),
#    ('one', 'CD'),
#    ('thing', 'NN'),
#    ('you', 'PRP'),
#    ('should', 'MD'),
#    ('know', 'VB')]],
#  ['i have put my trust in you',
#   [('i', 'NNS'),
#    ('have', 'VBP'),
#    ('put', 'VBN'),
#    ('my', 'PRP$'),
#    ('trust', 'NN'),
#    ('in', 'IN'),
#    ('you', 'PRP')]],
#  ['pushed as far as i can go',
#   [('pushed', 'VBN'),
#    ('as', 'RB'),
#    ('far', 'RB'),
#    ('as', 'IN'),
#    ('i', 'NN'),
#    ('can', 'MD'),
#    ('go', 'VB')]],
#  ['for all this', [('for', 'IN'), ('all', 'PDT'), ('this', 'DT')]],
#  ['there is only one thing you should know',
#   [('there', 'EX'),
#    ('is', 'VBZ'),
#    ('only', 'RB'),
#    ('one', 'CD'),
#    ('thing', 'NN'),
#    ('you', 'PRP'),
#    ('should', 'MD'),
#    ('know', 'VB')]],
#  ['i tried so hard',
#   [('i', 'NN'), ('tried', 'VBD'), ('so', 'RB'), ('hard', 'JJ')]],
#  ['and got so far',
#   [('and', 'CC'), ('got', 'VBD'), ('so', 'RB'), ('far', 'RB')]],
#  ['but in the end',
#   [('but', 'CC'), ('in', 'IN'), ('the', 'DT'), ('end', 'NN')]],
#  ['it does not even matter',
#   [('it', 'PRP'),
#    ('does', 'VBZ'),
#    ('not', 'RB'),
#    ('even', 'RB'),
#    ('matter', 'RBR')]],
#  ['i had to fall',
#   [('i', 'NN'), ('had', 'VBD'), ('to', 'TO'), ('fall', 'VB')]],
#  ['to lose it all',
#   [('to', 'TO'), ('lose', 'VB'), ('it', 'PRP'), ('all', 'DT')]],
#  ['but in the end',
#   [('but', 'CC'), ('in', 'IN'), ('the', 'DT'), ('end', 'NN')]],
#  ['it does not even matter',
#   [('it', 'PRP'),
#    ('does', 'VBZ'),
#    ('not', 'RB'),
#    ('even', 'RB'),
#    ('matter', 'RBR')]],
#  ['', []],
#  ['', []],
#  ['i remember black skies',
#   [('i', 'JJ'), ('remember', 'VBP'), ('black', 'JJ'), ('skies', 'NNS')]],
#  ['the lightning all around me',
#   [('the', 'DT'),
#    ('lightning', 'VBG'),
#    ('all', 'DT'),
#    ('around', 'IN'),
#    ('me', 'PRP')]],
#  ['i remember each flash',
#   [('i', 'JJ'), ('remember', 'VBP'), ('each', 'DT'), ('flash', 'NN')]],
#  ['as time began to blur',
#   [('as', 'IN'),
#    ('time', 'NN'),
#    ('began', 'VBD'),
#    ('to', 'TO'),
#    ('blur', 'VB')]],
#  ['like a startling sign',
#   [('like', 'IN'), ('a', 'DT'), ('startling', 'JJ'), ('sign', 'NN')]],
#  ['that fate had finally found me',
#   [('that', 'DT'),
#    ('fate', 'NN'),
#    ('had', 'VBD'),
#    ('finally', 'RB'),
#    ('found', 'VBN'),
#    ('me', 'PRP')]],
#  ['and your voice was all i heard',
#   [('and', 'CC'),
#    ('your', 'PRP$'),
#    ('voice', 'NN'),
#    ('was', 'VBD'),
#    ('all', 'DT'),
#    ('i', 'JJ'),
#    ('heard', 'NN')]],
#  ['that i get what i deserve',
#   [('that', 'DT'),
#    ('i', 'VBZ'),
#    ('get', 'VBP'),
#    ('what', 'WP'),
#    ('i', 'VBP'),
#    ('deserve', 'VBP')]],
#  ['so give me reason',
#   [('so', 'RB'), ('give', 'VB'), ('me', 'PRP'), ('reason', 'NN')]],
#  ['to prove me wrong',
#   [('to', 'TO'), ('prove', 'VB'), ('me', 'PRP'), ('wrong', 'JJ')]],
#  ['to wash this memory clean',
#   [('to', 'TO'),
#    ('wash', 'VB'),
#    ('this', 'DT'),
#    ('memory', 'NN'),
#    ('clean', 'NN')]],
#  ['let the floods cross',
#   [('let', 'VB'), ('the', 'DT'), ('floods', 'NNS'), ('cross', 'NN')]],
#  ['the distance in your eyes',
#   [('the', 'DT'),
#    ('distance', 'NN'),
#    ('in', 'IN'),
#    ('your', 'PRP$'),
#    ('eyes', 'NNS')]],
#  ['give me reason', [('give', 'VB'), ('me', 'PRP'), ('reason', 'NN')]],
#  ['to fill this hole',
#   [('to', 'TO'), ('fill', 'VB'), ('this', 'DT'), ('hole', 'NN')]],
#  ['connect this space between',
#   [('connect', 'NN'), ('this', 'DT'), ('space', 'NN'), ('between', 'IN')]],
#  ['let it be enough to reach the truth that lies',
#   [('let', 'VB'),
#    ('it', 'PRP'),
#    ('be', 'VB'),
#    ('enough', 'JJ'),
#    ('to', 'TO'),
#    ('reach', 'VB'),
#    ('the', 'DT'),
#    ('truth', 'NN'),
#    ('that', 'IN'),
#    ('lies', 'VBZ')]],
#  ['across this new divide',
#   [('across', 'IN'), ('this', 'DT'), ('new', 'JJ'), ('divide', 'NN')]],
#  ['there was nothing inside',
#   [('there', 'EX'), ('was', 'VBD'), ('nothing', 'NN'), ('inside', 'RB')]],
#  ['the memories left abandoned',
#   [('the', 'DT'), ('memories', 'NNS'), ('left', 'VBD'), ('abandoned', 'VBN')]],
#  ['there was nowhere to hide',
#   [('there', 'EX'),
#    ('was', 'VBD'),
#    ('nowhere', 'RB'),
#    ('to', 'TO'),
#    ('hide', 'VB')]],
#  ['the ashes fell like snow',
#   [('the', 'DT'),
#    ('ashes', 'NNS'),
#    ('fell', 'VBD'),
#    ('like', 'IN'),
#    ('snow', 'NN')]],
#  ['and the ground caved in',
#   [('and', 'CC'),
#    ('the', 'DT'),
#    ('ground', 'NN'),
#    ('caved', 'VBD'),
#    ('in', 'IN')]],
#  ['between where we were standing',
#   [('between', 'IN'),
#    ('where', 'WRB'),
#    ('we', 'PRP'),
#    ('were', 'VBD'),
#    ('standing', 'VBG')]],
#  ['and your voice was all i heard',
#   [('and', 'CC'),
#    ('your', 'PRP$'),
#    ('voice', 'NN'),
#    ('was', 'VBD'),
#    ('all', 'DT'),
#    ('i', 'JJ'),
#    ('heard', 'NN')]],
#  ['that i get what i deserve',
#   [('that', 'DT'),
#    ('i', 'VBZ'),
#    ('get', 'VBP'),
#    ('what', 'WP'),
#    ('i', 'VBP'),
#    ('deserve', 'VBP')]],
#  ['so give me reason',
#   [('so', 'RB'), ('give', 'VB'), ('me', 'PRP'), ('reason', 'NN')]],
#  ['to prove me wrong',
#   [('to', 'TO'), ('prove', 'VB'), ('me', 'PRP'), ('wrong', 'JJ')]],
#  ['to wash this memory clean',
#   [('to', 'TO'),
#    ('wash', 'VB'),
#    ('this', 'DT'),
#    ('memory', 'NN'),
#    ('clean', 'NN')]],
#  ['let the floods cross',
#   [('let', 'VB'), ('the', 'DT'), ('floods', 'NNS'), ('cross', 'NN')]],
#  ['the distance in your eyes',
#   [('the', 'DT'),
#    ('distance', 'NN'),
#    ('in', 'IN'),
#    ('your', 'PRP$'),
#    ('eyes', 'NNS')]],
#  ['across this new divide',
#   [('across', 'IN'), ('this', 'DT'), ('new', 'JJ'), ('divide', 'NN')]],
#  ['in every loss in every lie',
#   [('in', 'IN'),
#    ('every', 'DT'),
#    ('loss', 'NN'),
#    ('in', 'IN'),
#    ('every', 'DT'),
#    ('lie', 'NN')]],
#  ['in every truth that you deny',
#   [('in', 'IN'),
#    ('every', 'DT'),
#    ('truth', 'NN'),
#    ('that', 'IN'),
#    ('you', 'PRP'),
#    ('deny', 'VBP')]],
#  ['and each regret and each goodbye',
#   [('and', 'CC'),
#    ('each', 'DT'),
#    ('regret', 'NN'),
#    ('and', 'CC'),
#    ('each', 'DT'),
#    ('goodbye', 'NN')]],
#  ['was a mistake too great to hide',
#   [('was', 'VBD'),
#    ('a', 'DT'),
#    ('mistake', 'NN'),
#    ('too', 'RB'),
#    ('great', 'JJ'),
#    ('to', 'TO'),
#    ('hide', 'VB')]],
#  ['and your voice was all i heard',
#   [('and', 'CC'),
#    ('your', 'PRP$'),
#    ('voice', 'NN'),
#    ('was', 'VBD'),
#    ('all', 'DT'),
#    ('i', 'JJ'),
#    ('heard', 'NN')]],
#  ['that i get what i deserve',
#   [('that', 'DT'),
#    ('i', 'VBZ'),
#    ('get', 'VBP'),
#    ('what', 'WP'),
#    ('i', 'VBP'),
#    ('deserve', 'VBP')]],
#  ['so give me reason',
#   [('so', 'RB'), ('give', 'VB'), ('me', 'PRP'), ('reason', 'NN')]],
#  ['to prove me wrong',
#   [('to', 'TO'), ('prove', 'VB'), ('me', 'PRP'), ('wrong', 'JJ')]],
#  ['to wash this memory clean',
#   [('to', 'TO'),
#    ('wash', 'VB'),
#    ('this', 'DT'),
#    ('memory', 'NN'),
#    ('clean', 'NN')]],
#  ['let the floods cross',
#   [('let', 'VB'), ('the', 'DT'), ('floods', 'NNS'), ('cross', 'NN')]],
#  ['the distance in your eyes',
#   [('the', 'DT'),
#    ('distance', 'NN'),
#    ('in', 'IN'),
#    ('your', 'PRP$'),
#    ('eyes', 'NNS')]],
#  ['give me reason', [('give', 'VB'), ('me', 'PRP'), ('reason', 'NN')]],
#  ['to fill this hole',
#   [('to', 'TO'), ('fill', 'VB'), ('this', 'DT'), ('hole', 'NN')]],
#  ['connect this space between',
#   [('connect', 'NN'), ('this', 'DT'), ('space', 'NN'), ('between', 'IN')]],
#  ['let it be enough to reach the truth that lies',
#   [('let', 'VB'),
#    ('it', 'PRP'),
#    ('be', 'VB'),
#    ('enough', 'JJ'),
#    ('to', 'TO'),
#    ('reach', 'VB'),
#    ('the', 'DT'),
#    ('truth', 'NN'),
#    ('that', 'IN'),
#    ('lies', 'VBZ')]],
#  ['across this new divide',
#   [('across', 'IN'), ('this', 'DT'), ('new', 'JJ'), ('divide', 'NN')]],
#  ['across this new divide',
#   [('across', 'IN'), ('this', 'DT'), ('new', 'JJ'), ('divide', 'NN')]],
#  ['across this new divide',
#   [('across', 'IN'), ('this', 'DT'), ('new', 'JJ'), ('divide', 'NN')]],
#  ['', []],
#  ['', []],
#  ['take me down to the river bend',
#   [('take', 'VB'),
#    ('me', 'PRP'),
#    ('down', 'RP'),
#    ('to', 'TO'),
#    ('the', 'DT'),
#    ('river', 'NN'),
#    ('bend', 'NN')]],
#  ['take me down to the fighting end',
#   [('take', 'VB'),
#    ('me', 'PRP'),
#    ('down', 'RP'),
#    ('to', 'TO'),
#    ('the', 'DT'),
#    ('fighting', 'VBG'),
#    ('end', 'NN')]],
#  ['wash the poison from off my skin',
#   [('wash', 'IN'),
#    ('the', 'DT'),
#    ('poison', 'NN'),
#    ('from', 'IN'),
#    ('off', 'IN'),
#    ('my', 'PRP$'),
#    ('skin', 'NN')]],
#  ['show me how to be whole again',
#   [('show', 'VB'),
#    ('me', 'PRP'),
#    ('how', 'WRB'),
#    ('to', 'TO'),
#    ('be', 'VB'),
#    ('whole', 'JJ'),
#    ('again', 'RB')]],
#  ['fly me up on a silver wing',
#   [('fly', 'VB'),
#    ('me', 'PRP'),
#    ('up', 'RP'),
#    ('on', 'IN'),
#    ('a', 'DT'),
#    ('silver', 'NN'),
#    ('wing', 'NN')]],
#  ['past the black where the sirens sing',
#   [('past', 'IN'),
#    ('the', 'DT'),
#    ('black', 'JJ'),
#    ('where', 'WRB'),
#    ('the', 'DT'),
#    ('sirens', 'NNS'),
#    ('sing', 'VBG')]],
#  ["warm me up in a nova 's glow",
#   [('warm', 'NN'),
#    ('me', 'PRP'),
#    ('up', 'RP'),
#    ('in', 'IN'),
#    ('a', 'DT'),
#    ('nova', 'NN'),
#    ("'s", 'POS'),
#    ('glow', 'NN')]],
#  ['and drop me down to the dream below',
#   [('and', 'CC'),
#    ('drop', 'VB'),
#    ('me', 'PRP'),
#    ('down', 'RP'),
#    ('to', 'TO'),
#    ('the', 'DT'),
#    ('dream', 'NN'),
#    ('below', 'IN')]],
#  ["'ecause i am only a crack in this castle of glass",
#   [("'ecause", 'IN'),
#    ('i', 'NN'),
#    ('am', 'VBP'),
#    ('only', 'RB'),
#    ('a', 'DT'),
#    ('crack', 'NN'),
#    ('in', 'IN'),
#    ('this', 'DT'),
#    ('castle', 'NN'),
#    ('of', 'IN'),
#    ('glass', 'NN')]],
#  ['hardly anything there for you to see',
#   [('hardly', 'RB'),
#    ('anything', 'NN'),
#    ('there', 'RB'),
#    ('for', 'IN'),
#    ('you', 'PRP'),
#    ('to', 'TO'),
#    ('see', 'VB')]],
#  ['for you to see',
#   [('for', 'IN'), ('you', 'PRP'), ('to', 'TO'), ('see', 'VB')]],
#  ['bring me home in a blinding dream',
#   [('bring', 'VB'),
#    ('me', 'PRP'),
#    ('home', 'NN'),
#    ('in', 'IN'),
#    ('a', 'DT'),
#    ('blinding', 'NN'),
#    ('dream', 'NN')]],
#  ['through the secrets that i have seen',
#   [('through', 'IN'),
#    ('the', 'DT'),
#    ('secrets', 'NNS'),
#    ('that', 'IN'),
#    ('i', 'NN'),
#    ('have', 'VBP'),
#    ('seen', 'VBN')]],
#  ['wash the sorrow from off my skin',
#   [('wash', 'IN'),
#    ('the', 'DT'),
#    ('sorrow', 'NN'),
#    ('from', 'IN'),
#    ('off', 'IN'),
#    ('my', 'PRP$'),
#    ('skin', 'NN')]],
#  ['show me how to be whole again',
#   [('show', 'VB'),
#    ('me', 'PRP'),
#    ('how', 'WRB'),
#    ('to', 'TO'),
#    ('be', 'VB'),
#    ('whole', 'JJ'),
#    ('again', 'RB')]],
#  ["'ecause i am only a crack in this castle of glass",
#   [("'ecause", 'IN'),
#    ('i', 'NN'),
#    ('am', 'VBP'),
#    ('only', 'RB'),
#    ('a', 'DT'),
#    ('crack', 'NN'),
#    ('in', 'IN'),
#    ('this', 'DT'),
#    ('castle', 'NN'),
#    ('of', 'IN'),
#    ('glass', 'NN')]],
#  ['hardly anything there for you to see',
#   [('hardly', 'RB'),
#    ('anything', 'NN'),
#    ('there', 'RB'),
#    ('for', 'IN'),
#    ('you', 'PRP'),
#    ('to', 'TO'),
#    ('see', 'VB')]],
#  ['for you to see',
#   [('for', 'IN'), ('you', 'PRP'), ('to', 'TO'), ('see', 'VB')]],
#  ["'ecause i am only a crack in this castle of glass",
#   [("'ecause", 'IN'),
#    ('i', 'NN'),
#    ('am', 'VBP'),
#    ('only', 'RB'),
#    ('a', 'DT'),
#    ('crack', 'NN'),
#    ('in', 'IN'),
#    ('this', 'DT'),
#    ('castle', 'NN'),
#    ('of', 'IN'),
#    ('glass', 'NN')]],
#  ['hardly anything else i need to be',
#   [('hardly', 'RB'),
#    ('anything', 'NN'),
#    ('else', 'JJ'),
#    ('i', 'NN'),
#    ('need', 'VBP'),
#    ('to', 'TO'),
#    ('be', 'VB')]],
#  ["'ecause i am only a crack in this castle of glass",
#   [("'ecause", 'IN'),
#    ('i', 'NN'),
#    ('am', 'VBP'),
#    ('only', 'RB'),
#    ('a', 'DT'),
#    ('crack', 'NN'),
#    ('in', 'IN'),
#    ('this', 'DT'),
#    ('castle', 'NN'),
#    ('of', 'IN'),
#    ('glass', 'NN')]],
#  ['hardly anything there for you to see',
#   [('hardly', 'RB'),
#    ('anything', 'NN'),
#    ('there', 'RB'),
#    ('for', 'IN'),
#    ('you', 'PRP'),
#    ('to', 'TO'),
#    ('see', 'VB')]],
#  ['for you to see',
#   [('for', 'IN'), ('you', 'PRP'), ('to', 'TO'), ('see', 'VB')]],
#  ['for you to see',
#   [('for', 'IN'), ('you', 'PRP'), ('to', 'TO'), ('see', 'VB')]],
#  ['', []],
#  ['', []],
#  ['i dreamed i was missing',
#   [('i', 'NN'),
#    ('dreamed', 'VBD'),
#    ('i', 'NN'),
#    ('was', 'VBD'),
#    ('missing', 'VBG')]],
#  ['you were so scared',
#   [('you', 'PRP'), ('were', 'VBD'), ('so', 'RB'), ('scared', 'JJ')]],
#  ['but no one would listen',
#   [('but', 'CC'),
#    ('no', 'DT'),
#    ('one', 'NN'),
#    ('would', 'MD'),
#    ('listen', 'VB')]],
#  ['cause no one else cared',
#   [('cause', 'NN'),
#    ('no', 'DT'),
#    ('one', 'NN'),
#    ('else', 'RB'),
#    ('cared', 'VBD')]],
#  ['after my dreaming', [('after', 'IN'), ('my', 'PRP$'), ('dreaming', 'NN')]],
#  ['i woke with this fear',
#   [('i', 'JJ'),
#    ('woke', 'VBD'),
#    ('with', 'IN'),
#    ('this', 'DT'),
#    ('fear', 'NN')]],
#  ['what am i leaving',
#   [('what', 'WP'), ('am', 'VBP'), ('i', 'JJ'), ('leaving', 'VBG')]],
#  ['when i am done here ?',
#   [('when', 'WRB'),
#    ('i', 'NN'),
#    ('am', 'VBP'),
#    ('done', 'VBN'),
#    ('here', 'RB'),
#    ('?', '.')]],
#  ['so , if you are asking me , i want you to know',
#   [('so', 'RB'),
#    (',', ','),
#    ('if', 'IN'),
#    ('you', 'PRP'),
#    ('are', 'VBP'),
#    ('asking', 'VBG'),
#    ('me', 'PRP'),
#    (',', ','),
#    ('i', 'VB'),
#    ('want', 'VBP'),
#    ('you', 'PRP'),
#    ('to', 'TO'),
#    ('know', 'VB')]],
#  ['when my time comes',
#   [('when', 'WRB'), ('my', 'PRP$'), ('time', 'NN'), ('comes', 'VBZ')]],
#  ['forget the wrong that i have done',
#   [('forget', 'VB'),
#    ('the', 'DT'),
#    ('wrong', 'JJ'),
#    ('that', 'IN'),
#    ('i', 'NN'),
#    ('have', 'VBP'),
#    ('done', 'VBN')]],
#  ['help me leave behind some reasons to be missed',
#   [('help', 'VB'),
#    ('me', 'PRP'),
#    ('leave', 'VB'),
#    ('behind', 'IN'),
#    ('some', 'DT'),
#    ('reasons', 'NNS'),
#    ('to', 'TO'),
#    ('be', 'VB'),
#    ('missed', 'VBN')]],
#  ['and do not resent me',
#   [('and', 'CC'),
#    ('do', 'VB'),
#    ('not', 'RB'),
#    ('resent', 'VB'),
#    ('me', 'PRP')]],
#  ['and when you are feeling empty',
#   [('and', 'CC'),
#    ('when', 'WRB'),
#    ('you', 'PRP'),
#    ('are', 'VBP'),
#    ('feeling', 'VBG'),
#    ('empty', 'JJ')]],
#  ['keep me in your memory',
#   [('keep', 'VB'),
#    ('me', 'PRP'),
#    ('in', 'IN'),
#    ('your', 'PRP$'),
#    ('memory', 'NN')]],
#  ['leave out all the rest',
#   [('leave', 'VB'),
#    ('out', 'RP'),
#    ('all', 'PDT'),
#    ('the', 'DT'),
#    ('rest', 'NN')]],
#  ['leave out all the rest',
#   [('leave', 'VB'),
#    ('out', 'RP'),
#    ('all', 'PDT'),
#    ('the', 'DT'),
#    ('rest', 'NN')]],
#  ['do not be afraid',
#   [('do', 'VB'), ('not', 'RB'), ('be', 'VB'), ('afraid', 'JJ')]],
#  ['i have taken my beating',
#   [('i', 'NNS'),
#    ('have', 'VBP'),
#    ('taken', 'VBN'),
#    ('my', 'PRP$'),
#    ('beating', 'NN')]],
#  ['i have shared what i have made',
#   [('i', 'NNS'),
#    ('have', 'VBP'),
#    ('shared', 'VBN'),
#    ('what', 'WP'),
#    ('i', 'NN'),
#    ('have', 'VBP'),
#    ('made', 'VBN')]],
#  ['i am strong on the surface',
#   [('i', 'NN'),
#    ('am', 'VBP'),
#    ('strong', 'JJ'),
#    ('on', 'IN'),
#    ('the', 'DT'),
#    ('surface', 'NN')]],
#  ['not all the way through',
#   [('not', 'RB'),
#    ('all', 'PDT'),
#    ('the', 'DT'),
#    ('way', 'NN'),
#    ('through', 'IN')]],
#  ['i have never been perfect',
#   [('i', 'NNS'),
#    ('have', 'VBP'),
#    ('never', 'RB'),
#    ('been', 'VBN'),
#    ('perfect', 'JJ')]],
#  ['but neither have you',
#   [('but', 'CC'), ('neither', 'DT'), ('have', 'VBP'), ('you', 'PRP')]],
#  ['so , if you are asking me , i want you to know',
#   [('so', 'RB'),
#    (',', ','),
#    ('if', 'IN'),
#    ('you', 'PRP'),
#    ('are', 'VBP'),
#    ('asking', 'VBG'),
#    ('me', 'PRP'),
#    (',', ','),
#    ('i', 'VB'),
#    ('want', 'VBP'),
#    ('you', 'PRP'),
#    ('to', 'TO'),
#    ('know', 'VB')]],
#  ['when my time comes',
#   [('when', 'WRB'), ('my', 'PRP$'), ('time', 'NN'), ('comes', 'VBZ')]],
#  ['forget the wrong that i have done',
#   [('forget', 'VB'),
#    ('the', 'DT'),
#    ('wrong', 'JJ'),
#    ('that', 'IN'),
#    ('i', 'NN'),
#    ('have', 'VBP'),
#    ('done', 'VBN')]],
#  ['help me leave behind some reasons to be missed',
#   [('help', 'VB'),
#    ('me', 'PRP'),
#    ('leave', 'VB'),
#    ('behind', 'IN'),
#    ('some', 'DT'),
#    ('reasons', 'NNS'),
#    ('to', 'TO'),
#    ('be', 'VB'),
#    ('missed', 'VBN')]],
#  ['and do not resent me',
#   [('and', 'CC'),
#    ('do', 'VB'),
#    ('not', 'RB'),
#    ('resent', 'VB'),
#    ('me', 'PRP')]],
#  ['and when you are feeling empty',
#   [('and', 'CC'),
#    ('when', 'WRB'),
#    ('you', 'PRP'),
#    ('are', 'VBP'),
#    ('feeling', 'VBG'),
#    ('empty', 'JJ')]],
#  ['keep me in your memory',
#   [('keep', 'VB'),
#    ('me', 'PRP'),
#    ('in', 'IN'),
#    ('your', 'PRP$'),
#    ('memory', 'NN')]],
#  ['leave out all the rest',
#   [('leave', 'VB'),
#    ('out', 'RP'),
#    ('all', 'PDT'),
#    ('the', 'DT'),
#    ('rest', 'NN')]],
#  ['leave out all the rest',
#   [('leave', 'VB'),
#    ('out', 'RP'),
#    ('all', 'PDT'),
#    ('the', 'DT'),
#    ('rest', 'NN')]],
#  ['forgetting', [('forgetting', 'VBG')]],
#  ['all the hurt inside you have learned to hide so well',
#   [('all', 'PDT'),
#    ('the', 'DT'),
#    ('hurt', 'NN'),
#    ('inside', 'IN'),
#    ('you', 'PRP'),
#    ('have', 'VBP'),
#    ('learned', 'VBN'),
#    ('to', 'TO'),
#    ('hide', 'VB'),
#    ('so', 'RB'),
#    ('well', 'RB')]],
#  ['pretending', [('pretending', 'VBG')]],
#  ['someone else can come and save me from myself',
#   [('someone', 'NN'),
#    ('else', 'RB'),
#    ('can', 'MD'),
#    ('come', 'VB'),
#    ('and', 'CC'),
#    ('save', 'VB'),
#    ('me', 'PRP'),
#    ('from', 'IN'),
#    ('myself', 'PRP')]],
#  ['i can not be who you are',
#   [('i', 'NN'),
#    ('can', 'MD'),
#    ('not', 'RB'),
#    ('be', 'VB'),
#    ('who', 'WP'),
#    ('you', 'PRP'),
#    ('are', 'VBP')]],
#  ['when my time comes',
#   [('when', 'WRB'), ('my', 'PRP$'), ('time', 'NN'), ('comes', 'VBZ')]],
#  ['forget the wrong that i have done',
#   [('forget', 'VB'),
#    ('the', 'DT'),
#    ('wrong', 'JJ'),
#    ('that', 'IN'),
#    ('i', 'NN'),
#    ('have', 'VBP'),
#    ('done', 'VBN')]],
#  ['help me leave behind some reasons to be missed',
#   [('help', 'VB'),
#    ('me', 'PRP'),
#    ('leave', 'VB'),
#    ('behind', 'IN'),
#    ('some', 'DT'),
#    ('reasons', 'NNS'),
#    ('to', 'TO'),
#    ('be', 'VB'),
#    ('missed', 'VBN')]],
#  ['and do not resent me',
#   [('and', 'CC'),
#    ('do', 'VB'),
#    ('not', 'RB'),
#    ('resent', 'VB'),
#    ('me', 'PRP')]],
#  ['and when you are feeling empty',
#   [('and', 'CC'),
#    ('when', 'WRB'),
#    ('you', 'PRP'),
#    ('are', 'VBP'),
#    ('feeling', 'VBG'),
#    ('empty', 'JJ')]],
#  ['keep me in your memory',
#   [('keep', 'VB'),
#    ('me', 'PRP'),
#    ('in', 'IN'),
#    ('your', 'PRP$'),
#    ('memory', 'NN')]],
#  ['leave out all the rest',
#   [('leave', 'VB'),
#    ('out', 'RP'),
#    ('all', 'PDT'),
#    ('the', 'DT'),
#    ('rest', 'NN')]],
#  ['leave out all the rest',
#   [('leave', 'VB'),
#    ('out', 'RP'),
#    ('all', 'PDT'),
#    ('the', 'DT'),
#    ('rest', 'NN')]],
#  ['forgetting', [('forgetting', 'VBG')]],
#  ['all the hurt inside you have learned to hide so well',
#   [('all', 'PDT'),
#    ('the', 'DT'),
#    ('hurt', 'NN'),
#    ('inside', 'IN'),
#    ('you', 'PRP'),
#    ('have', 'VBP'),
#    ('learned', 'VBN'),
#    ('to', 'TO'),
#    ('hide', 'VB'),
#    ('so', 'RB'),
#    ('well', 'RB')]],
#  ['pretending', [('pretending', 'VBG')]],
#  ['someone else can come and save me from myself',
#   [('someone', 'NN'),
#    ('else', 'RB'),
#    ('can', 'MD'),
#    ('come', 'VB'),
#    ('and', 'CC'),
#    ('save', 'VB'),
#    ('me', 'PRP'),
#    ('from', 'IN'),
#    ('myself', 'PRP')]],
#  ['i can not be who you are',
#   [('i', 'NN'),
#    ('can', 'MD'),
#    ('not', 'RB'),
#    ('be', 'VB'),
#    ('who', 'WP'),
#    ('you', 'PRP'),
#    ('are', 'VBP')]],
#  ['i can not be who you are',
#   [('i', 'NN'),
#    ('can', 'MD'),
#    ('not', 'RB'),
#    ('be', 'VB'),
#    ('who', 'WP'),
#    ('you', 'PRP'),
#    ('are', 'VBP')]],
#  ['', []],
#  ['', []],
#  ['telling me to go',
#   [('telling', 'VBG'), ('me', 'PRP'), ('to', 'TO'), ('go', 'VB')]],
#  ['but hands beg me to stay',
#   [('but', 'CC'),
#    ('hands', 'VBZ'),
#    ('beg', 'NNS'),
#    ('me', 'PRP'),
#    ('to', 'TO'),
#    ('stay', 'VB')]],
#  ['your lips say that you love',
#   [('your', 'PRP$'),
#    ('lips', 'NNS'),
#    ('say', 'VBP'),
#    ('that', 'IN'),
#    ('you', 'PRP'),
#    ('love', 'VBP')]],
#  ['your eyes say that you hate',
#   [('your', 'PRP$'),
#    ('eyes', 'NNS'),
#    ('say', 'VBP'),
#    ('that', 'IN'),
#    ('you', 'PRP'),
#    ('hate', 'VBP')]],
#  ['there is truth in your lies',
#   [('there', 'EX'),
#    ('is', 'VBZ'),
#    ('truth', 'NN'),
#    ('in', 'IN'),
#    ('your', 'PRP$'),
#    ('lies', 'NNS')]],
#  ['doubt in your faith',
#   [('doubt', 'NN'), ('in', 'IN'), ('your', 'PRP$'), ('faith', 'NN')]],
#  ['what you build you lay to waste',
#   [('what', 'WP'),
#    ('you', 'PRP'),
#    ('build', 'VBP'),
#    ('you', 'PRP'),
#    ('lay', 'VBP'),
#    ('to', 'TO'),
#    ('waste', 'VB')]],
#  ['there is truth in your lies',
#   [('there', 'EX'),
#    ('is', 'VBZ'),
#    ('truth', 'NN'),
#    ('in', 'IN'),
#    ('your', 'PRP$'),
#    ('lies', 'NNS')]],
#  ['doubt in your faith',
#   [('doubt', 'NN'), ('in', 'IN'), ('your', 'PRP$'), ('faith', 'NN')]],
#  ["all i have got 's what you did not take",
#   [('all', 'DT'),
#    ('i', 'NNS'),
#    ('have', 'VBP'),
#    ('got', 'VBN'),
#    ("'s", 'POS'),
#    ('what', 'WP'),
#    ('you', 'PRP'),
#    ('did', 'VBD'),
#    ('not', 'RB'),
#    ('take', 'VB')]],
#  ['so i , i will not be the one',
#   [('so', 'RB'),
#    ('i', 'JJ'),
#    (',', ','),
#    ('i', 'NN'),
#    ('will', 'MD'),
#    ('not', 'RB'),
#    ('be', 'VB'),
#    ('the', 'DT'),
#    ('one', 'CD')]],
#  ['be the one to leave this',
#   [('be', 'VB'),
#    ('the', 'DT'),
#    ('one', 'CD'),
#    ('to', 'TO'),
#    ('leave', 'VB'),
#    ('this', 'DT')]],
#  ['in pieces', [('in', 'IN'), ('pieces', 'NNS')]],
#  ['and you , you will be alone',
#   [('and', 'CC'),
#    ('you', 'PRP'),
#    (',', ','),
#    ('you', 'PRP'),
#    ('will', 'MD'),
#    ('be', 'VB'),
#    ('alone', 'RB')]],
#  ['alone with all your secrets',
#   [('alone', 'RB'),
#    ('with', 'IN'),
#    ('all', 'DT'),
#    ('your', 'PRP$'),
#    ('secrets', 'NNS')]],
#  ['and regrets', [('and', 'CC'), ('regrets', 'NNS')]],
#  ['do not lie', [('do', 'VB'), ('not', 'RB'), ('lie', 'VB')]],
#  ['you promise me the sky',
#   [('you', 'PRP'),
#    ('promise', 'VBP'),
#    ('me', 'PRP'),
#    ('the', 'DT'),
#    ('sky', 'NN')]],
#  ['then toss me like a stone',
#   [('then', 'RB'),
#    ('toss', 'IN'),
#    ('me', 'PRP'),
#    ('like', 'IN'),
#    ('a', 'DT'),
#    ('stone', 'NN')]],
#  ['you wrap me in your arms',
#   [('you', 'PRP'),
#    ('wrap', 'VBP'),
#    ('me', 'PRP'),
#    ('in', 'IN'),
#    ('your', 'PRP$'),
#    ('arms', 'NNS')]],
#  ['and chill me to the bone',
#   [('and', 'CC'),
#    ('chill', 'VB'),
#    ('me', 'PRP'),
#    ('to', 'TO'),
#    ('the', 'DT'),
#    ('bone', 'NN')]],
#  ['there is truth in your lies',
#   [('there', 'EX'),
#    ('is', 'VBZ'),
#    ('truth', 'NN'),
#    ('in', 'IN'),
#    ('your', 'PRP$'),
#    ('lies', 'NNS')]],
#  ['doubt in your faith',
#   [('doubt', 'NN'), ('in', 'IN'), ('your', 'PRP$'), ('faith', 'NN')]],
#  ["all i have got 's what you did not take",
#   [('all', 'DT'),
#    ('i', 'NNS'),
#    ('have', 'VBP'),
#    ('got', 'VBN'),
#    ("'s", 'POS'),
#    ('what', 'WP'),
#    ('you', 'PRP'),
#    ('did', 'VBD'),
#    ('not', 'RB'),
#    ('take', 'VB')]],
#  ['so i , i will not be the one',
#   [('so', 'RB'),
#    ('i', 'JJ'),
#    (',', ','),
#    ('i', 'NN'),
#    ('will', 'MD'),
#    ('not', 'RB'),
#    ('be', 'VB'),
#    ('the', 'DT'),
#    ('one', 'CD')]],
#  ['be the one to leave this',
#   [('be', 'VB'),
#    ('the', 'DT'),
#    ('one', 'CD'),
#    ('to', 'TO'),
#    ('leave', 'VB'),
#    ('this', 'DT')]],
#  ['in pieces', [('in', 'IN'), ('pieces', 'NNS')]],
#  ['and you , you will be alone',
#   [('and', 'CC'),
#    ('you', 'PRP'),
#    (',', ','),
#    ('you', 'PRP'),
#    ('will', 'MD'),
#    ('be', 'VB'),
#    ('alone', 'RB')]],
#  ['alone with all your secrets',
#   [('alone', 'RB'),
#    ('with', 'IN'),
#    ('all', 'DT'),
#    ('your', 'PRP$'),
#    ('secrets', 'NNS')]],
#  ['and regrets', [('and', 'CC'), ('regrets', 'NNS')]],
#  ['do not lie', [('do', 'VB'), ('not', 'RB'), ('lie', 'VB')]],
#  ['so i , i will not be the one',
#   [('so', 'RB'),
#    ('i', 'JJ'),
#    (',', ','),
#    ('i', 'NN'),
#    ('will', 'MD'),
#    ('not', 'RB'),
#    ('be', 'VB'),
#    ('the', 'DT'),
#    ('one', 'CD')]],
#  ['be the one to leave this',
#   [('be', 'VB'),
#    ('the', 'DT'),
#    ('one', 'CD'),
#    ('to', 'TO'),
#    ('leave', 'VB'),
#    ('this', 'DT')]],
#  ['in pieces', [('in', 'IN'), ('pieces', 'NNS')]],
#  ['and you , you will be alone',
#   [('and', 'CC'),
#    ('you', 'PRP'),
#    (',', ','),
#    ('you', 'PRP'),
#    ('will', 'MD'),
#    ('be', 'VB'),
#    ('alone', 'RB')]],
#  ['alone with all your secrets',
#   [('alone', 'RB'),
#    ('with', 'IN'),
#    ('all', 'DT'),
#    ('your', 'PRP$'),
#    ('secrets', 'NNS')]],
#  ['and regrets', [('and', 'CC'), ('regrets', 'NNS')]],
#  ['do not lie', [('do', 'VB'), ('not', 'RB'), ('lie', 'VB')]],
#  ['', []],
#  ['', []],
#  ['i do not like my mind right now',
#   [('i', 'NNS'),
#    ('do', 'VBP'),
#    ('not', 'RB'),
#    ('like', 'IN'),
#    ('my', 'PRP$'),
#    ('mind', 'NN'),
#    ('right', 'RB'),
#    ('now', 'RB')]],
#  ['stacking up problems that are so unnecessary',
#   [('stacking', 'VBG'),
#    ('up', 'RP'),
#    ('problems', 'NNS'),
#    ('that', 'WDT'),
#    ('are', 'VBP'),
#    ('so', 'RB'),
#    ('unnecessary', 'JJ')]],
#  ['wish that i could slow things down',
#   [('wish', 'JJ'),
#    ('that', 'IN'),
#    ('i', 'NN'),
#    ('could', 'MD'),
#    ('slow', 'VB'),
#    ('things', 'NNS'),
#    ('down', 'RP')]],
#  ['i wan na let go but there is comfort in the panic',
#   [('i', 'NN'),
#    ('wan', 'VBP'),
#    ('na', 'TO'),
#    ('let', 'VB'),
#    ('go', 'VB'),
#    ('but', 'CC'),
#    ('there', 'EX'),
#    ('is', 'VBZ'),
#    ('comfort', 'NN'),
#    ('in', 'IN'),
#    ('the', 'DT'),
#    ('panic', 'NN')]],
#  ['and i drive myself crazy',
#   [('and', 'CC'),
#    ('i', 'VB'),
#    ('drive', 'VBP'),
#    ('myself', 'PRP'),
#    ('crazy', 'JJ')]],
#  ["thinking everything 's about me",
#   [('thinking', 'VBG'),
#    ('everything', 'NN'),
#    ("'s", 'POS'),
#    ('about', 'IN'),
#    ('me', 'PRP')]],
#  ['yeah , i drive myself crazy',
#   [('yeah', 'NN'),
#    (',', ','),
#    ('i', 'JJ'),
#    ('drive', 'VBP'),
#    ('myself', 'PRP'),
#    ('crazy', 'JJ')]],
#  ["'ecause i can ’ t escape the gravity",
#   [("'ecause", 'IN'),
#    ('i', 'NN'),
#    ('can', 'MD'),
#    ('’', 'VB'),
#    ('t', 'JJ'),
#    ('escape', 'NN'),
#    ('the', 'DT'),
#    ('gravity', 'NN')]],
#  ['i am holding on',
#   [('i', 'NN'), ('am', 'VBP'), ('holding', 'VBG'), ('on', 'IN')]],
#  ['why is everything so heavy ?',
#   [('why', 'WRB'),
#    ('is', 'VBZ'),
#    ('everything', 'NN'),
#    ('so', 'RB'),
#    ('heavy', 'JJ'),
#    ('?', '.')]],
#  ['holding on', [('holding', 'VBG'), ('on', 'IN')]],
#  ['so much more than i can carry',
#   [('so', 'RB'),
#    ('much', 'RB'),
#    ('more', 'JJR'),
#    ('than', 'IN'),
#    ('i', 'NN'),
#    ('can', 'MD'),
#    ('carry', 'VB')]],
#  ['i keep dragging around what is bringing me down',
#   [('i', 'JJ'),
#    ('keep', 'VBP'),
#    ('dragging', 'VBG'),
#    ('around', 'IN'),
#    ('what', 'WP'),
#    ('is', 'VBZ'),
#    ('bringing', 'VBG'),
#    ('me', 'PRP'),
#    ('down', 'RP')]],
#  ['if i just let go , i would be set free',
#   [('if', 'IN'),
#    ('i', 'JJ'),
#    ('just', 'RB'),
#    ('let', 'NN'),
#    ('go', 'VB'),
#    (',', ','),
#    ('i', 'VB'),
#    ('would', 'MD'),
#    ('be', 'VB'),
#    ('set', 'VBN'),
#    ('free', 'JJ')]],
#  ['holding on', [('holding', 'VBG'), ('on', 'IN')]],
#  ['why is everything so heavy ?',
#   [('why', 'WRB'),
#    ('is', 'VBZ'),
#    ('everything', 'NN'),
#    ('so', 'RB'),
#    ('heavy', 'JJ'),
#    ('?', '.')]],
#  ['you say that i am paranoid',
#   [('you', 'PRP'),
#    ('say', 'VBP'),
#    ('that', 'IN'),
#    ('i', 'NN'),
#    ('am', 'VBP'),
#    ('paranoid', 'NN')]],
#  ['but i am pretty sure the world is out to get me',
#   [('but', 'CC'),
#    ('i', 'JJ'),
#    ('am', 'VBP'),
#    ('pretty', 'JJ'),
#    ('sure', 'JJ'),
#    ('the', 'DT'),
#    ('world', 'NN'),
#    ('is', 'VBZ'),
#    ('out', 'RP'),
#    ('to', 'TO'),
#    ('get', 'VB'),
#    ('me', 'PRP')]],
#  ['it is not like i make the choice',
#   [('it', 'PRP'),
#    ('is', 'VBZ'),
#    ('not', 'RB'),
#    ('like', 'IN'),
#    ('i', 'NNS'),
#    ('make', 'VBP'),
#    ('the', 'DT'),
#    ('choice', 'NN')]],
#  ['to let my mind stay so fucking messy',
#   [('to', 'TO'),
#    ('let', 'VB'),
#    ('my', 'PRP$'),
#    ('mind', 'NN'),
#    ('stay', 'NN'),
#    ('so', 'RB'),
#    ('fucking', 'JJ'),
#    ('messy', 'NN')]],
#  ['i know i am not the center of the universe',
#   [('i', 'NN'),
#    ('know', 'VBP'),
#    ('i', 'NN'),
#    ('am', 'VBP'),
#    ('not', 'RB'),
#    ('the', 'DT'),
#    ('center', 'NN'),
#    ('of', 'IN'),
#    ('the', 'DT'),
#    ('universe', 'NN')]],
#  ["but you keep spinning 'round me just the same",
#   [('but', 'CC'),
#    ('you', 'PRP'),
#    ('keep', 'VBP'),
#    ('spinning', 'VBG'),
#    ("'round", 'IN'),
#    ('me', 'PRP'),
#    ('just', 'RB'),
#    ('the', 'DT'),
#    ('same', 'JJ')]],
#  ['i know i am not the center of the universe',
#   [('i', 'NN'),
#    ('know', 'VBP'),
#    ('i', 'NN'),
#    ('am', 'VBP'),
#    ('not', 'RB'),
#    ('the', 'DT'),
#    ('center', 'NN'),
#    ('of', 'IN'),
#    ('the', 'DT'),
#    ('universe', 'NN')]],
#  ["but you keep spinning 'round me just the same",
#   [('but', 'CC'),
#    ('you', 'PRP'),
#    ('keep', 'VBP'),
#    ('spinning', 'VBG'),
#    ("'round", 'IN'),
#    ('me', 'PRP'),
#    ('just', 'RB'),
#    ('the', 'DT'),
#    ('same', 'JJ')]],
#  ['i am holding on',
#   [('i', 'NN'), ('am', 'VBP'), ('holding', 'VBG'), ('on', 'IN')]],
#  ['why is everything so heavy ?',
#   [('why', 'WRB'),
#    ('is', 'VBZ'),
#    ('everything', 'NN'),
#    ('so', 'RB'),
#    ('heavy', 'JJ'),
#    ('?', '.')]],
#  ['holding on', [('holding', 'VBG'), ('on', 'IN')]],
#  ['so much more than i can carry',
#   [('so', 'RB'),
#    ('much', 'RB'),
#    ('more', 'JJR'),
#    ('than', 'IN'),
#    ('i', 'NN'),
#    ('can', 'MD'),
#    ('carry', 'VB')]],
#  ['i keep dragging around what is bringing me down',
#   [('i', 'JJ'),
#    ('keep', 'VBP'),
#    ('dragging', 'VBG'),
#    ('around', 'IN'),
#    ('what', 'WP'),
#    ('is', 'VBZ'),
#    ('bringing', 'VBG'),
#    ('me', 'PRP'),
#    ('down', 'RP')]],
#  ['if i just let go , i would be set free',
#   [('if', 'IN'),
#    ('i', 'JJ'),
#    ('just', 'RB'),
#    ('let', 'NN'),
#    ('go', 'VB'),
#    (',', ','),
#    ('i', 'VB'),
#    ('would', 'MD'),
#    ('be', 'VB'),
#    ('set', 'VBN'),
#    ('free', 'JJ')]],
#  ['holding on', [('holding', 'VBG'), ('on', 'IN')]],
#  ['why is everything so heavy ?',
#   [('why', 'WRB'),
#    ('is', 'VBZ'),
#    ('everything', 'NN'),
#    ('so', 'RB'),
#    ('heavy', 'JJ'),
#    ('?', '.')]],
#  ['i know i am not the center of the universe',
#   [('i', 'NN'),
#    ('know', 'VBP'),
#    ('i', 'NN'),
#    ('am', 'VBP'),
#    ('not', 'RB'),
#    ('the', 'DT'),
#    ('center', 'NN'),
#    ('of', 'IN'),
#    ('the', 'DT'),
#    ('universe', 'NN')]],
#  ["but you keep spinning 'round me just the same",
#   [('but', 'CC'),
#    ('you', 'PRP'),
#    ('keep', 'VBP'),
#    ('spinning', 'VBG'),
#    ("'round", 'IN'),
#    ('me', 'PRP'),
#    ('just', 'RB'),
#    ('the', 'DT'),
#    ('same', 'JJ')]],
#  ['i know i am not the center of the universe',
#   [('i', 'NN'),
#    ('know', 'VBP'),
#    ('i', 'NN'),
#    ('am', 'VBP'),
#    ('not', 'RB'),
#    ('the', 'DT'),
#    ('center', 'NN'),
#    ('of', 'IN'),
#    ('the', 'DT'),
#    ('universe', 'NN')]],
#  ["but you keep spinning 'round me just the same",
#   [('but', 'CC'),
#    ('you', 'PRP'),
#    ('keep', 'VBP'),
#    ('spinning', 'VBG'),
#    ("'round", 'IN'),
#    ('me', 'PRP'),
#    ('just', 'RB'),
#    ('the', 'DT'),
#    ('same', 'JJ')]],
#  ['and i drive myself crazy',
#   [('and', 'CC'),
#    ('i', 'VB'),
#    ('drive', 'VBP'),
#    ('myself', 'PRP'),
#    ('crazy', 'JJ')]],
#  ['thinking everything ’ s about me',
#   [('thinking', 'VBG'),
#    ('everything', 'NN'),
#    ('’', 'NN'),
#    ('s', 'NN'),
#    ('about', 'IN'),
#    ('me', 'PRP')]],
#  ['holding on', [('holding', 'VBG'), ('on', 'IN')]],
#  ['why is everything so heavy ?',
#   [('why', 'WRB'),
#    ('is', 'VBZ'),
#    ('everything', 'NN'),
#    ('so', 'RB'),
#    ('heavy', 'JJ'),
#    ('?', '.')]],
#  ['holding on', [('holding', 'VBG'), ('on', 'IN')]],
#  ['so much more than i can carry',
#   [('so', 'RB'),
#    ('much', 'RB'),
#    ('more', 'JJR'),
#    ('than', 'IN'),
#    ('i', 'NN'),
#    ('can', 'MD'),
#    ('carry', 'VB')]],
#  ['i keep dragging around what is bringing me down',
#   [('i', 'JJ'),
#    ('keep', 'VBP'),
#    ('dragging', 'VBG'),
#    ('around', 'IN'),
#    ('what', 'WP'),
#    ('is', 'VBZ'),
#    ('bringing', 'VBG'),
#    ('me', 'PRP'),
#    ('down', 'RP')]],
#  ['if i just let go , i would be set free',
#   [('if', 'IN'),
#    ('i', 'JJ'),
#    ('just', 'RB'),
#    ('let', 'NN'),
#    ('go', 'VB'),
#    (',', ','),
#    ('i', 'VB'),
#    ('would', 'MD'),
#    ('be', 'VB'),
#    ('set', 'VBN'),
#    ('free', 'JJ')]],
#  ['holding on', [('holding', 'VBG'), ('on', 'IN')]],
# ...
#   [('shut', 'VBN'),
#    ('up', 'RP'),
#    ('when', 'WRB'),
#    ('i', 'NN'),
#    ('am', 'VBP'),
#    ('talking', 'VBG'),
#    ('to', 'TO'),
#    ('you', 'PRP')]],
#  ['shut up , shut up , shut up',
#   [('shut', 'VBN'),
#    ('up', 'RP'),
#    (',', ','),
#    ('shut', 'VB'),
#    ('up', 'RP'),
#    (',', ','),
#    ('shut', 'VB'),
#    ('up', 'RP')]],
#  ['shut up when i am talking to you',
#   [('shut', 'VBN'),
#    ('up', 'RP'),
#    ('when', 'WRB'),
#    ('i', 'NN'),
#    ('am', 'VBP'),
#    ('talking', 'VBG'),
#    ('to', 'TO'),
#    ('you', 'PRP')]],
#  ['shut up , shut up , shut up',
#   [('shut', 'VBN'),
#    ('up', 'RP'),
#    (',', ','),
#    ('shut', 'VB'),
#    ('up', 'RP'),
#    (',', ','),
#    ('shut', 'VB'),
#    ('up', 'RP')]],
#  ['shut up , i am about to break !',
#   [('shut', 'VBN'),
#    ('up', 'RP'),
#    (',', ','),
#    ('i', 'RB'),
#    ('am', 'VBP'),
#    ('about', 'IN'),
#    ('to', 'TO'),
#    ('break', 'VB'),
#    ('!', '.')]],
#  ['everything you say to me',
#   [('everything', 'NN'),
#    ('you', 'PRP'),
#    ('say', 'VBP'),
#    ('to', 'TO'),
#    ('me', 'PRP')]],
#  ['takes me one step closer to the edge',
#   [('takes', 'VBZ'),
#    ('me', 'PRP'),
#    ('one', 'CD'),
#    ('step', 'NN'),
#    ('closer', 'RBR'),
#    ('to', 'TO'),
#    ('the', 'DT'),
#    ('edge', 'NN')]],
#  ['and i am about to break',
#   [('and', 'CC'),
#    ('i', 'VB'),
#    ('am', 'VBP'),
#    ('about', 'IN'),
#    ('to', 'TO'),
#    ('break', 'VB')]],
#  ['i need a little room to breathe',
#   [('i', 'NNS'),
#    ('need', 'VBP'),
#    ('a', 'DT'),
#    ('little', 'JJ'),
#    ('room', 'NN'),
#    ('to', 'TO'),
#    ('breathe', 'VB')]],
#  ["'ecause i am one step closer to the edge",
#   [("'ecause", 'IN'),
#    ('i', 'JJ'),
#    ('am', 'VBP'),
#    ('one', 'CD'),
#    ('step', 'NN'),
#    ('closer', 'RBR'),
#    ('to', 'TO'),
#    ('the', 'DT'),
#    ('edge', 'NN')]],
#  ['and i am about to break',
#   [('and', 'CC'),
#    ('i', 'VB'),
#    ('am', 'VBP'),
#    ('about', 'IN'),
#    ('to', 'TO'),
#    ('break', 'VB')]],
#  ['everything you say to me',
#   [('everything', 'NN'),
#    ('you', 'PRP'),
#    ('say', 'VBP'),
#    ('to', 'TO'),
#    ('me', 'PRP')]],
#  ['takes me one step closer to the edge',
#   [('takes', 'VBZ'),
#    ('me', 'PRP'),
#    ('one', 'CD'),
#    ('step', 'NN'),
#    ('closer', 'RBR'),
#    ('to', 'TO'),
#    ('the', 'DT'),
#    ('edge', 'NN')]],
#  ['and i am about to break',
#   [('and', 'CC'),
#    ('i', 'VB'),
#    ('am', 'VBP'),
#    ('about', 'IN'),
#    ('to', 'TO'),
#    ('break', 'VB')]],
#  ['i need a little room to breathe',
#   [('i', 'NNS'),
#    ('need', 'VBP'),
#    ('a', 'DT'),
#    ('little', 'JJ'),
#    ('room', 'NN'),
#    ('to', 'TO'),
#    ('breathe', 'VB')]],
#  ["'ecause i am one step closer to the edge",
#   [("'ecause", 'IN'),
#    ('i', 'JJ'),
#    ('am', 'VBP'),
#    ('one', 'CD'),
#    ('step', 'NN'),
#    ('closer', 'RBR'),
#    ('to', 'TO'),
#    ('the', 'DT'),
#    ('edge', 'NN')]],
#  ['and i am about to , brea',
#   [('and', 'CC'),
#    ('i', 'VB'),
#    ('am', 'VBP'),
#    ('about', 'IN'),
#    ('to', 'TO'),
#    (',', ','),
#    ('brea', 'VB')]],
#  ['', []],
#  ['i close both locks below the window',
#   [('i', 'NN'),
#    ('close', 'VBP'),
#    ('both', 'DT'),
#    ('locks', 'NNS'),
#    ('below', 'IN'),
#    ('the', 'DT'),
#    ('window', 'NN')]],
#  ['i close both blinds and turn away',
#   [('i', 'NN'),
#    ('close', 'VBP'),
#    ('both', 'DT'),
#    ('blinds', 'NNS'),
#    ('and', 'CC'),
#    ('turn', 'VB'),
#    ('away', 'RP')]],
#  ['sometimes solutions are not so simple',
#   [('sometimes', 'RB'),
#    ('solutions', 'NNS'),
#    ('are', 'VBP'),
#    ('not', 'RB'),
#    ('so', 'RB'),
#    ('simple', 'JJ')]],
#  ["sometimes goodbye 's the only way , oh",
#   [('sometimes', 'RB'),
#    ('goodbye', 'NN'),
#    ("'s", 'POS'),
#    ('the', 'DT'),
#    ('only', 'JJ'),
#    ('way', 'NN'),
#    (',', ','),
#    ('oh', 'UH')]],
#  ['and the sun will set for you',
#   [('and', 'CC'),
#    ('the', 'DT'),
#    ('sun', 'NN'),
#    ('will', 'MD'),
#    ('set', 'VB'),
#    ('for', 'IN'),
#    ('you', 'PRP')]],
#  ['the sun will set for you',
#   [('the', 'DT'),
#    ('sun', 'NN'),
#    ('will', 'MD'),
#    ('set', 'VB'),
#    ('for', 'IN'),
#    ('you', 'PRP')]],
#  ['and the shadow of the day',
#   [('and', 'CC'),
#    ('the', 'DT'),
#    ('shadow', 'NN'),
#    ('of', 'IN'),
#    ('the', 'DT'),
#    ('day', 'NN')]],
#  ['will embrace the world in gray',
#   [('will', 'MD'),
#    ('embrace', 'VB'),
#    ('the', 'DT'),
#    ('world', 'NN'),
#    ('in', 'IN'),
#    ('gray', 'NN')]],
#  ['and the sun will set for you',
#   [('and', 'CC'),
#    ('the', 'DT'),
#    ('sun', 'NN'),
#    ('will', 'MD'),
#    ('set', 'VB'),
#    ('for', 'IN'),
#    ('you', 'PRP')]],
#  ['in cards and flowers on your window',
#   [('in', 'IN'),
#    ('cards', 'NNS'),
#    ('and', 'CC'),
#    ('flowers', 'NNS'),
#    ('on', 'IN'),
#    ('your', 'PRP$'),
#    ('window', 'NN')]],
#  ['your friends all plead for you to stay',
#   [('your', 'PRP$'),
#    ('friends', 'NNS'),
#    ('all', 'DT'),
#    ('plead', 'VBP'),
#    ('for', 'IN'),
#    ('you', 'PRP'),
#    ('to', 'TO'),
#    ('stay', 'VB')]],
#  ['sometimes beginnings are not so simple',
#   [('sometimes', 'RB'),
#    ('beginnings', 'NNS'),
#    ('are', 'VBP'),
#    ('not', 'RB'),
#    ('so', 'RB'),
#    ('simple', 'JJ')]],
#  ["sometimes goodbye 's the only way , oh",
#   [('sometimes', 'RB'),
#    ('goodbye', 'NN'),
#    ("'s", 'POS'),
#    ('the', 'DT'),
#    ('only', 'JJ'),
#    ('way', 'NN'),
#    (',', ','),
#    ('oh', 'UH')]],
#  ['and the sun will set for you',
#   [('and', 'CC'),
#    ('the', 'DT'),
#    ('sun', 'NN'),
#    ('will', 'MD'),
#    ('set', 'VB'),
#    ('for', 'IN'),
#    ('you', 'PRP')]],
#  ['the sun will set for you',
#   [('the', 'DT'),
#    ('sun', 'NN'),
#    ('will', 'MD'),
#    ('set', 'VB'),
#    ('for', 'IN'),
#    ('you', 'PRP')]],
#  ['and the shadow of the day',
#   [('and', 'CC'),
#    ('the', 'DT'),
#    ('shadow', 'NN'),
#    ('of', 'IN'),
#    ('the', 'DT'),
#    ('day', 'NN')]],
#  ['will embrace the world in gray',
#   [('will', 'MD'),
#    ('embrace', 'VB'),
#    ('the', 'DT'),
#    ('world', 'NN'),
#    ('in', 'IN'),
#    ('gray', 'NN')]],
#  ['and the sun will set for you',
#   [('and', 'CC'),
#    ('the', 'DT'),
#    ('sun', 'NN'),
#    ('will', 'MD'),
#    ('set', 'VB'),
#    ('for', 'IN'),
#    ('you', 'PRP')]],
#  ['and the shadow of the day',
#   [('and', 'CC'),
#    ('the', 'DT'),
#    ('shadow', 'NN'),
#    ('of', 'IN'),
#    ('the', 'DT'),
#    ('day', 'NN')]],
#  ['will embrace the world in gray',
#   [('will', 'MD'),
#    ('embrace', 'VB'),
#    ('the', 'DT'),
#    ('world', 'NN'),
#    ('in', 'IN'),
#    ('gray', 'NN')]],
#  ['and the sun will set for you',
#   [('and', 'CC'),
#    ('the', 'DT'),
#    ('sun', 'NN'),
#    ('will', 'MD'),
#    ('set', 'VB'),
#    ('for', 'IN'),
#    ('you', 'PRP')]],
#  ['and the shadow of the day',
#   [('and', 'CC'),
#    ('the', 'DT'),
#    ('shadow', 'NN'),
#    ('of', 'IN'),
#    ('the', 'DT'),
#    ('day', 'NN')]],
#  ['will embrace the world in gray',
#   [('will', 'MD'),
#    ('embrace', 'VB'),
#    ('the', 'DT'),
#    ('world', 'NN'),
#    ('in', 'IN'),
#    ('gray', 'NN')]],
#  ['and the sun will set for you',
#   [('and', 'CC'),
#    ('the', 'DT'),
#    ('sun', 'NN'),
#    ('will', 'MD'),
#    ('set', 'VB'),
#    ('for', 'IN'),
#    ('you', 'PRP')]],
#  ['', []],
#  ['', []],
#  ['i am a little bit of loneliness , a little bit of disregard',
#   [('i', 'NN'),
#    ('am', 'VBP'),
#    ('a', 'DT'),
#    ('little', 'JJ'),
#    ('bit', 'NN'),
#    ('of', 'IN'),
#    ('loneliness', 'NN'),
#    (',', ','),
#    ('a', 'DT'),
#    ('little', 'JJ'),
#    ('bit', 'NN'),
#    ('of', 'IN'),
#    ('disregard', 'NN')]],
#  ['handful of complaints but i can not help the fact',
#   [('handful', 'NN'),
#    ('of', 'IN'),
#    ('complaints', 'NNS'),
#    ('but', 'CC'),
#    ('i', 'NNS'),
#    ('can', 'MD'),
#    ('not', 'RB'),
#    ('help', 'VB'),
#    ('the', 'DT'),
#    ('fact', 'NN')]],
#  ['that everyone can see these scars',
#   [('that', 'IN'),
#    ('everyone', 'NN'),
#    ('can', 'MD'),
#    ('see', 'VB'),
#    ('these', 'DT'),
#    ('scars', 'NNS')]],
#  ['i am what i want you to want , what i want you to feel',
#   [('i', 'NN'),
#    ('am', 'VBP'),
#    ('what', 'WP'),
#    ('i', 'NN'),
#    ('want', 'VBP'),
#    ('you', 'PRP'),
#    ('to', 'TO'),
#    ('want', 'VB'),
#    (',', ','),
#    ('what', 'WP'),
#    ('i', 'VBZ'),
#    ('want', 'VBP'),
#    ('you', 'PRP'),
#    ('to', 'TO'),
#    ('feel', 'VB')]],
#  ['but it is like no matter what i do , i can not convince you',
#   [('but', 'CC'),
#    ('it', 'PRP'),
#    ('is', 'VBZ'),
#    ('like', 'IN'),
#    ('no', 'DT'),
#    ('matter', 'NN'),
#    ('what', 'WP'),
#    ('i', 'VBZ'),
#    ('do', 'VBP'),
#    (',', ','),
#    ('i', 'VB'),
#    ('can', 'MD'),
#    ('not', 'RB'),
#    ('convince', 'VB'),
#    ('you', 'PRP')]],
#  ['to just believe this is real',
#   [('to', 'TO'),
#    ('just', 'RB'),
#    ('believe', 'VB'),
#    ('this', 'DT'),
#    ('is', 'VBZ'),
#    ('real', 'JJ')]],
#  ['so i , let go watching you turn your back like you always do',
#   [('so', 'RB'),
#    ('i', 'JJ'),
#    (',', ','),
#    ('let', 'VB'),
#    ('go', 'VB'),
#    ('watching', 'VBG'),
#    ('you', 'PRP'),
#    ('turn', 'VBP'),
#    ('your', 'PRP$'),
#    ('back', 'RP'),
#    ('like', 'IN'),
#    ('you', 'PRP'),
#    ('always', 'RB'),
#    ('do', 'VBP')]],
#  ['face away and pretend i am not',
#   [('face', 'NN'),
#    ('away', 'RB'),
#    ('and', 'CC'),
#    ('pretend', 'VBP'),
#    ('i', 'NN'),
#    ('am', 'VBP'),
#    ('not', 'RB')]],
#  ["but i will be here 'ecause you are all that i have got",
#   [('but', 'CC'),
#    ('i', 'NN'),
#    ('will', 'MD'),
#    ('be', 'VB'),
#    ('here', 'RB'),
#    ("'ecause", 'IN'),
#    ('you', 'PRP'),
#    ('are', 'VBP'),
#    ('all', 'PDT'),
#    ('that', 'IN'),
#    ('i', 'NNS'),
#    ('have', 'VBP'),
#    ('got', 'VBN')]],
#  ['i can not feel the way i did before',
#   [('i', 'NN'),
#    ('can', 'MD'),
#    ('not', 'RB'),
#    ('feel', 'VB'),
#    ('the', 'DT'),
#    ('way', 'NN'),
#    ('i', 'NN'),
#    ('did', 'VBD'),
#    ('before', 'IN')]],
#  ['do not turn your back on me',
#   [('do', 'VB'),
#    ('not', 'RB'),
#    ('turn', 'VB'),
#    ('your', 'PRP$'),
#    ('back', 'NN'),
#    ('on', 'IN'),
#    ('me', 'PRP')]],
#  ['i will not be ignored',
#   [('i', 'NN'),
#    ('will', 'MD'),
#    ('not', 'RB'),
#    ('be', 'VB'),
#    ('ignored', 'VBN')]],
#  ['time will not heal this damage anymore',
#   [('time', 'NN'),
#    ('will', 'MD'),
#    ('not', 'RB'),
#    ('heal', 'VB'),
#    ('this', 'DT'),
#    ('damage', 'NN'),
#    ('anymore', 'RB')]],
#  ['do not turn your back on me i will not be ignored',
#   [('do', 'VB'),
#    ('not', 'RB'),
#    ('turn', 'VB'),
#    ('your', 'PRP$'),
#    ('back', 'NN'),
#    ('on', 'IN'),
#    ('me', 'PRP'),
#    ('i', 'VB'),
#    ('will', 'MD'),
#    ('not', 'RB'),
#    ('be', 'VB'),
#    ('ignored', 'VBN')]],
#  ['i am , a little bit insecure , a little unconfident',
#   [('i', 'NN'),
#    ('am', 'VBP'),
#    (',', ','),
#    ('a', 'DT'),
#    ('little', 'JJ'),
#    ('bit', 'NN'),
#    ('insecure', 'NN'),
#    (',', ','),
#    ('a', 'DT'),
#    ('little', 'JJ'),
#    ('unconfident', 'JJ')]],
#  ["'ecause you do not understand i do what i can",
#   [("'ecause", 'IN'),
#    ('you', 'PRP'),
#    ('do', 'VBP'),
#    ('not', 'RB'),
#    ('understand', 'VB'),
#    ('i', 'NN'),
#    ('do', 'VBP'),
#    ('what', 'WP'),
#    ('i', 'VB'),
#    ('can', 'MD')]],
#  ['but sometimes i do not make sense',
#   [('but', 'CC'),
#    ('sometimes', 'RB'),
#    ('i', 'VB'),
#    ('do', 'VBP'),
#    ('not', 'RB'),
#    ('make', 'VB'),
#    ('sense', 'NN')]],
#  ['i am , what you never want to say , but i have never had a doubt',
#   [('i', 'NN'),
#    ('am', 'VBP'),
#    (',', ','),
#    ('what', 'WP'),
#    ('you', 'PRP'),
#    ('never', 'RB'),
#    ('want', 'VBP'),
#    ('to', 'TO'),
#    ('say', 'VB'),
#    (',', ','),
#    ('but', 'CC'),
#    ('i', 'NNS'),
#    ('have', 'VBP'),
#    ('never', 'RB'),
#    ('had', 'VBD'),
#    ('a', 'DT'),
#    ('doubt', 'NN')]],
#  ['it is like no matter what i do i can not convince you for once just to hear me out',
#   [('it', 'PRP'),
#    ('is', 'VBZ'),
#    ('like', 'IN'),
#    ('no', 'DT'),
#    ('matter', 'NN'),
#    ('what', 'WP'),
#    ('i', 'VBZ'),
#    ('do', 'VBP'),
#    ('i', 'NNS'),
#    ('can', 'MD'),
#    ('not', 'RB'),
#    ('convince', 'VB'),
#    ('you', 'PRP'),
#    ('for', 'IN'),
#    ('once', 'RB'),
#    ('just', 'RB'),
#    ('to', 'TO'),
#    ('hear', 'VB'),
#    ('me', 'PRP'),
#    ('out', 'RP')]],
#  ['so i , let go watching you turn your back like you always do',
#   [('so', 'RB'),
#    ('i', 'JJ'),
#    (',', ','),
#    ('let', 'VB'),
#    ('go', 'VB'),
#    ('watching', 'VBG'),
#    ('you', 'PRP'),
#    ('turn', 'VBP'),
#    ('your', 'PRP$'),
#    ('back', 'RP'),
#    ('like', 'IN'),
#    ('you', 'PRP'),
#    ('always', 'RB'),
#    ('do', 'VBP')]],
#  ['you face away and pretend i am not',
#   [('you', 'PRP'),
#    ('face', 'VBP'),
#    ('away', 'RB'),
#    ('and', 'CC'),
#    ('pretend', 'VBP'),
#    ('i', 'NN'),
#    ('am', 'VBP'),
#    ('not', 'RB')]],
#  ["but i will be here 'ecause you are all that i have got",
#   [('but', 'CC'),
#    ('i', 'NN'),
#    ('will', 'MD'),
#    ('be', 'VB'),
#    ('here', 'RB'),
#    ("'ecause", 'IN'),
#    ('you', 'PRP'),
#    ('are', 'VBP'),
#    ('all', 'PDT'),
#    ('that', 'IN'),
#    ('i', 'NNS'),
#    ('have', 'VBP'),
#    ('got', 'VBN')]],
#  ['i can not feel the way i did before',
#   [('i', 'NN'),
#    ('can', 'MD'),
#    ('not', 'RB'),
#    ('feel', 'VB'),
#    ('the', 'DT'),
#    ('way', 'NN'),
#    ('i', 'NN'),
#    ('did', 'VBD'),
#    ('before', 'IN')]],
#  ['do not turn your back on me',
#   [('do', 'VB'),
#    ('not', 'RB'),
#    ('turn', 'VB'),
#    ('your', 'PRP$'),
#    ('back', 'NN'),
#    ('on', 'IN'),
#    ('me', 'PRP')]],
#  ['i will not be ignored',
#   [('i', 'NN'),
#    ('will', 'MD'),
#    ('not', 'RB'),
#    ('be', 'VB'),
#    ('ignored', 'VBN')]],
#  ['time will not heal this damage anymore',
#   [('time', 'NN'),
#    ('will', 'MD'),
#    ('not', 'RB'),
#    ('heal', 'VB'),
#    ('this', 'DT'),
#    ('damage', 'NN'),
#    ('anymore', 'RB')]],
#  ['do not turn your back on me i will not be ignored',
#   [('do', 'VB'),
#    ('not', 'RB'),
#    ('turn', 'VB'),
#    ('your', 'PRP$'),
#    ('back', 'NN'),
#    ('on', 'IN'),
#    ('me', 'PRP'),
#    ('i', 'VB'),
#    ('will', 'MD'),
#    ('not', 'RB'),
#    ('be', 'VB'),
#    ('ignored', 'VBN')]],
#  ['you hear me out now',
#   [('you', 'PRP'),
#    ('hear', 'VBP'),
#    ('me', 'PRP'),
#    ('out', 'RP'),
#    ('now', 'RB')]],
#  ['you are gon na listen to me like it or not',
#   [('you', 'PRP'),
#    ('are', 'VBP'),
#    ('gon', 'VBG'),
#    ('na', 'TO'),
#    ('listen', 'VB'),
#    ('to', 'TO'),
#    ('me', 'PRP'),
#    ('like', 'IN'),
#    ('it', 'PRP'),
#    ('or', 'CC'),
#    ('not', 'RB')]],
#  ['right now , hear me out now',
#   [('right', 'RB'),
#    ('now', 'RB'),
#    (',', ','),
#    ('hear', 'VB'),
#    ('me', 'PRP'),
#    ('out', 'RP'),
#    ('now', 'RB')]],
#  ['you are gon na listen to me like it or not',
#   [('you', 'PRP'),
#    ('are', 'VBP'),
#    ('gon', 'VBG'),
#    ('na', 'TO'),
#    ('listen', 'VB'),
#    ('to', 'TO'),
#    ('me', 'PRP'),
#    ('like', 'IN'),
#    ('it', 'PRP'),
#    ('or', 'CC'),
#    ('not', 'RB')]],
#  ['right now', [('right', 'RB'), ('now', 'RB')]],
#  ['i can not feel the way i did before',
#   [('i', 'NN'),
#    ('can', 'MD'),
#    ('not', 'RB'),
#    ('feel', 'VB'),
#    ('the', 'DT'),
#    ('way', 'NN'),
#    ('i', 'NN'),
#    ('did', 'VBD'),
#    ('before', 'IN')]],
#  ['do not turn your back on me',
#   [('do', 'VB'),
#    ('not', 'RB'),
#    ('turn', 'VB'),
#    ('your', 'PRP$'),
#    ('back', 'NN'),
#    ('on', 'IN'),
#    ('me', 'PRP')]],
#  ['i will not be ignored',
#   [('i', 'NN'),
#    ('will', 'MD'),
#    ('not', 'RB'),
#    ('be', 'VB'),
#    ('ignored', 'VBN')]],
#  ['time will not heal this damage anymore',
#   [('time', 'NN'),
#    ('will', 'MD'),
#    ('not', 'RB'),
#    ('heal', 'VB'),
#    ('this', 'DT'),
#    ('damage', 'NN'),
#    ('anymore', 'RB')]],
#  ['do not turn your back on me i will not be ignored',
#   [('do', 'VB'),
#    ('not', 'RB'),
#    ('turn', 'VB'),
#    ('your', 'PRP$'),
#    ('back', 'NN'),
#    ('on', 'IN'),
#    ('me', 'PRP'),
#    ('i', 'VB'),
#    ('will', 'MD'),
#    ('not', 'RB'),
#    ('be', 'VB'),
#    ('ignored', 'VBN')]],
#  ['i can not feel',
#   [('i', 'NN'), ('can', 'MD'), ('not', 'RB'), ('feel', 'VB')]],
#  ['do not turn your back on me',
#   [('do', 'VB'),
#    ('not', 'RB'),
#    ('turn', 'VB'),
#    ('your', 'PRP$'),
#    ('back', 'NN'),
#    ('on', 'IN'),
#    ('me', 'PRP')]],
#  ['i will not be ignored',
#   [('i', 'NN'),
#    ('will', 'MD'),
#    ('not', 'RB'),
#    ('be', 'VB'),
#    ('ignored', 'VBN')]],
#  ['time will not heal',
#   [('time', 'NN'), ('will', 'MD'), ('not', 'RB'), ('heal', 'VB')]],
#  ['do not turn your back on me i will not be ignored',
#   [('do', 'VB'),
#    ('not', 'RB'),
#    ('turn', 'VB'),
#    ('your', 'PRP$'),
#    ('back', 'NN'),
#    ('on', 'IN'),
#    ('me', 'PRP'),
#    ('i', 'VB'),
#    ('will', 'MD'),
#    ('not', 'RB'),
#    ('be', 'VB'),
#    ('ignored', 'VBN')]]]

# %%
tree_list = []
str_4_sng = ''

for _ in range(2, len(pos_tag_res)):
    print("Iteration: ", str(_), end='\n')
    print(pos_tag_res[_][1], end='\n\n')
    
    if (pos_tag_res[_][1][_2] is None):
        tree_list.append(str_4_sng)
    
    for _2 in range(len(pos_tag_res[_][1])):
        print(pos_tag_res[_][1][_2][1])
        str_4_sng = str_4_sng + ' ' + pos_tag_res[_][1][_2][1]
    str_4_sng = str_4_sng + '. '
        
    print()
# Out:
# Iteration:  2
# [('i', 'NN'), ('am', 'VBP'), ('tired', 'VBN'), ('of', 'IN'), ('being', 'VBG'), ('what', 'WP'), ('you', 'PRP'), ('want', 'VBP'), ('me', 'PRP'), ('to', 'TO'), ('be', 'VB')]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-24-e53024ecc4f9> in <module>()
#       6     print(pos_tag_res[_][1], end='\n\n')
#       7
# ----> 8     if (pos_tag_res[_][1][_2] is None):
#       9         tree_list.append(str_4_sng)
#      10
#
# IndexError: list index out of range

# %%
tree_list
# Out:
# []

# %%
cleaned_lyrics = [['Text', 'Expanded', 'Cleaned']]

for _ in linkin_park[3][1].split('\n'):
    print(TextCleaner.remove_stopwords(nltk.word_tokenize(TextCleaner.expand_contractions(_, CONTRACTION_MAP))))
    _text = _.lower()
    clnd_txt = TextCleaner.remove_stopwords(nltk.word_tokenize(TextCleaner.expand_contractions(_text, CONTRACTION_MAP)))
    expnded_txt = nltk.word_tokenize(TextCleaner.expand_contractions(_text, CONTRACTION_MAP))
    cleaned_lyrics.append([_text, expnded_txt, clnd_txt])
#     _))
