with open('lp_lyrics_list.pkl', 'wb') as f:
    pickle.dump(linkin_park, f)

# %%
import re
import string

from contractions import CONTRACTION_MAP

import nltk

from textstat.textstat import textstat

import obo

from textblob import TextBlob

import preprocessor as p

# %%
class TextCleaner:
    '''Cleans text for Analysis.'''
    
    def __init__(self):
        pass
    
    def remove_characters_before_tokenization(sentence,
         keep_apostrophes=False):
        
         '''
         remove_characters_before_tokenization('Test sentence 1 2 3 4 @')
         >>> Test sentence 1 2 3 4
         '''
        
         sentence = sentence.strip()
         if keep_apostrophes:
             PATTERN = r'[?|$|&|*|%|@|(|)|~]' # add other characters here to remove them
             filtered_sentence = re.sub(PATTERN, r'', sentence)
         else:
             PATTERN = r'[^a-zA-Z0-9 ]' # only extract alpha-numeric characters
             filtered_sentence = re.sub(PATTERN, r'', sentence)
         return filtered_sentence 
    
    def expand_contractions(sentence, contraction_mapping):
         '''
          expand_contractions("This is a test sentence. But this isn't one. hasn't she hearten?", CONTRACTION_MAP)
          >>> This is a test sentence. But this is not one. has not she hearten?
         '''
         contractions_pattern = re.compile('({})'.format('|'.join(contraction_mapping.keys())),
         flags=re.IGNORECASE|re.DOTALL)
            
         def expand_match(contraction):
             match = contraction.group(0)
             first_char = match[0]
             expanded_contraction = contraction_mapping.get(match)\
                 if contraction_mapping.get(match)\
                 else contraction_mapping.get(match.lower())
             expanded_contraction = first_char+expanded_contraction[1:]
             return expanded_contraction
         expanded_sentence = contractions_pattern.sub(expand_match, sentence)
         return expanded_sentence 
        
    def remove_stopwords(tokens):
         '''
        remove_stopwords(nltk.word_tokenize("This is a test sentence. But this isn't one. hasn't she hearten?".lower()))
        >>> ['test', 'sentence', '.', "n't", 'one', '.', "n't", 'hearten', '?']
         '''
         stopword_list = nltk.corpus.stopwords.words('english')
         filtered_tokens = [token for token in tokens if token not in stopword_list]
         return filtered_tokens 
        
    def stat_text_analysis(test_data):
        '''
        Returns list of statistical text test results.
        '''
        fre = textstat.flesch_reading_ease(test_data)
        si = textstat.smog_index(test_data)
        fkg = textstat.flesch_kincaid_grade(test_data)
        cli = textstat.coleman_liau_index(test_data)
        ari = textstat.automated_readability_index(test_data)
        dcri = textstat.dale_chall_readability_score(test_data)
        dw = textstat.difficult_words(test_data)
        lwf = textstat.linsear_write_formula(test_data)
        gf = textstat.gunning_fog(test_data)
        ts = textstat.text_standard(test_data)
        
        return ([
            ['fre', fre],
            ['si', si],
            ['fkg', fkg],
            ['cli', cli],
            ['ari', ari],
            ['dcri', dcri],
            ['dw', dw],
            ['lwf', lwf],
            ['gf', gf],
            ['ts', ts],            
                ])
    
    def word_freq_pair(wordstring):
        '''
        print((word_freq_pair('this is a test sentence is is is.')))
        [('this', 1), ('is', 3), ('a', 1), ('test', 1), ('sentence', 1), ('is', 3), ('is', 3), ('is.', 1)]
        '''
        wordlist = wordstring.split()

        wordfreq = []

        for w in wordlist:
            wordfreq.append(wordlist.count(w))

        return list(zip(wordlist, wordfreq))
    
    
    def removeStopwords(wordlist):
        '''
        removeStopwords("this is a test sentence.".split(" "))
        >>> ['test', 'sentence.']
        '''
        return [w for w in wordlist if w not in nltk.corpus.stopwords.words('english')]
    
    
    

    def nGramsToKWICDict(ngrams):
        '''
        ngrams = obo.getNGrams('this test sentence has eight words in it'.split(), 5)
        print(ngrams)
        >>> [['this', 'test', 'sentence', 'has', 'eight'],
             ['test', 'sentence', 'has', 'eight', 'words'],
             ['sentence', 'has', 'eight', 'words', 'in'],
             ['has', 'eight', 'words', 'in', 'it']]
        '''
        keyindex = len(ngrams[0]) // 2

        return keyindex
    
    
    def nGramsToKWICDict(ngrams):
        '''
        print(nGramsToKWICDict(
                             [['this', 'test', 'sentence', 'has', 'eight'],
                             ['test', 'sentence', 'has', 'eight', 'words'],
                             ['sentence', 'has', 'eight', 'words', 'in'],
                             ['has', 'eight', 'words', 'in', 'it']]
                             ))
                             
        >>> {'words': [['has', 'eight', 'words', 'in', 'it']], 
            'sentence': [['this', 'test', 'sentence', 'has', 'eight']], 
            'has': [['test', 'sentence', 'has', 'eight', 'words']], 
            'eight': [['sentence', 'has', 'eight', 'words', 'in']]}
        
        '''
        keyindex = len(ngrams[0]) // 2

        kwicdict = {}

        for k in ngrams:
            if k[keyindex] not in kwicdict:
                kwicdict[k[keyindex]] = [k]
            else:
                kwicdict[k[keyindex]].append(k)
        return kwicdict
    
    def get_n_grams(allMyWords, n):
        return obo.getNGrams(allMyWords, n)
    
    def getNGrams(wordlist, n):
        '''
        tNGrams(test2.split(), 5)
        # -> [['this', 'test', 'sentence', 'has', 'eight'],
        # ['test', 'sentence', 'has', 'eight', 'words'],
        # ['sentence', 'has', 'eight', 'words', 'in'],
        # ['has', 'eight', 'words', 'in', 'it']]
        '''
        ngrams = []
        for i in range(len(wordlist)-(n-1)):
            ngrams.append(wordlist[i:i+n])
        return ngrams
    
    
    
    def clean_tweet(tweet):
        '''
        Utility function to clean the text in a tweet by removing 
        links and special characters using regex.
        '''
        return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

    def analize_sentiment(tweet):
        '''
        Utility function to classify the polarity of a tweet
        using textblob.
        '''
        analysis = TextBlob(clean_tweet(tweet))
        if analysis.sentiment.polarity > 0:
            return 1
        elif analysis.sentiment.polarity == 0:
            return 0
        else:
            return -1
        
    def cln_twt(twt):
        return p.clean(twt)
    
    def tkn_twt(twt):
        return p.tokenize(twt)
    
    def prs_twt(twt):
        return p.parse(twt)

# %%
# 5 not done

cleaned_lyrics = [['Text', 'Expanded', 'Cleaned']]

for _ in linkin_park[16][1].split('\n'):
#     print(TextCleaner.remove_stopwords(nltk.word_tokenize(TextCleaner.expand_contractions(_, CONTRACTION_MAP))))
    _text = _.lower()
    clnd_txt = TextCleaner.remove_stopwords(nltk.word_tokenize(TextCleaner.expand_contractions(_text, CONTRACTION_MAP)))
    expnded_txt = nltk.word_tokenize(TextCleaner.expand_contractions(_text, CONTRACTION_MAP))
    cleaned_lyrics.append([_text, expnded_txt, clnd_txt])
#     _))


import nltk

pos_tag_res = ['Tagged Entries']

for _ in range(1, len(cleaned_lyrics)):
    text = nltk.pos_tag(cleaned_lyrics[_][1])
#     print(cleaned_lyrics[_][1])
    pos_tag_res.append([' '.join(cleaned_lyrics[_][1]), text])
    

tree_list = []
str_4_sng = ''

for _ in range(2, len(pos_tag_res)):
#     print("Iteration: ", str(_), end='\n')
    print(pos_tag_res[_][1], end='\n\n')
    
    for _2 in range(len(pos_tag_res[_][1])):
#         print(pos_tag_res[_][1][_2][1])
        str_4_sng = str_4_sng + ' ' + pos_tag_res[_][1][_2][1]
    str_4_sng = str_4_sng + '. '
        
#     print()


# str_4_sng
# Out:
# [('i', 'NN'), ('am', 'VBP'), ('a', 'DT'), ('little', 'JJ'), ('bit', 'NN'), ('of', 'IN'), ('loneliness', 'NN'), (',', ','), ('a', 'DT'), ('little', 'JJ'), ('bit', 'NN'), ('of', 'IN'), ('disregard', 'NN')]
#
# [('handful', 'NN'), ('of', 'IN'), ('complaints', 'NNS'), ('but', 'CC'), ('i', 'NNS'), ('can', 'MD'), ('not', 'RB'), ('help', 'VB'), ('the', 'DT'), ('fact', 'NN')]
#
# [('that', 'IN'), ('everyone', 'NN'), ('can', 'MD'), ('see', 'VB'), ('these', 'DT'), ('scars', 'NNS')]
#
# [('i', 'NN'), ('am', 'VBP'), ('what', 'WP'), ('i', 'NN'), ('want', 'VBP'), ('you', 'PRP'), ('to', 'TO'), ('want', 'VB'), (',', ','), ('what', 'WP'), ('i', 'VBZ'), ('want', 'VBP'), ('you', 'PRP'), ('to', 'TO'), ('feel', 'VB')]
#
# [('but', 'CC'), ('it', 'PRP'), ('is', 'VBZ'), ('like', 'IN'), ('no', 'DT'), ('matter', 'NN'), ('what', 'WP'), ('i', 'VBZ'), ('do', 'VBP'), (',', ','), ('i', 'VB'), ('can', 'MD'), ('not', 'RB'), ('convince', 'VB'), ('you', 'PRP')]
#
# [('to', 'TO'), ('just', 'RB'), ('believe', 'VB'), ('this', 'DT'), ('is', 'VBZ'), ('real', 'JJ')]
#
# [('so', 'RB'), ('i', 'JJ'), (',', ','), ('let', 'VB'), ('go', 'VB'), ('watching', 'VBG'), ('you', 'PRP'), ('turn', 'VBP'), ('your', 'PRP$'), ('back', 'RP'), ('like', 'IN'), ('you', 'PRP'), ('always', 'RB'), ('do', 'VBP')]
#
# [('face', 'NN'), ('away', 'RB'), ('and', 'CC'), ('pretend', 'VBP'), ('i', 'NN'), ('am', 'VBP'), ('not', 'RB')]
#
# [('but', 'CC'), ('i', 'NN'), ('will', 'MD'), ('be', 'VB'), ('here', 'RB'), ("'ecause", 'IN'), ('you', 'PRP'), ('are', 'VBP'), ('all', 'PDT'), ('that', 'IN'), ('i', 'NNS'), ('have', 'VBP'), ('got', 'VBN')]
#
# [('i', 'NN'), ('can', 'MD'), ('not', 'RB'), ('feel', 'VB'), ('the', 'DT'), ('way', 'NN'), ('i', 'NN'), ('did', 'VBD'), ('before', 'IN')]
#
# [('do', 'VB'), ('not', 'RB'), ('turn', 'VB'), ('your', 'PRP$'), ('back', 'NN'), ('on', 'IN'), ('me', 'PRP')]
#
# [('i', 'NN'), ('will', 'MD'), ('not', 'RB'), ('be', 'VB'), ('ignored', 'VBN')]
#
# [('time', 'NN'), ('will', 'MD'), ('not', 'RB'), ('heal', 'VB'), ('this', 'DT'), ('damage', 'NN'), ('anymore', 'RB')]
#
# [('do', 'VB'), ('not', 'RB'), ('turn', 'VB'), ('your', 'PRP$'), ('back', 'NN'), ('on', 'IN'), ('me', 'PRP'), ('i', 'VB'), ('will', 'MD'), ('not', 'RB'), ('be', 'VB'), ('ignored', 'VBN')]
#
# [('i', 'NN'), ('am', 'VBP'), (',', ','), ('a', 'DT'), ('little', 'JJ'), ('bit', 'NN'), ('insecure', 'NN'), (',', ','), ('a', 'DT'), ('little', 'JJ'), ('unconfident', 'JJ')]
#
# [("'ecause", 'IN'), ('you', 'PRP'), ('do', 'VBP'), ('not', 'RB'), ('understand', 'VB'), ('i', 'NN'), ('do', 'VBP'), ('what', 'WP'), ('i', 'VB'), ('can', 'MD')]
#
# [('but', 'CC'), ('sometimes', 'RB'), ('i', 'VB'), ('do', 'VBP'), ('not', 'RB'), ('make', 'VB'), ('sense', 'NN')]
#
# [('i', 'NN'), ('am', 'VBP'), (',', ','), ('what', 'WP'), ('you', 'PRP'), ('never', 'RB'), ('want', 'VBP'), ('to', 'TO'), ('say', 'VB'), (',', ','), ('but', 'CC'), ('i', 'NNS'), ('have', 'VBP'), ('never', 'RB'), ('had', 'VBD'), ('a', 'DT'), ('doubt', 'NN')]
#
# [('it', 'PRP'), ('is', 'VBZ'), ('like', 'IN'), ('no', 'DT'), ('matter', 'NN'), ('what', 'WP'), ('i', 'VBZ'), ('do', 'VBP'), ('i', 'NNS'), ('can', 'MD'), ('not', 'RB'), ('convince', 'VB'), ('you', 'PRP'), ('for', 'IN'), ('once', 'RB'), ('just', 'RB'), ('to', 'TO'), ('hear', 'VB'), ('me', 'PRP'), ('out', 'RP')]
#
# [('so', 'RB'), ('i', 'JJ'), (',', ','), ('let', 'VB'), ('go', 'VB'), ('watching', 'VBG'), ('you', 'PRP'), ('turn', 'VBP'), ('your', 'PRP$'), ('back', 'RP'), ('like', 'IN'), ('you', 'PRP'), ('always', 'RB'), ('do', 'VBP')]
#
# [('you', 'PRP'), ('face', 'VBP'), ('away', 'RB'), ('and', 'CC'), ('pretend', 'VBP'), ('i', 'NN'), ('am', 'VBP'), ('not', 'RB')]
#
# [('but', 'CC'), ('i', 'NN'), ('will', 'MD'), ('be', 'VB'), ('here', 'RB'), ("'ecause", 'IN'), ('you', 'PRP'), ('are', 'VBP'), ('all', 'PDT'), ('that', 'IN'), ('i', 'NNS'), ('have', 'VBP'), ('got', 'VBN')]
#
# [('i', 'NN'), ('can', 'MD'), ('not', 'RB'), ('feel', 'VB'), ('the', 'DT'), ('way', 'NN'), ('i', 'NN'), ('did', 'VBD'), ('before', 'IN')]
#
# [('do', 'VB'), ('not', 'RB'), ('turn', 'VB'), ('your', 'PRP$'), ('back', 'NN'), ('on', 'IN'), ('me', 'PRP')]
#
# [('i', 'NN'), ('will', 'MD'), ('not', 'RB'), ('be', 'VB'), ('ignored', 'VBN')]
#
# [('time', 'NN'), ('will', 'MD'), ('not', 'RB'), ('heal', 'VB'), ('this', 'DT'), ('damage', 'NN'), ('anymore', 'RB')]
#
# [('do', 'VB'), ('not', 'RB'), ('turn', 'VB'), ('your', 'PRP$'), ('back', 'NN'), ('on', 'IN'), ('me', 'PRP'), ('i', 'VB'), ('will', 'MD'), ('not', 'RB'), ('be', 'VB'), ('ignored', 'VBN')]
#
# [('you', 'PRP'), ('hear', 'VBP'), ('me', 'PRP'), ('out', 'RP'), ('now', 'RB')]
#
# [('you', 'PRP'), ('are', 'VBP'), ('gon', 'VBG'), ('na', 'TO'), ('listen', 'VB'), ('to', 'TO'), ('me', 'PRP'), ('like', 'IN'), ('it', 'PRP'), ('or', 'CC'), ('not', 'RB')]
#
# [('right', 'RB'), ('now', 'RB'), (',', ','), ('hear', 'VB'), ('me', 'PRP'), ('out', 'RP'), ('now', 'RB')]
#
# [('you', 'PRP'), ('are', 'VBP'), ('gon', 'VBG'), ('na', 'TO'), ('listen', 'VB'), ('to', 'TO'), ('me', 'PRP'), ('like', 'IN'), ('it', 'PRP'), ('or', 'CC'), ('not', 'RB')]
#
# [('right', 'RB'), ('now', 'RB')]
#
# [('i', 'NN'), ('can', 'MD'), ('not', 'RB'), ('feel', 'VB'), ('the', 'DT'), ('way', 'NN'), ('i', 'NN'), ('did', 'VBD'), ('before', 'IN')]
#
# [('do', 'VB'), ('not', 'RB'), ('turn', 'VB'), ('your', 'PRP$'), ('back', 'NN'), ('on', 'IN'), ('me', 'PRP')]
#
# [('i', 'NN'), ('will', 'MD'), ('not', 'RB'), ('be', 'VB'), ('ignored', 'VBN')]
#
# [('time', 'NN'), ('will', 'MD'), ('not', 'RB'), ('heal', 'VB'), ('this', 'DT'), ('damage', 'NN'), ('anymore', 'RB')]
#
# [('do', 'VB'), ('not', 'RB'), ('turn', 'VB'), ('your', 'PRP$'), ('back', 'NN'), ('on', 'IN'), ('me', 'PRP'), ('i', 'VB'), ('will', 'MD'), ('not', 'RB'), ('be', 'VB'), ('ignored', 'VBN')]
#
# [('i', 'NN'), ('can', 'MD'), ('not', 'RB'), ('feel', 'VB')]
#
# [('do', 'VB'), ('not', 'RB'), ('turn', 'VB'), ('your', 'PRP$'), ('back', 'NN'), ('on', 'IN'), ('me', 'PRP')]
#
# [('i', 'NN'), ('will', 'MD'), ('not', 'RB'), ('be', 'VB'), ('ignored', 'VBN')]
#
# [('time', 'NN'), ('will', 'MD'), ('not', 'RB'), ('heal', 'VB')]
#
# [('do', 'VB'), ('not', 'RB'), ('turn', 'VB'), ('your', 'PRP$'), ('back', 'NN'), ('on', 'IN'), ('me', 'PRP'), ('i', 'VB'), ('will', 'MD'), ('not', 'RB'), ('be', 'VB'), ('ignored', 'VBN')]

# %%
len(cl)

# %%
str_4_sng
# Out:
# ' NN VBP DT JJ NN IN NN , DT JJ NN IN NN.  NN IN NNS CC NNS MD RB VB DT NN.  IN NN MD VB DT NNS.  NN VBP WP NN VBP PRP TO VB , WP VBZ VBP PRP TO VB.  CC PRP VBZ IN DT NN WP VBZ VBP , VB MD RB VB PRP.  TO RB VB DT VBZ JJ.  RB JJ , VB VB VBG PRP VBP PRP$ RP IN PRP RB VBP.  NN RB CC VBP NN VBP RB.  CC NN MD VB RB IN PRP VBP PDT IN NNS VBP VBN.  NN MD RB VB DT NN NN VBD IN.  VB RB VB PRP$ NN IN PRP.  NN MD RB VB VBN.  NN MD RB VB DT NN RB.  VB RB VB PRP$ NN IN PRP VB MD RB VB VBN.  NN VBP , DT JJ NN NN , DT JJ JJ.  IN PRP VBP RB VB NN VBP WP VB MD.  CC RB VB VBP RB VB NN.  NN VBP , WP PRP RB VBP TO VB , CC NNS VBP RB VBD DT NN.  PRP VBZ IN DT NN WP VBZ VBP NNS MD RB VB PRP IN RB RB TO VB PRP RP.  RB JJ , VB VB VBG PRP VBP PRP$ RP IN PRP RB VBP.  PRP VBP RB CC VBP NN VBP RB.  CC NN MD VB RB IN PRP VBP PDT IN NNS VBP VBN.  NN MD RB VB DT NN NN VBD IN.  VB RB VB PRP$ NN IN PRP.  NN MD RB VB VBN.  NN MD RB VB DT NN RB.  VB RB VB PRP$ NN IN PRP VB MD RB VB VBN.  PRP VBP PRP RP RB.  PRP VBP VBG TO VB TO PRP IN PRP CC RB.  RB RB , VB PRP RP RB.  PRP VBP VBG TO VB TO PRP IN PRP CC RB.  RB RB.  NN MD RB VB DT NN NN VBD IN.  VB RB VB PRP$ NN IN PRP.  NN MD RB VB VBN.  NN MD RB VB DT NN RB.  VB RB VB PRP$ NN IN PRP VB MD RB VB VBN.  NN MD RB VB.  VB RB VB PRP$ NN IN PRP.  NN MD RB VB VBN.  NN MD RB VB.  VB RB VB PRP$ NN IN PRP VB MD RB VB VBN. '

# %%
cleaned_lyrics
# Out:
# [['Text', 'Expanded', 'Cleaned'],
#  ['', [], []],
#  ['    i am a little bit of loneliness, a little bit of disregard',
#   ['i',
#    'am',
#    'a',
#    'little',
#    'bit',
#    'of',
#    'loneliness',
#    ',',
#    'a',
#    'little',
#    'bit',
#    'of',
#    'disregard'],
#   ['little', 'bit', 'loneliness', ',', 'little', 'bit', 'disregard']],
#  ["handful of complaints but i can't help the fact",
#   ['handful',
#    'of',
#    'complaints',
#    'but',
#    'i',
#    'can',
#    'not',
#    'help',
#    'the',
#    'fact'],
#   ['handful', 'complaints', 'help', 'fact']],
#  ['that everyone can see these scars',
#   ['that', 'everyone', 'can', 'see', 'these', 'scars'],
#   ['everyone', 'see', 'scars']],
#  ['i am what i want you to want, what i want you to feel',
#   ['i',
#    'am',
#    'what',
#    'i',
#    'want',
#    'you',
#    'to',
#    'want',
#    ',',
#    'what',
#    'i',
#    'want',
#    'you',
#    'to',
#    'feel'],
#   ['want', 'want', ',', 'want', 'feel']],
#  ["but it's like no matter what i do, i can't convince you",
#   ['but',
#    'it',
#    'is',
#    'like',
#    'no',
#    'matter',
#    'what',
#    'i',
#    'do',
#    ',',
#    'i',
#    'can',
#    'not',
#    'convince',
#    'you'],
#   ['like', 'matter', ',', 'convince']],
#  ['to just believe this is real',
#   ['to', 'just', 'believe', 'this', 'is', 'real'],
#   ['believe', 'real']],
#  ['so i, let go watching you turn your back like you always do',
#   ['so',
#    'i',
#    ',',
#    'let',
#    'go',
#    'watching',
#    'you',
#    'turn',
#    'your',
#    'back',
#    'like',
#    'you',
#    'always',
#    'do'],
#   [',', 'let', 'go', 'watching', 'turn', 'back', 'like', 'always']],
#  ["face away and pretend i'm not",
#   ['face', 'away', 'and', 'pretend', 'i', 'am', 'not'],
#   ['face', 'away', 'pretend']],
#  ["but i'll be here 'cause you're all that i've got",
#   ['but',
#    'i',
#    'will',
#    'be',
#    'here',
#    "'ecause",
#    'you',
#    'are',
#    'all',
#    'that',
#    'i',
#    'have',
#    'got'],
#   ["'ecause", 'got']],
#  ["i can't feel the way i did before",
#   ['i', 'can', 'not', 'feel', 'the', 'way', 'i', 'did', 'before'],
#   ['feel', 'way']],
#  ["don't turn your back on me",
#   ['do', 'not', 'turn', 'your', 'back', 'on', 'me'],
#   ['turn', 'back']],
#  ["i won't be ignored", ['i', 'will', 'not', 'be', 'ignored'], ['ignored']],
#  ["time won't heal this damage anymore",
#   ['time', 'will', 'not', 'heal', 'this', 'damage', 'anymore'],
#   ['time', 'heal', 'damage', 'anymore']],
#  ["don't turn your back on me i won't be ignored",
#   ['do',
#    'not',
#    'turn',
#    'your',
#    'back',
#    'on',
#    'me',
#    'i',
#    'will',
#    'not',
#    'be',
#    'ignored'],
#   ['turn', 'back', 'ignored']],
#  ['i am, a little bit insecure, a little unconfident',
#   ['i',
#    'am',
#    ',',
#    'a',
#    'little',
#    'bit',
#    'insecure',
#    ',',
#    'a',
#    'little',
#    'unconfident'],
#   [',', 'little', 'bit', 'insecure', ',', 'little', 'unconfident']],
#  ["'cause you don't understand i do what i can",
#   ["'ecause", 'you', 'do', 'not', 'understand', 'i', 'do', 'what', 'i', 'can'],
#   ["'ecause", 'understand']],
#  ["but sometimes i don't make sense",
#   ['but', 'sometimes', 'i', 'do', 'not', 'make', 'sense'],
#   ['sometimes', 'make', 'sense']],
#  ["i am, what you never want to say, but i've never had a doubt",
#   ['i',
#    'am',
#    ',',
#    'what',
#    'you',
#    'never',
#    'want',
#    'to',
#    'say',
#    ',',
#    'but',
#    'i',
#    'have',
#    'never',
#    'had',
#    'a',
#    'doubt'],
#   [',', 'never', 'want', 'say', ',', 'never', 'doubt']],
#  ["it's like no matter what i do i can't convince you for once just to hear me out",
#   ['it',
#    'is',
#    'like',
#    'no',
#    'matter',
#    'what',
#    'i',
#    'do',
#    'i',
#    'can',
#    'not',
#    'convince',
#    'you',
#    'for',
#    'once',
#    'just',
#    'to',
#    'hear',
#    'me',
#    'out'],
#   ['like', 'matter', 'convince', 'hear']],
#  ['so i, let go watching you turn your back like you always do',
#   ['so',
#    'i',
#    ',',
#    'let',
#    'go',
#    'watching',
#    'you',
#    'turn',
#    'your',
#    'back',
#    'like',
#    'you',
#    'always',
#    'do'],
#   [',', 'let', 'go', 'watching', 'turn', 'back', 'like', 'always']],
#  ["you face away and pretend i'm not",
#   ['you', 'face', 'away', 'and', 'pretend', 'i', 'am', 'not'],
#   ['face', 'away', 'pretend']],
#  ["but i'll be here 'cause you're all that i've got",
#   ['but',
#    'i',
#    'will',
#    'be',
#    'here',
#    "'ecause",
#    'you',
#    'are',
#    'all',
#    'that',
#    'i',
#    'have',
#    'got'],
#   ["'ecause", 'got']],
#  ["i can't feel the way i did before",
#   ['i', 'can', 'not', 'feel', 'the', 'way', 'i', 'did', 'before'],
#   ['feel', 'way']],
#  ["don't turn your back on me",
#   ['do', 'not', 'turn', 'your', 'back', 'on', 'me'],
#   ['turn', 'back']],
#  ["i won't be ignored", ['i', 'will', 'not', 'be', 'ignored'], ['ignored']],
#  ["time won't heal this damage anymore",
#   ['time', 'will', 'not', 'heal', 'this', 'damage', 'anymore'],
#   ['time', 'heal', 'damage', 'anymore']],
#  ["don't turn your back on me i won't be ignored",
#   ['do',
#    'not',
#    'turn',
#    'your',
#    'back',
#    'on',
#    'me',
#    'i',
#    'will',
#    'not',
#    'be',
#    'ignored'],
#   ['turn', 'back', 'ignored']],
#  ['you hear me out now', ['you', 'hear', 'me', 'out', 'now'], ['hear']],
#  ["you're gonna listen to me like it or not",
#   ['you', 'are', 'gon', 'na', 'listen', 'to', 'me', 'like', 'it', 'or', 'not'],
#   ['gon', 'na', 'listen', 'like']],
#  ['right now, hear me out now',
#   ['right', 'now', ',', 'hear', 'me', 'out', 'now'],
#   ['right', ',', 'hear']],
#  ["you're gonna listen to me like it or not",
#   ['you', 'are', 'gon', 'na', 'listen', 'to', 'me', 'like', 'it', 'or', 'not'],
#   ['gon', 'na', 'listen', 'like']],
#  ['right now', ['right', 'now'], ['right']],
#  ["i can't feel the way i did before",
#   ['i', 'can', 'not', 'feel', 'the', 'way', 'i', 'did', 'before'],
#   ['feel', 'way']],
#  ["don't turn your back on me",
#   ['do', 'not', 'turn', 'your', 'back', 'on', 'me'],
#   ['turn', 'back']],
#  ["i won't be ignored", ['i', 'will', 'not', 'be', 'ignored'], ['ignored']],
#  ["time won't heal this damage anymore",
#   ['time', 'will', 'not', 'heal', 'this', 'damage', 'anymore'],
#   ['time', 'heal', 'damage', 'anymore']],
#  ["don't turn your back on me i won't be ignored",
#   ['do',
#    'not',
#    'turn',
#    'your',
#    'back',
#    'on',
#    'me',
#    'i',
#    'will',
#    'not',
#    'be',
#    'ignored'],
#   ['turn', 'back', 'ignored']],
#  ["i can't feel ", ['i', 'can', 'not', 'feel'], ['feel']],
#  ["don't turn your back on me",
#   ['do', 'not', 'turn', 'your', 'back', 'on', 'me'],
#   ['turn', 'back']],
#  ["i won't be ignored", ['i', 'will', 'not', 'be', 'ignored'], ['ignored']],
#  ["time won't heal ", ['time', 'will', 'not', 'heal'], ['time', 'heal']],
#  ["don't turn your back on me i won't be ignored",
#   ['do',
#    'not',
#    'turn',
#    'your',
#    'back',
#    'on',
#    'me',
#    'i',
#    'will',
#    'not',
#    'be',
#    'ignored'],
#   ['turn', 'back', 'ignored']]]

# %%
# pos_tag_res

# %%
# for _ in range(2, len(pos_tag_res)):
#     print(pos_tag_res[_][1])

# %%
tree_list = []
str_4_sng = ''

for _ in range(2, len(pos_tag_res)):
#     print("Iteration: ", str(_), end='\n')
    print(pos_tag_res[_][1], end='\n\n')
    
    for _2 in range(len(pos_tag_res[_][1])):
#         print(pos_tag_res[_][1][_2][1])
        str_4_sng = str_4_sng + ' ' + pos_tag_res[_][1][_2][1]
    str_4_sng = str_4_sng + '. '
        
#     print()
# Out:
# [('telling', 'VBG'), ('me', 'PRP'), ('to', 'TO'), ('go', 'VB')]
#
# [('but', 'CC'), ('hands', 'VBZ'), ('beg', 'NNS'), ('me', 'PRP'), ('to', 'TO'), ('stay', 'VB')]
#
# [('your', 'PRP$'), ('lips', 'NNS'), ('say', 'VBP'), ('that', 'IN'), ('you', 'PRP'), ('love', 'VBP')]
#
# [('your', 'PRP$'), ('eyes', 'NNS'), ('say', 'VBP'), ('that', 'IN'), ('you', 'PRP'), ('hate', 'VBP')]
#
# [('there', 'EX'), ('is', 'VBZ'), ('truth', 'NN'), ('in', 'IN'), ('your', 'PRP$'), ('lies', 'NNS')]
#
# [('doubt', 'NN'), ('in', 'IN'), ('your', 'PRP$'), ('faith', 'NN')]
#
# [('what', 'WP'), ('you', 'PRP'), ('build', 'VBP'), ('you', 'PRP'), ('lay', 'VBP'), ('to', 'TO'), ('waste', 'VB')]
#
# [('there', 'EX'), ('is', 'VBZ'), ('truth', 'NN'), ('in', 'IN'), ('your', 'PRP$'), ('lies', 'NNS')]
#
# [('doubt', 'NN'), ('in', 'IN'), ('your', 'PRP$'), ('faith', 'NN')]
#
# [('all', 'DT'), ('i', 'NNS'), ('have', 'VBP'), ('got', 'VBN'), ("'s", 'POS'), ('what', 'WP'), ('you', 'PRP'), ('did', 'VBD'), ('not', 'RB'), ('take', 'VB')]
#
# [('so', 'RB'), ('i', 'JJ'), (',', ','), ('i', 'NN'), ('will', 'MD'), ('not', 'RB'), ('be', 'VB'), ('the', 'DT'), ('one', 'CD')]
#
# [('be', 'VB'), ('the', 'DT'), ('one', 'CD'), ('to', 'TO'), ('leave', 'VB'), ('this', 'DT')]
#
# [('in', 'IN'), ('pieces', 'NNS')]
#
# [('and', 'CC'), ('you', 'PRP'), (',', ','), ('you', 'PRP'), ('will', 'MD'), ('be', 'VB'), ('alone', 'RB')]
#
# [('alone', 'RB'), ('with', 'IN'), ('all', 'DT'), ('your', 'PRP$'), ('secrets', 'NNS')]
#
# [('and', 'CC'), ('regrets', 'NNS')]
#
# [('do', 'VB'), ('not', 'RB'), ('lie', 'VB')]
#
# [('you', 'PRP'), ('promise', 'VBP'), ('me', 'PRP'), ('the', 'DT'), ('sky', 'NN')]
#
# [('then', 'RB'), ('toss', 'IN'), ('me', 'PRP'), ('like', 'IN'), ('a', 'DT'), ('stone', 'NN')]
#
# [('you', 'PRP'), ('wrap', 'VBP'), ('me', 'PRP'), ('in', 'IN'), ('your', 'PRP$'), ('arms', 'NNS')]
#
# [('and', 'CC'), ('chill', 'VB'), ('me', 'PRP'), ('to', 'TO'), ('the', 'DT'), ('bone', 'NN')]
#
# [('there', 'EX'), ('is', 'VBZ'), ('truth', 'NN'), ('in', 'IN'), ('your', 'PRP$'), ('lies', 'NNS')]
#
# [('doubt', 'NN'), ('in', 'IN'), ('your', 'PRP$'), ('faith', 'NN')]
#
# [('all', 'DT'), ('i', 'NNS'), ('have', 'VBP'), ('got', 'VBN'), ("'s", 'POS'), ('what', 'WP'), ('you', 'PRP'), ('did', 'VBD'), ('not', 'RB'), ('take', 'VB')]
#
# [('so', 'RB'), ('i', 'JJ'), (',', ','), ('i', 'NN'), ('will', 'MD'), ('not', 'RB'), ('be', 'VB'), ('the', 'DT'), ('one', 'CD')]
#
# [('be', 'VB'), ('the', 'DT'), ('one', 'CD'), ('to', 'TO'), ('leave', 'VB'), ('this', 'DT')]
#
# [('in', 'IN'), ('pieces', 'NNS')]
#
# [('and', 'CC'), ('you', 'PRP'), (',', ','), ('you', 'PRP'), ('will', 'MD'), ('be', 'VB'), ('alone', 'RB')]
#
# [('alone', 'RB'), ('with', 'IN'), ('all', 'DT'), ('your', 'PRP$'), ('secrets', 'NNS')]
#
# [('and', 'CC'), ('regrets', 'NNS')]
#
# [('do', 'VB'), ('not', 'RB'), ('lie', 'VB')]
#
# [('so', 'RB'), ('i', 'JJ'), (',', ','), ('i', 'NN'), ('will', 'MD'), ('not', 'RB'), ('be', 'VB'), ('the', 'DT'), ('one', 'CD')]
#
# [('be', 'VB'), ('the', 'DT'), ('one', 'CD'), ('to', 'TO'), ('leave', 'VB'), ('this', 'DT')]
#
# [('in', 'IN'), ('pieces', 'NNS')]
#
# [('and', 'CC'), ('you', 'PRP'), (',', ','), ('you', 'PRP'), ('will', 'MD'), ('be', 'VB'), ('alone', 'RB')]
#
# [('alone', 'RB'), ('with', 'IN'), ('all', 'DT'), ('your', 'PRP$'), ('secrets', 'NNS')]
#
# [('and', 'CC'), ('regrets', 'NNS')]
#
# [('do', 'VB'), ('not', 'RB'), ('lie', 'VB')]
#
# []

# %%
str_4_sng
# Out:
# ' VBG PRP TO VB.  CC VBZ NNS PRP TO VB.  PRP$ NNS VBP IN PRP VBP.  PRP$ NNS VBP IN PRP VBP.  EX VBZ NN IN PRP$ NNS.  NN IN PRP$ NN.  WP PRP VBP PRP VBP TO VB.  EX VBZ NN IN PRP$ NNS.  NN IN PRP$ NN.  DT NNS VBP VBN POS WP PRP VBD RB VB.  RB JJ , NN MD RB VB DT CD.  VB DT CD TO VB DT.  IN NNS.  CC PRP , PRP MD VB RB.  RB IN DT PRP$ NNS.  CC NNS.  VB RB VB.  PRP VBP PRP DT NN.  RB IN PRP IN DT NN.  PRP VBP PRP IN PRP$ NNS.  CC VB PRP TO DT NN.  EX VBZ NN IN PRP$ NNS.  NN IN PRP$ NN.  DT NNS VBP VBN POS WP PRP VBD RB VB.  RB JJ , NN MD RB VB DT CD.  VB DT CD TO VB DT.  IN NNS.  CC PRP , PRP MD VB RB.  RB IN DT PRP$ NNS.  CC NNS.  VB RB VB.  RB JJ , NN MD RB VB DT CD.  VB DT CD TO VB DT.  IN NNS.  CC PRP , PRP MD VB RB.  RB IN DT PRP$ NNS.  CC NNS.  VB RB VB. . '

# %%
cleaned_lyrics
# Out:
# [['Text', 'Expanded', 'Cleaned'],
#  ['', [], []],
#  ['    telling me to go', ['telling', 'me', 'to', 'go'], ['telling', 'go']],
#  ['but hands beg me to stay',
#   ['but', 'hands', 'beg', 'me', 'to', 'stay'],
#   ['hands', 'beg', 'stay']],
#  ['your lips say that you love',
#   ['your', 'lips', 'say', 'that', 'you', 'love'],
#   ['lips', 'say', 'love']],
#  ['your eyes say that you hate',
#   ['your', 'eyes', 'say', 'that', 'you', 'hate'],
#   ['eyes', 'say', 'hate']],
#  ["there's truth in your lies",
#   ['there', 'is', 'truth', 'in', 'your', 'lies'],
#   ['truth', 'lies']],
#  ['doubt in your faith', ['doubt', 'in', 'your', 'faith'], ['doubt', 'faith']],
#  ['what you build you lay to waste',
#   ['what', 'you', 'build', 'you', 'lay', 'to', 'waste'],
#   ['build', 'lay', 'waste']],
#  ["there's truth in your lies",
#   ['there', 'is', 'truth', 'in', 'your', 'lies'],
#   ['truth', 'lies']],
#  ['doubt in your faith', ['doubt', 'in', 'your', 'faith'], ['doubt', 'faith']],
#  ["all i've got's what you didn't take",
#   ['all', 'i', 'have', 'got', "'s", 'what', 'you', 'did', 'not', 'take'],
#   ['got', "'s", 'take']],
#  ["so i, i won't be the one",
#   ['so', 'i', ',', 'i', 'will', 'not', 'be', 'the', 'one'],
#   [',', 'one']],
#  ['be the one to leave this',
#   ['be', 'the', 'one', 'to', 'leave', 'this'],
#   ['one', 'leave']],
#  ['in pieces', ['in', 'pieces'], ['pieces']],
#  ['and you, you will be alone',
#   ['and', 'you', ',', 'you', 'will', 'be', 'alone'],
#   [',', 'alone']],
#  ['alone with all your secrets',
#   ['alone', 'with', 'all', 'your', 'secrets'],
#   ['alone', 'secrets']],
#  ['and regrets', ['and', 'regrets'], ['regrets']],
#  ["don't lie", ['do', 'not', 'lie'], ['lie']],
#  ['you promise me the sky',
#   ['you', 'promise', 'me', 'the', 'sky'],
#   ['promise', 'sky']],
#  ['then toss me like a stone',
#   ['then', 'toss', 'me', 'like', 'a', 'stone'],
#   ['toss', 'like', 'stone']],
#  ['you wrap me in your arms',
#   ['you', 'wrap', 'me', 'in', 'your', 'arms'],
#   ['wrap', 'arms']],
#  ['and chill me to the bone',
#   ['and', 'chill', 'me', 'to', 'the', 'bone'],
#   ['chill', 'bone']],
#  ["there's truth in your lies",
#   ['there', 'is', 'truth', 'in', 'your', 'lies'],
#   ['truth', 'lies']],
#  ['doubt in your faith', ['doubt', 'in', 'your', 'faith'], ['doubt', 'faith']],
#  ["all i've got's what you didn't take",
#   ['all', 'i', 'have', 'got', "'s", 'what', 'you', 'did', 'not', 'take'],
#   ['got', "'s", 'take']],
#  ["so i, i won't be the one",
#   ['so', 'i', ',', 'i', 'will', 'not', 'be', 'the', 'one'],
#   [',', 'one']],
#  ['be the one to leave this',
#   ['be', 'the', 'one', 'to', 'leave', 'this'],
#   ['one', 'leave']],
#  ['in pieces', ['in', 'pieces'], ['pieces']],
#  ['and you, you will be alone',
#   ['and', 'you', ',', 'you', 'will', 'be', 'alone'],
#   [',', 'alone']],
#  ['alone with all your secrets',
#   ['alone', 'with', 'all', 'your', 'secrets'],
#   ['alone', 'secrets']],
#  ['and regrets', ['and', 'regrets'], ['regrets']],
#  ["don't lie", ['do', 'not', 'lie'], ['lie']],
#  ["so i, i won't be the one",
#   ['so', 'i', ',', 'i', 'will', 'not', 'be', 'the', 'one'],
#   [',', 'one']],
#  ['be the one to leave this',
#   ['be', 'the', 'one', 'to', 'leave', 'this'],
#   ['one', 'leave']],
#  ['in pieces', ['in', 'pieces'], ['pieces']],
#  ['and you, you will be alone',
#   ['and', 'you', ',', 'you', 'will', 'be', 'alone'],
#   [',', 'alone']],
#  ['alone with all your secrets',
#   ['alone', 'with', 'all', 'your', 'secrets'],
#   ['alone', 'secrets']],
#  ['and regrets', ['and', 'regrets'], ['regrets']],
#  ["don't lie", ['do', 'not', 'lie'], ['lie']],
#  ['    ', [], []]]
