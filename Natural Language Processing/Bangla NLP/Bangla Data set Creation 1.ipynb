# %%
import pickle

neg_lst = pickle.load(open("pos_word_list.pkl", "rb"))

# %%
len(neg_lst)
# Out:
# 4555

# %%
neg_lst[:5]
# Out:
# ['abnormal', 'abolish', 'abominable', 'abominably', 'abominate']

# %%
len(neg_lst)
# Out:
# 1563

# %%
import csv

data = [1,2,3,4,5]

with open('test.csv', 'w') as csvfile:
    writer = csv.writer(csvfile, delimiter="\n")
    writer.writerow(data)

# %%
import csv

# data = [1,2,3,4,5]

with open('pos_word_list.csv', 'w') as csvfile:
    writer = csv.writer(csvfile, delimiter="\n")
    writer.writerow(neg_lst)

# %%
neg_translated = []

# %%
from googletrans import Translator

# %%
for i in range(0, 10):
    trans = Translator()

    neg_translated.append([neg_lst[i], translator.translate(neg_lst[i], dest='bn')])
    
    
print('Completed!')
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-43-d422ff338afb> in <module>
#       2     trans = Translator()
#       3
# ----> 4     neg_translated.append([neg_lst[i], translator.translate(neg_lst[i], dest='bn')])
#       5
#       6
#
# ~/Project/pyenvs/env/lib/python3.6/site-packages/googletrans/client.py in translate(self, text, dest, src)
#     170
#     171         origin = text
# --> 172         data = self._translate(text, dest, src)
#     173
#     174         # this code will be updated when the format is changed.
#
# ~/Project/pyenvs/env/lib/python3.6/site-packages/googletrans/client.py in _translate(self, text, dest, src)
#      79         r = self.session.get(url, params=params)
#      80
# ---> 81         data = utils.format_json(r.text)
#      82         return data
#      83
#
# ...

# %%
neg_translated = translator.translate(neg_lst, dest='bn')
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# ~/Project/pyenvs/env/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~/Project/pyenvs/env/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     383                     # otherwise it looks like a programming error was the cause.
# --> 384                     six.raise_from(e, None)
#     385         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ...

# %%
# Out:
# 'zombie'

# %%
print(translator.translate('word', dest='bn'))
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-46-12de7d2db2a8> in <module>
# ----> 1 print(translator.translate('word', dest='bn'))
#
# ~/Project/pyenvs/env/lib/python3.6/site-packages/googletrans/client.py in translate(self, text, dest, src)
#     170
#     171         origin = text
# --> 172         data = self._translate(text, dest, src)
#     173
#     174         # this code will be updated when the format is changed.
#
# ~/Project/pyenvs/env/lib/python3.6/site-packages/googletrans/client.py in _translate(self, text, dest, src)
#      79         r = self.session.get(url, params=params)
#      80
# ---> 81         data = utils.format_json(r.text)
#      82         return data
#      83
#
# ~/Project/pyenvs/env/lib/python3.6/site-packages/googletrans/utils.py in format_json(original)
#      60         converted = json.loads(original)
# ...

# %%
translator.translate('word', dest='bn').text
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-47-2ba71d0500b4> in <module>
# ----> 1 translator.translate('word', dest='bn').text
#
# ~/Project/pyenvs/env/lib/python3.6/site-packages/googletrans/client.py in translate(self, text, dest, src)
#     170
#     171         origin = text
# --> 172         data = self._translate(text, dest, src)
#     173
#     174         # this code will be updated when the format is changed.
#
# ~/Project/pyenvs/env/lib/python3.6/site-packages/googletrans/client.py in _translate(self, text, dest, src)
#      79         r = self.session.get(url, params=params)
#      80
# ---> 81         data = utils.format_json(r.text)
#      82         return data
#      83
#
# ~/Project/pyenvs/env/lib/python3.6/site-packages/googletrans/utils.py in format_json(original)
#      60         converted = json.loads(original)
# ...

# %%
translator.translate('word', dest='bn').extra_data
# Out:
# {'translation': [['শব্দ', 'word', None, None, 0],
#   [None, None, 'Śabda', 'wərd']],
#  'all-translations': [['বিশেষ্য',
#    ['শব্দ',
#     'কথা',
#     'বাণী',
#     'উক্তি',
#     'দলগত সম্কেতশব্দ',
#     'পদ',
#     'আভাস',
#     'জবান',
#     'বোল',
#     'ঘোষণা'],
#    [['শব্দ',
#      ['word', 'sound', 'term', 'noise', 'cry', 'clop'],
#      None,
#      0.362176],
#     ['কথা',
#      ['word', 'saying', 'story', 'promise', 'accents', 'news'],
#      None,
#      0.03758125],
#     ['বাণী',
#      ['message', 'word', 'saying', 'aphorism', 'dictum', 'maxim'],
#      None,
#      0.022092877],
#     ['উক্তি',
#      ['saying', 'say', 'word', 'enunciation', 'term', 'emission'],
#      None,
#      0.00039837172],
#     ['দলগত সম্কেতশব্দ', ['shibboleth', 'word'], None, 3.0719129e-05],
#     ['পদ',
#      ['office', 'position', 'term', 'rank', 'job', 'word'],
#      None,
#      3.0719129e-05],
#     ['আভাস',
#      ['glimpse', 'glimmer', 'hint', 'semblance', 'guise', 'word'],
# ...
