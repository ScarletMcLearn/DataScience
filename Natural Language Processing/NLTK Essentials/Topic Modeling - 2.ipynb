# %%
import pickle

with open('story_list.pkl', 'rb') as f:
    docs = pickle.load(f)

# %%
docs[0]
# Out:
# 'used go thrift stores friends take train boston go garment district huge vintage clothing warehouse arranged somehow makes clothes beautiful kind like went wardrobe books instead finding white witch horrible found magic clothing talking animals feather boas wedding dresses bowling shoes paisley shirts doc martens hung racks first black dresses together like largest indoor funeral blue blues red dresses reds reds candy reds sometimes close eyes drag rack rub dress hand theory learn tell feeling example sitting lawn tell green grass eyes closed depending feels clothing stretchy velvet stuff always feels red eyes closed even red always best guessing colors also best cheating games getting time looking t-shirts found t-shirt belonged third grade knew belonged still name inside mother written permanent marker went summer camp bought back one money weekend one wondering guy like garment district bunch girls thing always good time matter likes likes likes best wherever bet great time wonde
# ...
